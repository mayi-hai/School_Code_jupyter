# %% [markdown]
# # 以段为单位依次读入射雕第一回的内容。

# %%
#导入书籍
import pandas as pd
# 有的环境配置下read_table出错，因此改用read_csv
raw = pd.read_csv("金庸-射雕英雄传txt精校版.txt",
                  names = ['txt'], sep ='aaa', encoding ="utf-8" ,engine='python')
print(len(raw))
raw
# Out:
# 7165
#                                                     txt
# 0     全本全集精校小说尽在：http://www.yimuhe.com/u/anglewing26...
# 1                       更多资源下载：http://qqzone.ctdisk.com
# 2     ※声明：本电子书仅供读者预览,请在下载24小时内删除，不得用作商业用途；如果喜欢请购买正版图书！※
# 3            ------------------------------------------
# 4                                             “金庸作品集”新序
# ...                                                 ...
# 7160                                            二〇〇二年六月
# 7161         ------------------------------------------
# 7162  全本全集精校小说尽在：http://www.yimuhe.com/u/anglewing26...
# 7163                    更多资源下载：http://qqzone.ctdisk.com
# 7164  ※声明：本电子书仅供读者预览,请在下载24小时内删除，不得用作商业用途；如果喜欢请购买正版图书！※
#
# [7165 rows x 1 columns]

# %%
# 章节判断用变量预处理
def m_head(tmpstr):
    return tmpstr[:1]

def m_mid(tmpstr):
    return tmpstr.find("回 ")

raw['head'] = raw.txt.apply(m_head)
raw['mid'] = raw.txt.apply(m_mid)
raw['len'] = raw.txt.apply(len)
# raw['chap'] = 0
raw.head(0)
# Out:
# Empty DataFrame
# Columns: [txt, head, mid, len]
# Index: []

# %%
# 章节判断
chapnum = 0
for i in range(len(raw)):
    if raw['head'][i] == "第" and raw['mid'][i] > 0 and raw['len'][i] < 30 :
        chapnum += 1
    if chapnum >= 40 and raw['txt'][i] == "附录一：成吉思汗家族" :
        chapnum = 0
    raw.loc[i, 'chap'] = chapnum
    
# 删除临时变量
del raw['head']
del raw['mid']
del raw['len']
raw.head(0)
# Out:
# Empty DataFrame
# Columns: [txt, chap]
# Index: []

# %%
##raw[raw.chap == 1].head()
tmpchap = raw[raw['chap'] == 1].copy()
#firstIdx = tmpchap.index[0]
tmpchap.reset_index(drop=True, inplace=True)
tmpchap['paraidx'] = tmpchap.index
tmpchap
# Out:
#                                                    txt  chap  paraidx
# 0                                             第一回 风雪惊变   1.0        0
# 1    钱塘江浩浩江水，日日夜夜无穷无休的从两浙西路临安府牛家村边绕过，东流入海。江畔一排数十株乌柏...   1.0        1
# 2    那说话人五十来岁年纪，一件青布长袍早洗得褪成了蓝灰带白。只听他两片梨花木板碰了几下，左手中竹...   1.0        2
# 3                                    几处败垣围故井，向来一一是人家。”   1.0        3
# 4    那说话人将木板敲了几下，说道：“这首七言诗，说的是兵火过后，原来的家家户户，都变成了断墙残瓦...   1.0        4
# ..                                                 ...   ...      ...
# 222  次日中午，两人到了嘉兴府。那是浙西大城，丝米集散之地，自来就十分繁盛，古称秀州，五代石晋时改...   1.0      222
# 223  颜烈道：“咱们找一家客店歇歇吧。”包惜弱一直在害怕官兵追来，道：“天色尚早，还可赶道呢。”颜...   1.0      223
# 224  包惜弱听他夸奖自己容貌，内心窃喜，低头道：“我是在热丧之中……”颜烈忙道：“小人理会得。”包...   1.0      224
# 225  颜烈问了途人，径去当地最大的“秀水客栈”投店。漱洗罢，颜烈与包惜弱一起吃了些点心，两人相对坐...   1.0      225
# 226  过了一会，颜烈道：“娘子请自宽便，小人出去买了物品就回。”包惜弱点了点头，道：“相公可别太多...   1.0      226
#
# [227 rows x 3 columns]

# %% [markdown]
# # 生成第一段交叉表

# %%
import pandas as pd
stoplist = list(pd.read_csv('停用词.txt',
                    names = ['w'], sep = 'aaa', encoding = 'utf-8',engine='python').w)

# %%
import jieba
def m_cut(tmpchap):
    return [ w for w in jieba.cut(tmpchap) if w not in stoplist and len(w) > 1 ]

# %%
def m_appdf(chapnum):
    tmpdf = pd.DataFrame(m_cut(tmpchap.txt[chapnum]), columns = ['word'])
    tmpdf['chap'] = tmpchap.index[chapnum]
    return tmpdf

# %%
df0 = pd.DataFrame(columns = ['word','chap'])

# %%
for chapidx in range(len(tmpchap)):
    df0 = df0.append(m_appdf(chapidx))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 0.823 seconds.
# Prefix dict has been built succesfully.

# %%
# df0.groupby(['word','chap']).agg('size').head()

# %%
t2d = pd.crosstab(df0.word, df0.chap)
len(t2d)
# Out:
# 3861

# %%
t2d.head(10000)
# Out:
# chap  0   ...   226
# word      ...
# 一两天     0 ...     0
# 一个      0 ...     0
# 一个个     0 ...     0
# 一个二十    0 ...     0
# 一个多     0 ...     0
# 一个月     0 ...     0
# 一了百了    0 ...     0
# 一事无成    0 ...     0
# 一人      0 ...     0
# 一件      0 ...     0
# 一众      0 ...     0
# 一伙      0 ...     0
# 一会      0 ...     1
# 一位      0 ...     0
# 一倒      0 ...     0
# 一兵      0 ...     0
# 一具      0 ...     0
# 一凛      0 ...     0
# 一击      0 ...     0
# 一刀      0 ...     0
# 一前一后    0 ...     0
# 一剑      0 ...     0
# 一力      0 ...     0
# 一动不动    0 ...     0
# 一匹      0 ...     0
# 一双      0 ...     0
# 一变      0 ...     0
# 一口      0 ...     0
# 一句      0 ...     0
# 一只      0 ...     0
# ...   ... ...   ...
# 鸡鸣犬吠    0 ...     0
# 鸡鸭      0 ...     0
# 鹰爪      0 ...     0
# 鹰犬      0 ...     0
# 麻札刀     0 ...     0
# 麻雀      0 ...     0
# 麾下      0 ...     0
# 黄大哥     0 ...     0
# 黄泉之下    0 ...     0
# 黄猄      0 ...     0
# 黄色      0 ...     0
# 黄酒      0 ...     0
# ...

# %% [markdown]
# # 为每一段分别生成bow稀疏向量。

# %%
#提取第一段
rawgrp = raw.groupby('chap')
chapter = rawgrp.sum()##.agg(sum) # 只有字符串列的情况下，sum函数自动转为合并字符串
chapter = chapter[chapter.index != 0]
txt1=chapter.txt[1]

# %%
import jieba
import pandas as pd
tmpdf = pd.read_csv('停用词.txt',
                    names = ['w'], sep = 'aaa', encoding = 'utf-8')
tmpdf.head()
aaa = [ w for w in jieba.cut(txt1) if w not in list(tmpdf.w) ]
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.

# %%
from gensim.corpora import Dictionary

texts = [aaa]
dct = Dictionary(texts)  # fit dictionary
dct.num_nnz
# Out:
# 4418

# %%
import jieba
for i in tmpchap.txt:
    result=[ w for w in jieba.cut(str(i)) if w not in list(tmpdf.w) ] 
    dct.add_documents([result])  
    dct.token2id
    print(dct.doc2bow(result))  
    print("=========================================================================================================================================")
# Out:
# [(0, 1), (1994, 1), (3332, 1), (4301, 1)]
# ...
# [(5, 1), (40, 1), (71, 1), (76, 1), (276, 1), (288, 1), (313, 1), (340, 1), (377, 1), (403, 1), (544, 1), (672, 1), (757, 1), (820, 1), (941, 1), (1035, 1), (1098, 1), (1160, 1), (1291, 1), (1445, 1), (1688, 1), (1829, 1), (2407, 1), (2444, 1), (2467, 1), (2486, 1), (2498, 1), (2527, 1), (2559, 1), (2634, 1), (2638, 1), (2671, 1), (2701, 1), (2765, 1), (2831, 1), (2833, 1), (2885, 1), (2893, 1), (2894, 1), (2896, 1), (2947, 1), (3014, 1), (3101, 1), (3127, 1), (3412, 1), (3465, 1), (3478, 1), (3574, 1), (3615, 1), (3749, 1), (3818, 1), (3842, 1), (4099, 1), (4119, 1)]
# ...
# [(13, 1), (316, 1), (321, 1), (453, 1), (754, 1), (1160, 1), (1216, 1), (1694, 1), (1741, 1), (1754, 1), (1788, 1), (1795, 1), (1810, 1), (1834, 1), (2416, 1), (2465, 1), (2506, 1), (2544, 1), (2596, 1), (2733, 1), (2972, 1), (3246, 1), (3322, 1), (3451, 1), (3597, 1), (3627, 1), (3685, 1), (3749, 1), (4165, 1), (4254, 1)]
# ...
# [(765, 1), (1145, 1), (2380, 1), (3775, 1)]
# ...

# %%
def m_cut(chaps):
    return [ w for w in jieba.cut(chaps) if w not in stoplist and len(w) > 1 ]
def m_appdf(chapnum):
    tmpdf = pd.DataFrame(m_cut(chaps.txt[chapnum]), columns = ['word'])
    tmpdf['chap'] = chaps.index[chapnum]
    return tmpdf
df2 = pd.DataFrame(columns = ['word','chap'])
for chapidx in range(len(chaps)):
    df2 = df2.append(m_appdf(chapidx))
    tsd = pd.crosstab(df2.word, df2.chap)
len(tsd)
tsd.head(10000)
