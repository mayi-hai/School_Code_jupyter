# %% [markdown]
# 分词

# %%
import pandas as pd
# 有的环境配置下read_table出错，因此改用read_csv
raw = pd.read_csv("金庸-射雕英雄传txt精校版.txt",
                  names = ['txt'], sep ='aaa', encoding ="GBK" ,engine='python')
print(len(raw))
raw
# Out:
# 7165
#                                                     txt
# 0     全本全集精校小说尽在：http://www.yimuhe.com/u/anglewing26...
# 1                       更多资源下载：http://qqzone.ctdisk.com
# 2     ※声明：本电子书仅供读者预览,请在下载24小时内删除，不得用作商业用途；如果喜欢请购买正版图书！※
# 3            ------------------------------------------
# 4                                             “金庸作品集”新序
# 5                                     小说是写给人看的。小说的内容是人。
# 6     小说写一个人、几个人、一群人、或成千成万人的性格和感情。他们的性格和感情从横面的环境中反映出...
# 7     西洋传统的小说理论分别从环境、人物、情节三个方面去分析一篇作品。由于小说作者不同的个性与才能...
# 8     基本上，武侠小说与别的小说一样，也是写人，只不过环境是古代的，主要人物是有武功的，情节偏重于...
# 9     小说是艺术的一种，艺术的基本内容是人的感情和生命，主要形式是美，广义的、美学上的美。在小说，...
# 10    读者阅读一部小说，是将小说的内容与自己的心理状态结合起来。同样一部小说，有的人感到强烈的震动...
# 11    武侠小说只是表现人情的一种特定形式。作曲家或演奏家要表现一种情绪，用钢琴、小提琴、交响乐、或...
# 12    好或者不好，在艺术上是属于美的范畴，不属于真或善的范畴。判断美的标准是美，是感情，不是科学上...
# 13    在中世纪的欧洲，基督教的势力及于一切，所以我们到欧美的博物院去参观，见到所有中世纪的绘画都以...
# 14    中国人的文艺观，长期以来是“文以载道”，那和中世纪欧洲黑暗时代的文艺思想是一致的，用“善或不...
# 15    我写武侠小说，只是塑造一些人物，描写他们在特定的武侠环境（中国古代的、没有法治的、以武力来解...
# 16    对于小说，我希望读者们只说喜欢或不喜欢，只说受到感动或觉得厌烦。我最高兴的是读者喜爱或憎恨我...
# 17    武侠小说虽说是通俗作品，以大众化、娱乐性强为重点，但对广大读者终究是会发生影响的。我希望传达...
# 18    武侠小说并不是现实主义的作品。有不少批评家认定，文学上只可肯定现实主义一个流派，除此之外，全...
# 19    撰写这套总数三十六册的《作品集》，是从一九五五年到七二年，前后约十三、四年，包括十二部长篇小...
# 20    翻版本不付版税，还在其次。许多版本粗制滥造，错讹百出。还有人借用“金庸”之名，撰写及出版武侠...
# 21    有些翻版本中，还说我和古龙、倪匡合出了一个上联“冰比冰水冰”徵对，真正是大开玩笑了。汉语的对...
# 22    为了使得读者易于分辨，我把我十四部长、中篇小说书名的第一个字凑成一副对联：“飞雪连天射白鹿，...
# 23    有不少读者来信提出一个同样的问题：“你所写的小说之中，你认为哪一部最好？最喜欢哪一部？”这个...
# 24    这些小说在香港、台湾、中国内地、新加坡曾拍摄为电影和电视连续集，有的还拍了三、四个不同版本，...
# 25    武侠小说继承中国古典小说的长期传统。中国最早的武侠小说，应该是唐人传奇的《虬髯客传》、《红线...
# 26    我初期所写的小说，汉人皇朝的正统观念很强。到了后期，中华民族各族一视同仁的观念成为基调，那是...
# 27    历史上的事件和人物，要放在当时的历史环境中去看。宋辽之际、元明之际、明清之际，汉族和契丹、蒙...
# 28    在刘再复先生与他千金刘剑梅合写的“父女两地书”（共悟人间）中，剑梅小姐提到她曾和李陀先生的一...
# 29    这次第三次修改，改正了许多错字讹字、以及漏失之处，多数由于得到了读者们的指正。有几段较长的补...
# ...                                                 ...
# 7135                                                 黄裳
# 7136  《射雕英雄传》中所说的黄裳真有其人。近人陈国符先生《道藏源流考》中考证宋徽宗访求天下道教遗书...
# 7137  黄裳，字晟仲，人称演山先生，福建延平人，高宗建炎三年卒，年八十七。《演山先生神道碑》中说他：...
# 7138  黄裳刊印道藏的名气很响，后来明教刊印经书，也借用他的名字。陆游《渭南文集卷五·条对状》：“明...
# 7139                    至于黄裳根据道藏而撰《九阴真经》，自是武侠小说家的凭空撰述了。
# 7140                                                 后记
# 7141  《射雕英雄传》作于一九五七年到一九五九年，在《香港商报》连载。回想十多年前《香港商报》副刊编...
# 7142  《射雕》中的人物个性单纯，郭靖诚朴厚重、黄蓉机智灵巧，读者容易印象深刻。这是中国传统小说和戏...
# 7143  写《射雕》时，我正在长城电影公司做编剧和导演，这段时期中所读的书主要是西洋的戏剧和戏剧理论，...
# 7144  修订时曾作了不少改动。删去了初版中一些与故事或人物并无必要联系的情节，如小红鸟、蛙蛤大战、铁...
# 7145  成吉思汗的事迹，主要取材于一部非常奇怪的书。这部书本来面目的怪异，远胜《九阴真经》，书名《忙...
# 7146  原来此书是以汉字写蒙古话，写成于一二四○年七月。“忙豁仑”就是“蒙古”，“纽察”在蒙古话中是...
# 7147  《元朝秘史》的第一行，仍写着原书书名的怪文“忙豁仑纽察脱必赤颜”。起初治元史的学者如李文田等...
# 7148  后来叶德辉所刊印的“怪文本”流传到了外国，各国汉学家热心研究，其中以法国人伯希和、德国人海涅...
# 7149  我所参考的《蒙古秘史》，是外蒙古学者策·达木丁苏隆先将汉字怪文本还原为蒙古古语（原书是十三世...
# 7150  《秘史》是原始材料，有若干修正本流传到西方，再由此而发展成许多著作，其中最重要的是波斯人拉施...
# 7151                  《九阴真经》中那段怪文的设想从什么地方得到启发，读者们自然知道了。
# 7152  蒙古人统治全中国八十九年，统治中国北部则超过一百年，但因文化低落，对中国人的生活没有遗留重大...
# 7153  本书的插图（大陆版未收——编注）有一幅是大理国画师张胜温所绘的佛像，此图有明朝翰林学士宋濂的...
# 7154  其中所考证的年代弄错了。宋濂认为画中的“庚子”是宋理宗嘉熙四年（一二四○年），其实他算迟了六...
# 7155  此图现藏台北故宫博物馆，该馆出版物中的说明根据宋濂的考证而写，将来似可改正。宋濂是明初有大名...
# 7156                                           一九七五年十二月
# 7157  本书第三版于2001年至2002年再作修订，改正了不少年代的错误，黄药师和诸弟子的关系也重写...
# 7158  第三版修订本中，将吕文焕守襄阳一节，改为李全、杨妙真夫妇领“忠义军”守青州，以顺合历史及地理...
# 7159  本书台湾出版者台北远流出版公司负责人王荣文先生、编辑李佳颖小姐、郑祥琳小姐、赵贞仪小姐，对书...
# 7160                                            二〇〇二年六月
# 7161         ------------------------------------------
# 7162  全本全集精校小说尽在：http://www.yimuhe.com/u/anglewing26...
# 7163                    更多资源下载：http://qqzone.ctdisk.com
# 7164  ※声明：本电子书仅供读者预览,请在下载24小时内删除，不得用作商业用途；如果喜欢请购买正版图书！※
#
# [7165 rows x 1 columns]

# %%
# 章节判断用变量预处理
def m_head(tmpstr):
    return tmpstr[:1]

def m_mid(tmpstr):
    return tmpstr.find("回 ")

raw['head'] = raw.txt.apply(m_head)
raw['mid'] = raw.txt.apply(m_mid)
raw['len'] = raw.txt.apply(len)
# raw['chap'] = 0
raw.head(50)
# Out:
#                                                   txt ...   len
# 0   全本全集精校小说尽在：http://www.yimuhe.com/u/anglewing26... ...    55
# 1                     更多资源下载：http://qqzone.ctdisk.com ...    31
# 2   ※声明：本电子书仅供读者预览,请在下载24小时内删除，不得用作商业用途；如果喜欢请购买正版图书！※ ...    49
# 3          ------------------------------------------ ...    42
# 4                                           “金庸作品集”新序 ...     9
# 5                                   小说是写给人看的。小说的内容是人。 ...    17
# 6   小说写一个人、几个人、一群人、或成千成万人的性格和感情。他们的性格和感情从横面的环境中反映出... ...   225
# 7   西洋传统的小说理论分别从环境、人物、情节三个方面去分析一篇作品。由于小说作者不同的个性与才能... ...    56
# 8   基本上，武侠小说与别的小说一样，也是写人，只不过环境是古代的，主要人物是有武功的，情节偏重于... ...   151
# 9   小说是艺术的一种，艺术的基本内容是人的感情和生命，主要形式是美，广义的、美学上的美。在小说，... ...   133
# 10  读者阅读一部小说，是将小说的内容与自己的心理状态结合起来。同样一部小说，有的人感到强烈的震动... ...    94
# 11  武侠小说只是表现人情的一种特定形式。作曲家或演奏家要表现一种情绪，用钢琴、小提琴、交响乐、或... ...   155
# 12  好或者不好，在艺术上是属于美的范畴，不属于真或善的范畴。判断美的标准是美，是感情，不是科学上... ...   148
# 13  在中世纪的欧洲，基督教的势力及于一切，所以我们到欧美的博物院去参观，见到所有中世纪的绘画都以... ...   140
# 14  中国人的文艺观，长期以来是“文以载道”，那和中世纪欧洲黑暗时代的文艺思想是一致的，用“善或不... ...   176
# 15  我写武侠小说，只是塑造一些人物，描写他们在特定的武侠环境（中国古代的、没有法治的、以武力来解... ...   287
# 16  对于小说，我希望读者们只说喜欢或不喜欢，只说受到感动或觉得厌烦。我最高兴的是读者喜爱或憎恨我... ...   262
# 17  武侠小说虽说是通俗作品，以大众化、娱乐性强为重点，但对广大读者终究是会发生影响的。我希望传达... ...   266
# 18  武侠小说并不是现实主义的作品。有不少批评家认定，文学上只可肯定现实主义一个流派，除此之外，全... ...   293
# 19  撰写这套总数三十六册的《作品集》，是从一九五五年到七二年，前后约十三、四年，包括十二部长篇小... ...   336
# 20  翻版本不付版税，还在其次。许多版本粗制滥造，错讹百出。还有人借用“金庸”之名，撰写及出版武侠... ...   224
# 21  有些翻版本中，还说我和古龙、倪匡合出了一个上联“冰比冰水冰”徵对，真正是大开玩笑了。汉语的对... ...   128
# 22  为了使得读者易于分辨，我把我十四部长、中篇小说书名的第一个字凑成一副对联：“飞雪连天射白鹿，... ...   240
# 23  有不少读者来信提出一个同样的问题：“你所写的小说之中，你认为哪一部最好？最喜欢哪一部？”这个... ...   234
# 24  这些小说在香港、台湾、中国内地、新加坡曾拍摄为电影和电视连续集，有的还拍了三、四个不同版本，... ...   370
# 25  武侠小说继承中国古典小说的长期传统。中国最早的武侠小说，应该是唐人传奇的《虬髯客传》、《红线... ...   239
# 26  我初期所写的小说，汉人皇朝的正统观念很强。到了后期，中华民族各族一视同仁的观念成为基调，那是... ...   306
# 27  历史上的事件和人物，要放在当时的历史环境中去看。宋辽之际、元明之际、明清之际，汉族和契丹、蒙... ...   188
# 28  在刘再复先生与他千金刘剑梅合写的“父女两地书”（共悟人间）中，剑梅小姐提到她曾和李陀先生的一... ...   280
# 29  这次第三次修改，改正了许多错字讹字、以及漏失之处，多数由于得到了读者们的指正。有几段较长的补... ...   159
# 30                                        二○○二年四月 于香港 ...    11
# 31                                           第一回 风雪惊变 ...     8
# 32  钱塘江浩浩江水，日日夜夜无穷无休的从两浙西路临安府牛家村边绕过，东流入海。江畔一排数十株乌柏... ...   136
# 33  那说话人五十来岁年纪，一件青布长袍早洗得褪成了蓝灰带白。只听他两片梨花木板碰了几下，左手中竹... ...    81
# 34                                  几处败垣围故井，向来一一是人家。” ...    17
# 35  那说话人将木板敲了几下，说道：“这首七言诗，说的是兵火过后，原来的家家户户，都变成了断墙残瓦... ...   342
# 36  “叶老汉和叶妈妈吓得呆了，扑将上去，搂住了儿子的尸体，放声大哭。那长官提起狼牙棒，一棒一个，... ...   245
# 37                        他说一段，唱一段，只听得众村民无不咬牙切齿，愤怒叹息。 ...    27
# 38                                  那人又道：“众位听了，常言道得好： ...    17
# 39                                   为人切莫用欺心，举头三尺有神明。 ...    16
# 40                                   若还作恶无报应，天下凶徒人吃人。 ...    16
# 41  “可是那金兵占了我大宋天下，杀人放火，奸淫掳掠，无恶不作，却又不见他遭到什么报应。只怪我大宋... ...   234
# 42    众村民便有人拿出两文三文，放入木盘，霎时间得了六七十文。张十五谢了，将铜钱放入囊中，便欲起行。 ...    47
# 43  村民中走出一个二十来岁的大汉，说道：“张先生，你可是从北方来吗？”说的是北方口音。张十五见他... ...   225
# 44                        郭啸天带着张十五来到村头一家小酒店中，在张饭桌旁坐了。 ...    27
# 45  小酒店的主人是个跛子，撑着两根拐杖，慢慢烫了两壶黄酒，摆出一碟蚕豆、一碟咸花生，一碟豆腐干，... ...    92
# 46  郭啸天斟了酒，劝张十五喝了两杯，说道：“乡下地方，只初二、十六才有肉卖。没了下酒之物，先生莫... ...   173
# 47  张十五叹道：“江南花花世界，遍地皆是金银，放眼但见美女，金兵又有哪一日不想过来？只是他来与不... ...    69
# 48                         郭啸天和杨铁心齐感诧异，同声问道：“这却是怎生说？” ...    26
# 49  张十五道：“我中国百姓，比女真人多上一百倍也还不止。只要朝廷肯用忠臣良将，咱们一百个打他一个... ...   187
#
# [50 rows x 4 columns]

# %%
# 章节判断
chapnum = 0
for i in range(len(raw)):
    if raw['head'][i] == "第" and raw['mid'][i] > 0 and raw['len'][i] < 30 :
        chapnum += 1
    if chapnum >= 40 and raw['txt'][i] == "附录一：成吉思汗家族" :
        chapnum = 0
    raw.loc[i, 'chap'] = chapnum
    # 删除临时变量
del raw['head']
del raw['mid']
del raw['len']

raw.head(50)
# Out:
#                                                   txt  chap
# 0   全本全集精校小说尽在：http://www.yimuhe.com/u/anglewing26...   0.0
# 1                     更多资源下载：http://qqzone.ctdisk.com   0.0
# 2   ※声明：本电子书仅供读者预览,请在下载24小时内删除，不得用作商业用途；如果喜欢请购买正版图书！※   0.0
# 3          ------------------------------------------   0.0
# 4                                           “金庸作品集”新序   0.0
# 5                                   小说是写给人看的。小说的内容是人。   0.0
# 6   小说写一个人、几个人、一群人、或成千成万人的性格和感情。他们的性格和感情从横面的环境中反映出...   0.0
# 7   西洋传统的小说理论分别从环境、人物、情节三个方面去分析一篇作品。由于小说作者不同的个性与才能...   0.0
# 8   基本上，武侠小说与别的小说一样，也是写人，只不过环境是古代的，主要人物是有武功的，情节偏重于...   0.0
# 9   小说是艺术的一种，艺术的基本内容是人的感情和生命，主要形式是美，广义的、美学上的美。在小说，...   0.0
# 10  读者阅读一部小说，是将小说的内容与自己的心理状态结合起来。同样一部小说，有的人感到强烈的震动...   0.0
# 11  武侠小说只是表现人情的一种特定形式。作曲家或演奏家要表现一种情绪，用钢琴、小提琴、交响乐、或...   0.0
# 12  好或者不好，在艺术上是属于美的范畴，不属于真或善的范畴。判断美的标准是美，是感情，不是科学上...   0.0
# 13  在中世纪的欧洲，基督教的势力及于一切，所以我们到欧美的博物院去参观，见到所有中世纪的绘画都以...   0.0
# 14  中国人的文艺观，长期以来是“文以载道”，那和中世纪欧洲黑暗时代的文艺思想是一致的，用“善或不...   0.0
# 15  我写武侠小说，只是塑造一些人物，描写他们在特定的武侠环境（中国古代的、没有法治的、以武力来解...   0.0
# 16  对于小说，我希望读者们只说喜欢或不喜欢，只说受到感动或觉得厌烦。我最高兴的是读者喜爱或憎恨我...   0.0
# 17  武侠小说虽说是通俗作品，以大众化、娱乐性强为重点，但对广大读者终究是会发生影响的。我希望传达...   0.0
# 18  武侠小说并不是现实主义的作品。有不少批评家认定，文学上只可肯定现实主义一个流派，除此之外，全...   0.0
# 19  撰写这套总数三十六册的《作品集》，是从一九五五年到七二年，前后约十三、四年，包括十二部长篇小...   0.0
# 20  翻版本不付版税，还在其次。许多版本粗制滥造，错讹百出。还有人借用“金庸”之名，撰写及出版武侠...   0.0
# 21  有些翻版本中，还说我和古龙、倪匡合出了一个上联“冰比冰水冰”徵对，真正是大开玩笑了。汉语的对...   0.0
# 22  为了使得读者易于分辨，我把我十四部长、中篇小说书名的第一个字凑成一副对联：“飞雪连天射白鹿，...   0.0
# 23  有不少读者来信提出一个同样的问题：“你所写的小说之中，你认为哪一部最好？最喜欢哪一部？”这个...   0.0
# 24  这些小说在香港、台湾、中国内地、新加坡曾拍摄为电影和电视连续集，有的还拍了三、四个不同版本，...   0.0
# 25  武侠小说继承中国古典小说的长期传统。中国最早的武侠小说，应该是唐人传奇的《虬髯客传》、《红线...   0.0
# 26  我初期所写的小说，汉人皇朝的正统观念很强。到了后期，中华民族各族一视同仁的观念成为基调，那是...   0.0
# 27  历史上的事件和人物，要放在当时的历史环境中去看。宋辽之际、元明之际、明清之际，汉族和契丹、蒙...   0.0
# 28  在刘再复先生与他千金刘剑梅合写的“父女两地书”（共悟人间）中，剑梅小姐提到她曾和李陀先生的一...   0.0
# 29  这次第三次修改，改正了许多错字讹字、以及漏失之处，多数由于得到了读者们的指正。有几段较长的补...   0.0
# 30                                        二○○二年四月 于香港   0.0
# 31                                           第一回 风雪惊变   1.0
# 32  钱塘江浩浩江水，日日夜夜无穷无休的从两浙西路临安府牛家村边绕过，东流入海。江畔一排数十株乌柏...   1.0
# 33  那说话人五十来岁年纪，一件青布长袍早洗得褪成了蓝灰带白。只听他两片梨花木板碰了几下，左手中竹...   1.0
# 34                                  几处败垣围故井，向来一一是人家。”   1.0
# 35  那说话人将木板敲了几下，说道：“这首七言诗，说的是兵火过后，原来的家家户户，都变成了断墙残瓦...   1.0
# 36  “叶老汉和叶妈妈吓得呆了，扑将上去，搂住了儿子的尸体，放声大哭。那长官提起狼牙棒，一棒一个，...   1.0
# 37                        他说一段，唱一段，只听得众村民无不咬牙切齿，愤怒叹息。   1.0
# 38                                  那人又道：“众位听了，常言道得好：   1.0
# 39                                   为人切莫用欺心，举头三尺有神明。   1.0
# 40                                   若还作恶无报应，天下凶徒人吃人。   1.0
# 41  “可是那金兵占了我大宋天下，杀人放火，奸淫掳掠，无恶不作，却又不见他遭到什么报应。只怪我大宋...   1.0
# 42    众村民便有人拿出两文三文，放入木盘，霎时间得了六七十文。张十五谢了，将铜钱放入囊中，便欲起行。   1.0
# 43  村民中走出一个二十来岁的大汉，说道：“张先生，你可是从北方来吗？”说的是北方口音。张十五见他...   1.0
# 44                        郭啸天带着张十五来到村头一家小酒店中，在张饭桌旁坐了。   1.0
# 45  小酒店的主人是个跛子，撑着两根拐杖，慢慢烫了两壶黄酒，摆出一碟蚕豆、一碟咸花生，一碟豆腐干，...   1.0
# 46  郭啸天斟了酒，劝张十五喝了两杯，说道：“乡下地方，只初二、十六才有肉卖。没了下酒之物，先生莫...   1.0
# 47  张十五叹道：“江南花花世界，遍地皆是金银，放眼但见美女，金兵又有哪一日不想过来？只是他来与不...   1.0
# 48                         郭啸天和杨铁心齐感诧异，同声问道：“这却是怎生说？”   1.0
# 49  张十五道：“我中国百姓，比女真人多上一百倍也还不止。只要朝廷肯用忠臣良将，咱们一百个打他一个...   1.0

# %%
#提取第一段
rawgrp = raw.groupby('chap')
chapter = rawgrp.sum()##.agg(sum) # 只有字符串列的情况下，sum函数自动转为合并字符串
chapter = chapter[chapter.index != 0]
txt1=chapter.txt[1]

# %%
import jieba
res = jieba.cut(txt1) # 精确模式
dict = '金庸小说词库.txt'
jieba.load_userdict(dict) # dict为自定义词典的路径
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost

# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# 分词人名和地名（尝试过一些办法，但做不好，只能粗略分词）

# %%
import jieba.posseg as psg
tmpres = psg.cut(str(word_list) )# 附加词性的分词结果
a=[]
alist=list(a)
for item in tmpres:
    if (item.flag=="nr") :
        alist.append(item.word)
    #print(item.word, item.flag)
print(alist)
# Out:
# ['钱塘江', '府', '牛家村', '乌', '柏树', '叶子', '黄', '萧索', '松树', '叶老汉', '卫州', '叶三姐', '马鞍', '小姑娘', '叶三姐', '那金兵', '叶四郎', '阴世', '叶老汉', '叶', '叶三姐', '叶三姐', '叶三姐', '那时快', '叶三姐', '叶三姐', '那金兵', '宋', '宋', '叶三姐', '诸君', '宁作', '莫为', '张十五', '叶三姐', '张十五', '张十五', '张十五', '郭', '郭啸天', '白净', '杨铁心', '杨兄弟', '叶三姐', '郭杨', '郭啸天', '张十五', '咸蛋', '郭啸天', '张十五', '杨铁心', '金狗', '江', '张十五', '宋朝廷', '郭啸天', '杨铁心', '宋', '高宗', '金', '金', '郭啸天', '宗道君', '蔡京', '朱', '王', '童贯', '梁师成', '李邦彦', '李纲', '李纲', '郭京', '郭啸天', '杨铁心', '郭啸天', '靖康', '杨铁心', '康王', '韩世忠', '岳爷爷', '秦桧', '岳爷爷', '张十五', '郭', '杨二人', '岳爷爷', '胡虏', '秦桧', '郭啸天', '杨铁心', '秦桧', '冷笑', '杨铁心', '秦桧', '岳爷爷', '秦桧', '秦桧', '秦桧', '岳爷爷', '高宗皇帝', '望天', '老虎', '老虎', '老虎', '老虎', '老虎', '慈爱', '老虎', '老虎', '岳爷爷', '秦桧', '高宗皇帝', '高宗皇帝', '郭啸天', '岳爷爷', '金', '高宗', '金', '岳飞', '秦桧', '岳爷爷', '岳爷爷', '宋金', '高宗皇帝', '向金国', '杨铁心', '高宗皇帝', '赵构', '蒙恩造', '子孙', '子孙', '金国皇帝', '郭啸天', '高宗', '秦桧', '秦桧', '鲁国公', '荣宠', '高宗', '金', '光宗', '郭啸天', '秦桧', '张十五', '杨铁心', '宋君臣', '张十五', '向东', '岳飞', '满江红', '靖康', '郭啸天', '杨铁心', '郭啸天', '李氏', '杨', '杨铁心', '李氏', '杨铁心', '郭啸天', '郭', '杨二人', '铎', '铎', '铎', '郭', '杨二人', '铎', '高明', '郭杨', '牛家村', '武功', '林来', '左跃开', '左拐', '武功', '左拐', '双拐', '郭', '杨二人', '仰天', '郭', '杨二人', '武功', '郭兄', '杨兄', '郭', '杨二人', '杨铁心', '郭啸天', '杨兄', '杨家枪', '杨铁心', '郭兄', '双戟', '郭啸天', '牛家村', '牛家村', '侍卫', '郭', '杨二人', '郭', '杨二人', '杨铁心', '杨铁心', '铁铸', '劳驾', '郭', '杨二人', '郭', '杨二人', '郭', '杨二人', '郭啸天', '郭兄', '梁山泊', '赛仁贵', '郭盛', '杨兄', '杨再兴', '岳爷爷', '牛家村', '郭', '杨二人', '祖宗', '郭盛', '杨再兴', '绿林好汉', '归顺', '宋', '祖宗', '杨铁心', '寻思', '丹青', '郭', '杨二人', '丹青', '杨铁心', '宋', '郭啸天', '武功', '郭', '杨二人', '郭
'杨铁心', '包惜弱', '包惜弱', '包惜弱', '包惜弱', '白雪', '仁慈', '田鸡', '田野', '养满', '红梅', '包惜弱', '杨铁心', '杨铁心', '包惜弱', '包惜弱', '包惜弱', '那枝箭', '包惜弱', '包惜弱', '包惜弱', '包惜弱', '高耸', '宛', '包惜弱', '包惜弱', '包惜弱', '柴房中', '冷汗', '包惜弱', '杨铁心', '包惜弱', '杨铁心', '小女儿', '包惜弱', '红梅', '杨铁心', '包惜弱', '杨氏', '包惜弱', '杨铁心', '包惜弱', '张木儿', '包惜弱', '杨铁心', '包惜弱', '杨铁心', '包惜弱', '包惜弱', '包惜弱', '马来', '杨铁心', '越来越近', '杨铁心', '包惜弱', '杨铁心', '杨铁心', '齐声', '莫让', '杨铁心', '寻思', '武功', '郭啸天', '杨铁心', '杨铁心', '包惜弱', '杨铁心', '包惜弱', '杨铁心', '包惜弱', '杨铁心', '包惜弱', '杨铁心', '小猫儿', '包惜弱', '郭啸天', '杨铁心', '牛家村', '杨铁心', '杨铁心', '杨铁心', '杨铁心', '白虹', '春雷', '武勇', '杨铁心', '郭犯', '郭啸天', '郭啸天', '郭啸天', '府', '牛家村', '郭啸天', '杨铁心', '严审', '郭啸天 ...

# %%
import jieba.posseg as psg
tmpres = psg.cut(str(word_list) )# 附加词性的分词结果
b=[]
blist=list(b)
for item in tmpres:
    if (item.flag=="ns") :
        blist.append(item.word)
    #print(item.word, item.flag)
print(blist)
# Out:
# ['江水', '浙西', '临安', '东', '江畔', '京城', '汴梁', '汴梁', '中国', '江北', '江南', '太平', '大汉', '大汉', '大汉', '咸', '落山', '太阳', '山东', '江南', '江南', '金国', '临安', '中国', '朝廷', '半壁江山', '江山', '朝廷', '京城', '汴梁', '京城', '中国', '南京', '京城', '汴梁', '中国', '临安', '金国', '中国', '绍兴', '绍兴', '两国', '淮', '藩国', '中国', '淮水', '河山', '泰山', '江山', '临安', '青山', '西湖', '杭州', '汴州', '西湖', '杭州', '汴梁', '旧京', '临安', '无伦', '临安', '东西', '八拜', '朝廷', '妙绝', '半壁江山', '东西', '东', '大江', '北风', '东西', '之士', '临安', '朝廷', '临安', '竹篱茅舍', '山野', '临安', '扬头', '江湖', '山东', '大汉', '临安', '满口', '山东', '山东', '东西', '江湖', '怒极', '长撒', '中原', '法堪堪', '虎口', '长春', '长春', '江南', '长春', '江湖', '临安', '临安', '大金国', '金国', '意兴', '二哥', '东西', '哥哥', '松林', '鸭', '波', '深渊', '英雄', '东村', '东南西北', '江湖', '东西', '临安', '临安', '临安', '白马', '那马', '上马', '临安', '那马', '中原', '辽东', '那马', '北', '黑马', '长索', '长索', '黑马', '黑马', '临安', '贵村', '之士', '上马', '北', '那大', '长安', '香', '江南春', '北', '临安', '临安', '临安', '安顿', '朝廷', '英雄', '淮河', '中宿', '浙西', '大城', '秀州', '龙兴', '临安', '兴旺']

# %%
sumlist=alist + blist
print(sumlist)
# Out:
# ['钱塘江', '府', '牛家村', '乌', '柏树', '叶子', '黄', '萧索', '松树', '叶老汉', '卫州', '叶三姐', '马鞍', '小姑娘', '叶三姐', '那金兵', '叶四郎', '阴世', '叶老汉', '叶', '叶三姐', '叶三姐', '叶三姐', '那时快', '叶三姐', '叶三姐', '那金兵', '宋', '宋', '叶三姐', '诸君', '宁作', '莫为', '张十五', '叶三姐', '张十五', '张十五', '张十五', '郭', '郭啸天', '白净', '杨铁心', '杨兄弟', '叶三姐', '郭杨', '郭啸天', '张十五', '咸蛋', '郭啸天', '张十五', '杨铁心',
'杨铁心', '包惜弱', '杨铁心', '包惜弱', '杨铁心', '包惜弱', '杨铁心', '包惜弱', '杨铁心', '小猫儿', '包惜弱', '郭啸天', '杨铁心', '牛家村', '杨铁心', '杨铁心', '杨铁心', '杨铁心', '白虹', '春雷', '武勇', '杨铁心', '郭犯', '郭啸天', '郭啸天', '郭啸天', '府', '牛家村', '郭啸天', '杨铁心', '严审', '郭啸天 ...

# %% [markdown]
# 计算词频

# %%
import pandas as pd

df = pd.DataFrame(sumlist, columns = ['word'])
result = df.groupby(['word']).size()
print(type(result))
dlist = result.sort_values(ascending=False)
dlist
# Out:
# <class 'pandas.core.series.Series'>
# word
# 杨铁心     148
# 包惜弱     114
# 郭啸天      67
# 颜烈       38
# 郭        38
# 杨二人      32
# 那道人      24
# 临安       21
# 段天德      17
# 杨家枪      13
# 秦桧       12
# 武功       11
# 叶三姐      10
# 岳爷爷      10
# 张十五      10
# 李氏        9
# 宋         9
# 府         9
# 金         9
# 冷笑        7
# 老虎        7
# 牛家村       7
# 杨         7
# 东西        6
# 杨再兴       6
# 相公        6
# 中国        6
# 马背        6
# 汴梁        5
# 朝廷        5
#        ...
# 盘桓        1
# 罗帕        1
# 绿林好汉      1
# 红颜        1
# 红缨        1
# 红光        1
# 索上        1
# 竹篱茅舍      1
# 童贯        1
# 秦明        1
# 秋尽冬       1
# 秀州        1
# 神智        1
# 祖传        1
# 白马        1
# 滑如游       1
# 白虹        1
# 白自在       1
# 白布        1
# 白刃        1
# 白净        1
# 田鸡        1
# 田野        1
# 田中        1
# 琼瑶        1
# 王大人       1
# 王         1
# 满江红       1
# 满口        1
# 江北        1
# Length: 309, dtype: int64

# %% [markdown]
# 第一问：将所有的人名按照蓝色系，地名按照红色系进行词云绘制。

# %%
import wordcloud
myfont = 'msyh.ttf'
import matplotlib.pyplot as plt

cloudobj = wordcloud.WordCloud(font_path = myfont,
        mode = "RGBA", background_color = None).fit_words(dlist)
plt.imshow(cloudobj)
plt.axis("off")
plt.show()

# %%
# 官网提供的颜色分组类代码，略有修改
from wordcloud import get_single_color_func

class GroupedColorFunc(object):

    def __init__(self, color_to_words, default_color):
        self.color_func_to_words = [
            (get_single_color_func(color), set(words))
            for (color, words) in color_to_words.items()]

        self.default_color_func = get_single_color_func(default_color)

    def get_color_func(self, word):
        """Returns a single_color_func associated with the word"""
        try:
            color_func = next(
                color_func for (color_func, words) in self.color_func_to_words
                if word in words)
        except StopIteration:
            color_func = self.default_color_func

        return color_func

    def __call__(self, word, **kwargs):
        return self.get_color_func(word)(word, **kwargs)

######

# 指定分组色系
color_to_words = {
   'blue': alist,
   'red':blist
}

default_color = 'red' # 指定其他词条的颜色

grouped_color_func = GroupedColorFunc(color_to_words, default_color)

cloudobj.recolor(color_func=grouped_color_func)

plt.imshow(cloudobj)
plt.axis("off")
plt.show()

# %% [markdown]
# 第二问：自行制作两个纯色图片，分别为绿色和蓝色，然后将其分别指定为绘图所用的色系，观察图形效果。

# %%
import numpy as np
from scipy.misc import imread
imgobj = imread("a.jpg")
image_colors = wordcloud.ImageColorGenerator(np.array(imgobj))
cloudobj.recolor(color_func=image_colors)

plt.imshow(cloudobj)
plt.axis("off")
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
import numpy as np
from scipy.misc import imread
imgobj = imread("b.jpg")
image_colors = wordcloud.ImageColorGenerator(np.array(imgobj))
cloudobj.recolor(color_func=image_colors)

plt.imshow(cloudobj)
plt.axis("off")
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# 第三问：尝试使用不同的背景图片作为掩模，思考怎样的图片才能使得绘图效果最佳。

# %%
cloudobj = wordcloud.WordCloud(font_path = myfont,max_words = 500,
    mask = imread("射雕背景1.png"), 
    mode = "RGBA", background_color = None                      
    ).fit_words(dlist)

plt.imshow(cloudobj)
plt.axis("off")
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.

# %%
cloudobj = wordcloud.WordCloud(font_path = myfont,max_words = 500, 
    mask = imread("射雕背景2.png"), 
    mode = "RGBA", background_color = None
    ).fit_words(dlist)

plt.imshow(cloudobj)
plt.axis("off")
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
