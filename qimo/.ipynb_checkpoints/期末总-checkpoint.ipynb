# %%
import pandas as pd
# 载入语料
raw = pd.read_csv("金庸-射雕英雄传txt精校版.txt",
                  names = ['txt'], sep ='aaa', encoding ="utf-8" ,engine='python')

# 章节判断用变量预处理
def m_head(tmpstr):
    return tmpstr[:1]

def m_mid(tmpstr):
    return tmpstr.find("回 ")

raw['head'] = raw.txt.apply(m_head)
raw['mid'] = raw.txt.apply(m_mid)
raw['len'] = raw.txt.apply(len)
# 章节判断
chapnum = 0
for i in range(len(raw)):
    if raw['head'][i] == "第" and raw['mid'][i] > 0 and raw['len'][i] < 30 :
        chapnum += 1
    if chapnum >= 40 and raw['txt'][i] == "附录一：成吉思汗家族" :
        chapnum = 0
    raw.loc[i, 'chap'] = chapnum
    
# 删除临时变量
del raw['head']
del raw['mid']
del raw['len']
# 提取出三四章内容
chap3=list(raw[raw.chap == 3].txt)
chap4=list(raw[raw.chap == 4].txt)

# chap3 = raw[raw['chap'] == 3].copy()
# chap3.reset_index(drop=True, inplace=True)
# chap3['paraidx'] = chap3.index
# del chap3['chap']
# del chap3['paraidx']

# chap4 = raw[raw['chap'] == 4].copy()
# chap4.reset_index(drop=True, inplace=True)
# chap4['paraidx'] = chap4.index
# del chap4['chap']
# del chap4['paraidx']


# 对三四章内容提取关键词
import jieba
import jieba.analyse
chap3_g=[]
chap4_g=[]
for w in chap3:
    chap3_g.append(jieba.analyse.extract_tags(w,20))
for w in chap4:
    chap4_g.append(jieba.analyse.extract_tags(w,20))

#选取训练集和测试集
text_chap3=chap3_g[120:150]
train_chap3=chap3_g[10:110]
text_chap4=chap4_g[150:180]
train_chap4=chap4_g[1:101]

# %%
# import pandas as pd
# chap4_a=pd.DataFrame({'chap_g':chap4_g,'chap':4})
# chap3_a=pd.DataFrame({'chap_g':chap3_g,'chap':3})
# chap_a=pd.concat([chap4_a,chap3_a])
# from sklearn.model_selection import train_test_split
# train_chap3, test_chap3, train_chap4, text_chap4 = train_test_split(chap_a['chap_g'].values,
#                                                                     chap_a['chap'].values, 
#                                                                     test_size = 0.3, 
#                                                                     random_state = 111)

# %%
# # 进行训练集计算
# #求P(A|Y)=P(Y|A)*P(A)/P(Y)

# # 求PY,P(Y)
# PY={}
# PY['train_chap3']=len(train_chap3)/(len(train_chap3)+len(train_chap4))
# PY['train_chap4']=len(train_chap4)/(len(train_chap3)+len(train_chap4))

# %%
# 求PYA3,PYA4
#第三,四章关键词词频统计
a3=[]
for i in range(len(train_chap3)):    
    for j in train_chap3[i]:
        a3.append(j)
a4=[]
for i in range(len(train_chap4)):    
    for j in train_chap4[i]:
        a4.append(j)
b3={}
for i in a3:
    if i in b3:
        b3[i] += 1
    else:
        b3[i] = 1
b4={}
for i in a4:
    if i in b4:
        b4[i] += 1
    else:
        b4[i] = 1
c3=list(set(b3))
c4=list(set(b4))
PYA3={}
for i in c3:
    if i in b3:
        PYA3[i]=b3[i]/len(a3)
PYA4={}
for i in c4:
    if i in b4:
        PYA4[i]=b4[i]/len(a4)

# %%
# 对第三章训练集判断
PP3=[]
for j in range(30):
    P3 = {}
    for i in text_chap3[j]:
        if i in PYA3:
            P3[i]=PYA3[i]
        else:
            P3[i]=0.001
    PP3.append(P3)

Pl3=[]
for j in range(30):
    m=1
    for i in PP3[j]:
        m=m*PP3[j][i]
    Pl3.append(m)

PP4=[]
for j in range(30):
    P4 = {}
    for i in text_chap3[j]:
        if i in PYA4:
            P4[i]=PYA4[i]
        else:
            P4[i]=0.001
    PP4.append(P4)

Pl4=[]
for j in range(30):
    m=1
    for i in PP4[j]:
        m=m*PP4[j][i]
    Pl4.append(m)

import numpy as np
a=np.array(Pl3)
b=np.array(Pl4)
e=a>b
e
# Out:
# array([False, False,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True, False,  True,  True,
#         True,  True,  True,  True, False,  True,  True, False,  True,
#        False,  True, False])

# %%
# 对第四章训练集判断
BB3=[]
for j in range(30):
    B3 = {}
    for i in text_chap4[j]:
        if i in PYA3:
            B3[i]=PYA3[i]
        else:
            B3[i]=0.01
    BB3.append(B3)

Bl3=[]
for j in range(30):
    m=1
    for i in BB3[j]:
        m=m*BB3[j][i]
    Bl3.append(m)

BB4=[]
for j in range(30):
    B4 = {}
    for i in text_chap4[j]:
        if i in PYA4:
            B4[i]=PYA4[i]
        else:
            B4[i]=0.01
    BB4.append(B4)

Bl4=[]
for j in range(30):
    m=1
    for i in BB4[j]:
        m=m*BB4[j][i]
    Bl4.append(m)

import numpy as np
aa=np.array(Bl3)
ba=np.array(Bl4)
ea=aa>ba
ea
# Out:
# array([ True,  True, False,  True,  True,  True,  True,  True,  True,
#         True, False,  True, False,  True,  True,  True,  True, False,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True])

# %%
c = np.vstack((e,ea))
c
# Out:
# array([[False, False,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True,  True,  True,  True, False,  True,  True,
#          True,  True,  True,  True, False,  True,  True, False,  True,
#         False,  True, False],
#        [ True,  True, False,  True,  True,  True,  True,  True,  True,
#          True, False,  True, False,  True,  True,  True,  True, False,
#          True,  True,  True,  True,  True,  True,  True,  True,  True,
#          True,  True,  True]])

# %%
d=['True,'*60]
baa=np.array(d)
d
# Out:
# ['True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,True,']

# %%
# pred=[0]*len(tp4)
# for i in range(len(tp4)):
#     if tp3[i]>tp4[i]:
#         pred[i]=3
#     else:
#         pred[i]=4

# %%
from sklearn.metrics import classification_report
target_names = ['class 3', 'class 4',]
print(classification_report(d, c, target_names=target_names))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-241-d6ec46cb0869> in <module>
#       1 from sklearn.metrics import classification_report
#       2 target_names = ['class 3', 'class 4',]
# ----> 3 print(classification_report(d, c, target_names=target_names))
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in classification_report(y_true, y_pred, labels, target_names, sample_weight, digits, output_dict)
#    1850     """
#    1851
# -> 1852     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#    1853
#    1854     labels_given = True
#
# ~\Anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      69     y_pred : array or indicator matrix
#      70     """
# ---> 71     check_consistent_length(y_true, y_pred)
#      72     type_true = type_of_target(y_true)
#      73     type_pred = type_of_target(y_pred)
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     203     if len(uniques) > 1:
#     204         raise ValueError("Found input variables with inconsistent numbers of"
# --> 205                          " samples: %r" % [int(l) for l in lengths])
#     206
#     207
#
# ValueError: Found input variables with inconsistent numbers of samples: [1, 2]

# %%
text_chap4
# Out:
# [['凉嗖嗖',
#   '朱聪',
#   '但觉',
#   '犹似',
#   '大青纸',
#   '心增',
#   '轻雷',
#   '窒滞',
#   '惊怖',
#   '云遮',
#   '浓墨',
#   '斜眼',
#   '脱出',
#   '电光',
#   '黑云',
#   '缠住',
#   '背心',
#   '郁闷',
#   '闪烁',
#   '冷汗'],
#  ['梅超风', '柯镇恶', '石坑', '打坐', '藏身', '弯腰', '石板', '尸首', '片刻', '起身', '之前'],
#  ['六怪', '兵刃', '跃出', '紧握', '石板', '个个', '江南', '立即'],
#  ['梅超风',
#   '上显',
#   '长啸',
#   '树梢',
#   '一响',
#   '陡然',
#   '树叶',
#   '人头',
#   '风声',
#   '月光',
#   '树上',
#   '影子',
#   '猛然',
#   '微微',
#   '回头',
#   '背后',
#   '似乎',
#   '一声',
#   '正在',
#   '出来'],
#  ['韩宝驹',
#   '梅超风',
#   '心疾',
#   '扑下',
#   '左掌',
#   '树巅',
#   '下跃',
#   '微一长',
#   '竟立',
#   '上击',
#   '反带',
#   '出劲',
#   '回夺',
#   '身随',
#   '已如',
#   '风行电掣',
#   '掌未到',
#   '风先',
#   '撤鞭',
#   '翻落'],
#  ['袖箭',
#   '韩宝驹',
#   '只感',
#   '南希仁',
#   '全金发',
#   '透骨',
#   '凉气',
#   '往前',
#   '竭力',
#   '双双',
#   '一股',
#   '敌人',
#   '同时'],
#  ['梅超风',
#   '韩宝驹',
#   '右掌',
#   '飘风',
#   '双爪',
#   '连弹',
#   '弹落',
#   '左足点',
#   '纵出',
#   '正落',
#   '这铁',
#   '尸动',
#   '只感',
#   '他大惊',
#   '斩落',
#   '铁锥',
#   '敌人',
#   '十指',
#   '借势',
#   '临危'],
#  ['足踝',
#   '梅超风',
#   '提脚往',
#   '首一条',
#   '猛往',
#   '南希仁',
#   '樵子',
#   '黑黝黝',
#   '扁担',
#   '臀部',
#   '忽地',
#   '南山',
#   '正是'],
#  ['汉子',
#   '妙龄女郎',
#   '屠牛',
#   '乡农',
#   '怪样',
#   '梅超风',
#   '韩宝驹',
#   '铁扇',
#   '使剑',
#   '从右',
#   '使软',
#   '先施',
#   '手爪',
#   '猛往',
#   '韩小莹',
#   '辣手',
#   '攻到',
#   '点穴',
#   '一个',
#   '胖子'],
#  ['曲池',
#   '铁扇',
#   '韩小莹',
#   '敌人',
#   '手臂',
#   '朱聪见',
#   '凶锐',
#   '肘心',
#   '这铁尸',
#   '右爪',
#   '直伸',
#   '横削',
#   '梅超风',
#   '翻处',
#   '竟似',
#   '大骇',
#   '缩剑',
#   '朱聪',
#   '全臂',
#   '朱聪正'],
#  ['全金发',
#   '兵刃',
#   '梅超风',
#   '齐施',
#   '练功夫',
#   '硬接',
#   '双爪',
#   '浑号',
#   '韩宝驹',
#   '肉掌',
#   '竟似',
#   '比六怪',
#   '硬夺',
#   '恶挖',
#   '六怪',
#   '这铁尸',
#   '殊非',
#   '已练',
#   '张阿生',
#   '韩小莹'],
#  ['梅超风',
#   '铁扇',
#   '两穴',
#   '功夫',
#   '有毒',
#   '练功夫',
#   '霎时之间',
#   '恶妇',
#   '廉泉',
#   '神阙',
#   '查知',
#   '朱聪心',
#   '连试',
#   '穴道',
#   '没罩',
#   '朱聪大惊',
#   '他动念',
#   '奇速',
#   '入肉',
#   '觉到'],
#  ['愈战愈勇',
#   '情急智生',
#   '三堆',
#   '暴骨',
#   '抓伤',
#   '朱聪跃开',
#   '久战',
#   '铜尸',
#   '张阿生',
#   '韩宝驹',
#   '全金发',
#   '南希仁',
#   '韩小莹',
#   '见累',
#   '间射出',
#   '柯镇恶',
#   '石坑',
#   '五侠',
#   '边战边',
#   '飞步'],
#  ['野种',
#   '梅超风',
#   '南希仁',
#   '全金发',
#   '韩小莹',
#   '朱聪',
#   '张阿生',
#   '韩宝驹',
#   '飞步',
#   '拼力',
#   '暗算',
#   '钻出来',
#   '俯身',
#   '老娘',
#   '石板',
#   '合力',
#   '挡住',
#   '冷笑',
#   '这时候',
#   '三人'],
#  ['双目',
#   '圈住',
#   '梅超风',
#   '南希仁',
#   '右爪',
#   '朱聪猛',
#   '望天',
#   '递出',
#   '下来',
#   '似是',
#   '扁担',
#   '左臂',
#   '直取',
#   '高举',
#   '夹击',
#   '招手',
#   '同伴',
#   '一指',
#   '隐藏',
#   '左手'],
#  ['梅超风',
#   '南希仁',
#   '手爪',
#   '分神',
#   '满天',
#   '明月',
#   '不由自主',
#   '望去',
#   '乌云',
#   '避开',
#   '乘机',
#   '低头',
#   '一惊',
#   '抬头',
#   '哪里',
#   '只见',
#   '有人',
#   '这么'],
#  ['七步',
#   '柯镇恶',
#   '毒菱',
#   '铁菱',
#   '齐施',
#   '打空',
#   '呼喝声',
#   '六枚',
#   '朱聪',
#   '菱分',
#   '江南七怪',
#   '梅超风',
#   '奇速',
#   '激射',
#   '四枚',
#   '上中下',
#   '之前',
#   '后仰',
#   '卸去',
#   '来势'],
#  ['石板',
#   '梅超风',
#   '急怒',
#   '双掌齐',
#   '柯镇恶',
#   '双掌',
#   '若狂',
#   '急出',
#   '七怪',
#   '相攻',
#   '攻心',
#   '右脚',
#   '心惊',
#   '两声',
#   '登时',
#   '无不',
#   '愤怒',
#   '一旁',
#   '上前',
#   '岩石'],
#  ['梅超风',
#   '七怪',
#   '凝气',
#   '长鞭',
#   '视物',
#   '抓乱',
#   '朱聪连',
#   '叫众',
#   '疯虎',
#   '形若',
#   '齐折',
#   '离得',
#   '胁下',
#   '舞成',
#   '银圈',
#   '打手势',
#   '兵刃',
#   '纷飞',
#   '邪魔',
#   '沙石'],
#  ['朱聪向',
#   '柯镇恶',
#   '发身',
#   '刚摇',
#   '目盲',
#   '摇摇手',
#   '摇手',
#   '手势',
#   '猛地',
#   '大哥',
#   '开口',
#   '想起',
#   '哪里',
#   '不可',
#   '说话'],
#  ['柯镇恶',
#   '梅超风',
#   '神龙',
#   '飞天',
#   '报仇',
#   '长笑',
#   '默然不语',
#   '辟邪',
#   '暗器',
#   '仰天',
#   '冷冷地',
#   '兄长',
#   '没见',
#   '小子',
#   '从来',
#   '记得',
#   '口气',
#   '不错',
#   '兄弟'],
#  ['宛似',
#   '寒风刺骨',
#   '阴气森',
#   '七怪',
#   '遮去',
#   '梅超风',
#   '身侧',
#   '尖尖',
#   '鞭盘',
#   '身前',
#   '练熟',
#   '韩小莹',
#   '五根',
#   '额前',
#   '疾风',
#   '兵刃',
#   '一条',
#   '这时',
#   '蟒蛇',
#   '映出'],
#  ['长鞭',
#   '柯镇恶',
#   '纵起',
#   '左手',
#   '手指',
#   '铁杖',
#   '身子',
#   '朱聪',
#   '全金发',
#   '未毕',
#   '胸袭',
#   '疾撑',
#   '树巅',
#   '梅超风',
#   '一扑',
#   '六怪',
#   '七怪',
#   '因九阴',
#   '似比',
#   '劲风'],
#  ['梅超风', '怪声', '长啸', '中气', '尖细', '忽地', '传送', '远远地', '充沛', '突击', '出去', '声音'],
#  ['朱聪心',
#   '铜尸',
#   '于臂',
#   '施重',
#   '张阿生',
#   '快干',
#   '后心',
#   '猛力',
#   '相救',
#   '运气',
#   '呼唤',
#   '一动',
#   '举起',
#   '头顶',
#   '手法',
#   '岩石',
#   '双手',
#   '丈夫',
#   '前来',
#   '一块'],
#  ['练功夫',
#   '梅超风',
#   '柯镇恶',
#   '风辨形',
#   '朱聪',
#   '这一掌',
#   '妙手',
#   '痛彻',
#   '粗重',
#   '一掌',
#   '心肺',
#   '大石',
#   '双目',
#   '书生',
#   '分辨',
#   '寻常',
#   '避开',
#   '厉害',
#   '得出',
#   '未能'],
#  ['朱聪', '次掌', '梅超风', '左爪', '反钩', '避过', '进袭', '疾忙', '跳开', '一掌', '得手', '跟着'],
#  ['啸声',
#   '传来',
#   '梅超风',
#   '已近',
#   '七怪',
#   '柯镇恶',
#   '尸来',
#   '好快',
#   '长啸',
#   '声音',
#   '顷刻之间',
#   '毛骨悚然',
#   '夹击',
#   '隐隐',
#   '余人',
#   '远处',
#   '上前',
#   '脚步',
#   '正要',
#   '一惊'],
#  ['韩小莹', '边啸', '飞驰而来', '奔马', '黑影', '望去', '山下', '一旁', '只见', '一个'],
#  ['毒质',
#   '抗毒',
#   '梅超风',
#   '守紧',
#   '行散',
#   '进击',
#   '歼敌',
#   '只待',
#   '运气',
#   '不致',
#   '救援',
#   '急速',
#   '门户',
#   '眼中',
#   '赶来',
#   '丈夫',
#   '一面',
#   '此时',
#   '不再'],
#  ['朱聪向',
#   '全金发',
#   '朱聪见',
#   '铁尸',
#   '那铜尸',
#   '明攻',
#   '硬战',
#   '显非',
#   '身法',
#   '犹在',
#   '敌手',
#   '功力',
#   '偷袭',
#   '钻入',
#   '以图',
#   '草丛',
#   '侥幸',
#   '手势',
#   '打个',
#   '暗中'],
#  ['矮小',
#   '人影',
#   '郭靖',
#   '韩小莹',
#   '山来',
#   '甚慢',
#   '看时',
#   '抢下去',
#   '要接',
#   '急奔',
#   '心知',
#   '又惊又喜',
#   '身形',
#   '凝神',
#   '人形',
#   '必是',
#   '小孩',
#   '先前',
#   '走上',
#   '而来'],
#  ['郭靖相',
#   '陈玄风',
#   '韩小莹',
#   '微一',
#   '铜尸',
#   '好快',
#   '轻身',
#   '片刻之间',
#   '加快脚步',
#   '毒手',
#   '甚远',
#   '怎能不',
#   '单身',
#   '眼见',
#   '路程',
#   '遇上',
#   '势必',
#   '迟疑',
#   '下山',
#   '功夫'],
#  ['眉睫', '郭靖见', '大祸', '欢呼', '大叫', '不知'],
#  ['张阿生',
#   '韩小莹',
#   '准拟',
#   '情愫',
#   '涉险',
#   '逃开',
#   '情急',
#   '爱慕',
#   '表露',
#   '救人',
#   '飞奔',
#   '这些年来',
#   '向来',
#   '丝毫',
#   '暗暗',
#   '关心',
#   '前面',
#   '这时',
#   '不敢',
#   '一直'],
#  ['南希仁',
#   '韩宝驹',
#   '梅超风',
#   '韩张',
#   '扣住',
#   '暗器',
#   '山腰',
#   '以备',
#   '各人',
#   '注视',
#   '支援',
#   '山上',
#   '动静',
#   '二人',
#   '进攻',
#   '手里',
#   '不再'],
#  ['韩小莹',
#   '郭靖面',
#   '飞逃',
#   '丈许',
#   '猛觉',
#   '郭靖大',
#   '陈玄风',
#   '一轻',
#   '转眼',
#   '小手',
#   '惊呼',
#   '拉住',
#   '转身',
#   '手里',
#   '一把',
#   '过去'],
#  ['韩小莹',
#   '左足',
#   '疾往',
#   '左胁',
#   '微侧',
#   '敌目',
#   '越女剑',
#   '剑尖',
#   '轻灵',
#   '精微',
#   '招数',
#   '直取',
#   '闪动',
#   '一招',
#   '光芒',
#   '点头',
#   '身子',
#   '跟着',
#   '敌人',
#   '一点'],
#  ['陈玄风',
#   '韩小莹',
#   '郭靖',
#   '猛见',
#   '剑身',
#   '发掌',
#   '圈转',
#   '斜里',
#   '削来',
#   '中掌',
#   '手肘',
#   '顺水推舟',
#   '陡然间',
#   '长剑',
#   '半尺',
#   '倏地',
#   '抵住',
#   '右臂',
#   '反手',
#   '闪开'],
#  ['韩小莹',
#   '陈玄风',
#   '张阿生',
#   '两招',
#   '出爪',
#   '插落',
#   '九阴',
#   '摧筋',
#   '破骨',
#   '血孔',
#   '势危',
#   '一爪',
#   '狠辣',
#   '天灵盖',
#   '毫不容情',
#   '数步',
#   '情急',
#   '五指',
#   '拚命',
#   '白骨'],
#  ['张阿生',
#   '陈玄风',
#   '尖刀',
#   '猛往',
#   '刺去',
#   '格出',
#   '大声吼叫',
#   '脱手',
#   '一掌',
#   '反手',
#   '胸口',
#   '随手',
#   '伸手',
#   '敌人',
#   '出去'],
#  ['朱聪', '全金发', '南希仁', '韩宝驹', '急奔', '大惊', '一齐'],
#  ['陈玄风',
#   '韩小莹',
#   '婆娘',
#   '驴打滚',
#   '痛不痛',
#   '梅超风',
#   '惨声',
#   '抓落',
#   '招子',
#   '数尺',
#   '狗贼',
#   '跑不了',
#   '滚开',
#   '别动',
#   '拚命',
#   '举手',
#   '扶住',
#   '一个',
#   '大树',
#   '七个'],
#  ['张阿生',
#   '陈玄风',
#   '韩小莹',
#   '双臂',
#   '中见',
#   '拼起',
#   '运劲',
#   '敌人',
#   '身受',
#   '五指',
#   '右脚',
#   '迷糊',
#   '小腿',
#   '挺身',
#   '脑门',
#   '一拳',
#   '情势',
#   '插入',
#   '之力',
#   '腰间'],
#  ['五哥',
#   '韩小莹',
#   '递剑',
#   '进招',
#   '张阿生',
#   '先逃',
#   '南希仁',
#   '韩宝驹',
#   '朱聪',
#   '全金发',
#   '已射出',
#   '轻灵',
#   '一挡',
#   '滴溜溜',
#   '身法',
#   '暗器',
#   '跃起',
#   '身形',
#   '脱身',
#   '翻身'],
#  ['陈玄风',
#   '梅超风',
#   '柯镇恶',
#   '妻子',
#   '婆娘',
#   '怒道',
#   '心下',
#   '朱聪',
#   '五人',
#   '敌人',
#   '伺机而动',
#   '送终',
#   '伤得',
#   '狗贼',
#   '嘴硬',
#   '素不相识',
#   '小命',
#   '死不了',
#   '同党',
#   '团团围住'],
#  ['郭靖',
#   '陈玄风',
#   '全金发',
#   '一掷',
#   '这一掷',
#   '来拳',
#   '丈余',
#   '扑鼠',
#   '避敌',
#   '声彩',
#   '挥拳',
#   '暗地',
#   '筋斗',
#   '灵猫',
#   '翻出',
#   '一招',
#   '救人',
#   '俯身',
#   '接住',
#   '顺势'],
#  ['敌人',
#   '这铜尸',
#   '惨酷',
#   '黑风双',
#   '九阴',
#   '摧心',
#   '怪啸',
#   '左掌右',
#   '招招',
#   '爱妻',
#   '十指',
#   '尤甚',
#   '十之八九',
#   '越强',
#   '火候',
#   '抓人',
#   '白骨',
#   '死得',
#   '生性',
#   '伤人'],
#  ['南希仁',
#   '专向',
#   '分际',
#   '奇痛',
#   '五怪',
#   '韩宝驹',
#   '使开',
#   '地堂',
#   '鞭法',
#   '急攻',
#   '打挥',
#   '陈玄风',
#   '铜尸',
#   '猛向',
#   '怠忽',
#   '轮盘',
#   '进袭',
#   '滚进',
#   '下盘',
#   '后心'],
#  ['南希仁',
#   '手臂',
#   '擒拿法',
#   '义弟',
#   '数寸',
#   '眉睫',
#   '敌爪',
#   '急使',
#   '陈玄风',
#   '已触',
#   '较技',
#   '已伸',
#   '趋避',
#   '面门',
#   '脑骨',
#   '疾起',
#   '左猛',
#   '朱聪',
#   '如铁',
#   '铁板桥'],
#  ['撒下来',
#   '掩月',
#   '黄豆大',
#   '此际',
#   '伸手不见五指',
#   '雨点',
#   '荒山',
#   '霹雳',
#   '半空中',
#   '乌云',
#   '打了个',
#   '跟着',
#   '忽然'],
#  ['陈玄风',
#   '朱聪',
#   '两响',
#   '以力',
#   '碰力',
#   '已震断',
#   '南希仁',
#   '脱力',
#   '直跌',
#   '扼得',
#   '手肘',
#   '剧痛',
#   '左臂',
#   '前胸',
#   '喘气',
#   '咽喉',
#   '不由自主',
#   '胸口',
#   '手臂',
#   '为难'],
#  ['别做声', '韩宝驹', '七妹', '韩小莹', '几步', '大叫', '黑暗', '怎样', '大家'],
#  ['柯镇恶',
#   '暗叫',
#   '心下',
#   '甚奇',
#   '全金发',
#   '漆黑一团',
#   '二弟',
#   '老天',
#   '大喜',
#   '动静',
#   '此刻',
#   '不见',
#   '众人',
#   '问道',
#   '怎么',
#   '什么'],
#  ['凝气',
#   '齐扬',
#   '六枚',
#   '江南七怪',
#   '中三人',
#   '先动',
#   '柯镇恶',
#   '极灵',
#   '八九步',
#   '菱往',
#   '耳音',
#   '大雨倾盆',
#   '辨出',
#   '一败涂地',
#   '黑云',
#   '雨声',
#   '屏息',
#   '重伤',
#   '笼罩',
#   '左侧'],
#  ['陈玄风',
#   '柯镇恶',
#   '敌人',
#   '半成',
#   '宛似',
#   '双爪',
#   '六枚',
#   '刚觉',
#   '毒菱',
#   '纵起',
#   '身前',
#   '处舞成',
#   '猛向',
#   '一杖',
#   '中目',
#   '斗得',
#   '十余招',
#   '一团漆黑',
#   '瞬息之间',
#   '扑击'],
#  ['陈玄风',
#   '铁杖',
#   '三人',
#   '韩宝驹',
#   '韩小莹',
#   '全金发',
#   '柯镇恶',
#   '二三十招',
#   '但守',
#   '竟如过',
#   '连中',
#   '两杖',
#   '正自',
#   '众人',
#   '干着急',
#   '心中',
#   '系于',
#   '狂呼',
#   '怪叫',
#   '嗖嗖'],
#  ['电光',
#   '右手',
#   '铁杖',
#   '硬接',
#   '搭出',
#   '全金发',
#   '陈玄风',
#   '欺身',
#   '左肩',
#   '一杖',
#   '急探',
#   '虽隐',
#   '柯镇恶',
#   '霎时间',
#   '乘着',
#   '运气',
#   '胸口',
#   '向外',
#   '光亮',
#   '左手'],
#  ['柯镇恶',
#   '铁杖',
#   '身子',
#   '撒杖',
#   '陈玄风',
#   '哪肯',
#   '变爪',
#   '陡长',
#   '潜运',
#   '直跌',
#   '挥出',
#   '招招',
#   '怪啸',
#   '扯破',
#   '夺来',
#   '内力',
#   '轰轰',
#   '倏地',
#   '结结实实',
#   '绝技'],
#  ['铁杖',
#   '声中',
#   '两闪',
#   '韩宝驹',
#   '猛见',
#   '柯镇恶',
#   '茫如',
#   '这一惊',
#   '卷住',
#   '倏地',
#   '电光',
#   '飞去',
#   '非同小可',
#   '霹雳',
#   '金龙',
#   '正向',
#   '不觉',
#   '大哥'],
#  ['郭靖',
#   '陈玄风',
#   '现下取',
#   '发足',
#   '一绊',
#   '狗命',
#   '似是',
#   '俯身',
#   '抓起',
#   '忽地',
#   '脚下',
#   '那人',
#   '人体',
#   '却是',
#   '胖子'],
#  ['陈玄风',
#   '短剑',
#   '郭靖大',
#   '郭靖见',
#   '目射',
#   '凶光',
#   '大骇',
#   '插落',
#   '直没至',
#   '八寸',
#   '焦黄',
#   '肚脐',
#   '可怖',
#   '电光',
#   '小腹',
#   '之极',
#   '这一下',
#   '插入',
#   '拔出',
#   '腰间'],
#  ['武功',
#   '陈玄风',
#   '全然',
#   '练功夫',
#   '抓住',
#   '无匹',
#   '碰中',
#   '善泳',
#   '覆车',
#   '锋锐',
#   '幼童',
#   '兵刃',
#   '溺水',
#   '竟自',
#   '狂叫',
#   '肚脐',
#   '拳脚',
#   '毙命',
#   '小腹',
#   '短剑'],
#  ['郭靖挥', '地站', '六神无主', '糊里糊涂', '短剑', '张嘴', '出声', '一旁'],
#  ['梅超风',
#   '陈玄风',
#   '师妹',
#   '丈夫',
#   '长声',
#   '连跌',
#   '师哥',
#   '夫妻情',
#   '独个儿',
#   '舍不得你',
#   '孤苦伶仃',
#   '冲下来',
#   '毙命',
#   '筋斗',
#   '声道',
#   '惨叫',
#   '咬牙切齿',
#   '逃命',
#   '地道',
#   '报仇'],
#  ['丈夫',
#   '梅超风',
#   '你别',
#   '韩宝驹',
#   '韩小莹',
#   '全金发',
#   '攻上来',
#   '师哥',
#   '哀叫',
#   '气绝',
#   '舍不得你',
#   '微露',
#   '尸身',
#   '乘着',
#   '人形',
#   '放手',
#   '悲痛',
#   '出声',
#   '分辨',
#   '光芒'],
#  ['抗毒',
#   '梅超风',
#   '显是',
#   '上毒发',
#   '九阴',
#   '运功',
#   '已具',
#   '铁菱',
#   '之毒',
#   '自不死',
#   '攻近',
#   '三怪',
#   '反连',
#   '伤到',
#   '昏晕',
#   '相辅',
#   '内功',
#   '修习',
#   '遇险',
#   '内力'],
#  ['连攻',
#   '韩宝驹',
#   '三人合斗',
#   '江南七怪',
#   '鞭法',
#   '三鞭',
#   '梅超风',
#   '韩小莹',
#   '挺剑',
#   '疾刺',
#   '全金发',
#   '瞎眼',
#   '猛打',
#   '支持不住',
#   '蹒跚',
#   '威名',
#   '变幻',
#   '扫地',
#   '连环',
#   '婆娘'],
#  ['乱舞',
#   '漆黑一团',
#   '疾风',
#   '沙石',
#   '黑云',
#   '乱打',
#   '大作',
#   '卷起',
#   '得手',
#   '狂风',
#   '眼见',
#   '登时',
#   '三人',
#   '空中',
#   '眼前',
#   '突然'],
#  ['韩宝驹',
#   '梅超风',
#   '地下',
#   '大雨淋',
#   '郭靖',
#   '长鞭',
#   '纵开',
#   '身来',
#   '陈玄风',
#   '柯镇恶',
#   '朱聪',
#   '南希仁',
#   '张阿生',
#   '探上',
#   '稍息',
#   '小头',
#   '丝丝',
#   '黑云',
#   '跃起',
#   '湿透'],
#  ['猛击',
#   '全金发',
#   '三人忙',
#   '南希仁',
#   '折臂',
#   '柯镇恶',
#   '朱聪',
#   '以力',
#   '张阿生',
#   '连中',
#   '九阴',
#   '深湛',
#   '抗力',
#   '断骨',
#   '内功',
#   '垂危',
#   '内伤',
#   '未受',
#   '白骨',
#   '一拳'],
#  ['张阿生',
#   '儿女之情',
#   '六怪',
#   '韩小莹',
#   '五哥',
#   '深怀',
#   '好武',
#   '极淡',
#   '爪下',
#   '感且',
#   '气息奄奄',
#   '傻笑',
#   '咧开',
#   '嘻嘻哈哈',
#   '情意',
#   '表露',
#   '之极',
#   '豪迈',
#   '心痛',
#   '放声'],
#  ['张阿生',
#   '韩小莹',
#   '七妹',
#   '哭道',
#   '五哥',
#   '两下',
#   '胖脸',
#   '笑惯',
#   '屠牛大手',
#   '你作',
#   '大喜若狂',
#   '这生',
#   '这世',
#   '嘴合',
#   '不拢',
#   '意中人',
#   '配不上',
#   '轻抚',
#   '再嫁',
#   '微露'],
#  ['朱聪',
#   '郭靖',
#   '郭靖道',
#   '归天',
#   '磕头',
#   '师父',
#   '朱聪道',
#   '扑翻',
#   '张阿生',
#   '拜师',
#   '我们',
#   '咚咚',
#   '哽咽',
#   '快要',
#   '现今',
#   '想来',
#   '本事',
#   '眼中',
#   '泪水',
#   '不住'],
#  ['本事',
#   '张阿生',
#   '学武',
#   '只仗',
#   '牛力',
#   '贪懒',
#   '气若游丝',
#   '苦功',
#   '愚笨',
#   '侠义',
#   '天资',
#   '惨然',
#   '送命',
#   '几斤',
#   '用功',
#   '好孩子',
#   '为先',
#   '管不了',
#   '强忍',
#   '惨白'],
#  ['韩小莹',
#   '江南七怪',
#   '张阿生',
#   '而逝',
#   '傻笑',
#   '输给',
#   '凑到',
#   '闭目',
#   '好孩子',
#   '嘴边',
#   '几声',
#   '道士',
#   '决不会',
#   '耳朵',
#   '放心',
#   '咱们',
#   '说道'],
#  ['义结金兰',
#   '六怪',
#   '他七人',
#   '已情',
#   '寻郭靖',
#   '而远来',
#   '伤于',
#   '不悲',
#   '上掘',
#   '张阿生',
#   '异乡',
#   '惨死',
#   '一哭',
#   '六人',
#   '敌手',
#   '大漠',
#   '伏地',
#   '骨肉',
#   '荒山',
#   '尽情'],
#  ['记认', '待得立', '巨石', '已然', '大明', '天色', '作为'],
#  ['沙漠',
#   '六弟',
#   '全金发',
#   '韩宝驹',
#   '梅超风',
#   '追出',
#   '朱聪道',
#   '毒菱',
#   '已毒',
#   '发身',
#   '先送',
#   '三弟',
#   '七妹',
#   '些微',
#   '养伤',
#   '有伤',
#   '大漠',
#   '数里',
#   '服药',
#   '全然'],
#  ['张阿生', '洒泪', '而别', '点头称是', '坟墓', '余人']]

# %%
# # 求PA
# PA3 = {}
# PA4 = {}
# for i in b3:
#     PA3[i]=b3[i]/len(a3+a4)
# for i in b4:
#     PA4[i]=b4[i]/len(a3+a4)

# PA3

# text_chap=text_chap3+text_chap4

# %%
# test=[]
# ture=[]
# # 测试集
# d3={}
# for i in text_chap:
#     for j in i:
#         if j not in PA3.keys():
#             continue
#         d3[j]=PYA3[j]*PA3[j]/PY['train_chap3']

# %%
# test=[]
# ture=[4]*102
# for i in range(102):
#     if i<51:
#         ture[i]=3

# %%
# for i in d3:
#     if j not in d4.keys():
#         continue
#     if i<j:
#         test.append('3')
#     else:
#         test.append("4")
