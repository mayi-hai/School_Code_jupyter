# %%
import pandas as pd
# 载入语料射雕英雄传
raw1 = pd.read_csv("金庸-射雕英雄传txt精校版.txt",
                  names = ['txt'], sep ='aaa', encoding ="utf-8" ,engine='python')

# %%
import pandas as pd
# 载入语料天龙八部
raw2 = pd.read_csv("附件3_金庸-天龙八部txt精校版.txt",
                  names = ['txt'], sep ='aaa', encoding ="utf-8" ,engine='python')

# %%
chap1=raw1[1500:2000]
chap2=raw2[1500:2000]

# %%
import numpy as np
para1_data = np.array(chap1)#np.ndarray()
para1=para1_data.tolist()#list
para2_data = np.array(chap2)#np.ndarray()
para2=para2_data.tolist()#list

# %%
# 提取出射雕英雄传和天龙八部的500段存入一维数组sd和tl
from tkinter import _flatten
sd = list(_flatten(para1))
tl = list(_flatten(para2))

# %%
# 提取关键字
import jieba
import jieba.analyse
sd_g=[]
tl_g=[]
for w in sd:
    sd_g.append(jieba.analyse.extract_tags(w,20))
for w in tl:
    tl_g.append(jieba.analyse.extract_tags(w,20))
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\ADMINI~1\AppData\Local\Temp\jieba.cache
# Loading model cost 2.875 seconds.
# Prefix dict has been built succesfully.

# %%
sd_g
# Out:
# [['郭靖',
#   '未停',
#   '侯通海',
#   '连扫',
#   '用脚',
#   '雪坟',
#   '直没到',
#   '倒身',
#   '稍动',
#   '雪里',
#   '到庭',
#   '下脚',
#   '并拢',
#   '四尺',
#   '飞雪',
#   '堆成',
#   '埋入',
#   '三步',
#   '跃起',
#   '竖立'],
#  ['亲随',
#   '沙通天',
#   '完颜康',
#   '打实',
#   '侯通海',
#   '胸旁',
#   '雪踏得',
#   '侯爷',
#   '相烦',
#   '笑嘻嘻',
#   '结实',
#   '管家',
#   '身旁',
#   '各位',
#   '有趣',
#   '四周'],
#  ['侯通海',
#   '功夫',
#   '沙通天',
#   '练惯',
#   '潜泳',
#   '凝住',
#   '雪里',
#   '熟识',
#   '换气',
#   '称霸',
#   '水性',
#   '一顿饭',
#   '水底',
#   '水上',
#   '把头',
#   '讲究',
#   '呼吸',
#   '平日',
#   '水中',
#   '黄河'],
#  ['侯通海',
#   '一撑',
#   '从雪中',
#   '头来',
#   '鲤鱼打挺',
#   '良久',
#   '拔出',
#   '赞赏',
#   '直立',
#   '翻身',
#   '饮酒',
#   '双手',
#   '众人'],
#  ['侯通海',
#   '侯三爷',
#   '有雪',
#   '四爷',
#   '偏偏',
#   '头上',
#   '郭靖',
#   '雪融',
#   '浑号',
#   '归座',
#   '郭靖见',
#   '怒道',
#   '行三',
#   '可差',
#   '一爷',
#   '不抹',
#   '为水',
#   '他额',
#   '上分',
#   '他侯'],
#  ['雪堆',
#   '瓜子',
#   '草写',
#   '艺业',
#   '黄河',
#   '手力',
#   '王处一',
#   '沙通天',
#   '连弹',
#   '侯通海',
#   '所堆',
#   '嵌成',
#   '他弹',
#   '地嵌',
#   '成一字',
#   '准实',
#   '片刻之间',
#   '一颗颗',
#   '三丈',
#   '独霸'],
#  ['神技',
#   '彭连虎',
#   '这手',
#   '沙通天',
#   '弹出',
#   '瓜子',
#   '合伙',
#   '大哥',
#   '左掌',
#   '考较',
#   '做件',
#   '微晃',
#   '跃到',
#   '厅口',
#   '伸右',
#   '指弹',
#   '嵌成',
#   '借光',
#   '雪堆',
#   '咱们'],
#  ['彭连虎',
#   '沙通天',
#   '笑跃',
#   '归座',
#   '换作',
#   '欧阳克',
#   '欧阳公子',
#   '人开',
#   '露点',
#   '叫好声',
#   '有言在先',
#   '开眼界',
#   '见过世面',
#   '见怪',
#   '有损',
#   '做买卖',
#   '交情',
#   '这一下',
#   '旁人',
#   '威风'],
#  ['筷子',
#   '二十只',
#   '收起',
#   '插入',
#   '四盆',
#   '深妙',
#   '郭靖',
#   '王处一',
#   '欧阳克听',
#   '他语',
#   '震开',
#   '显些',
#   '正送',
#   '新筷',
#   '咸食',
#   '欧阳克',
#   '一撒',
#   '撒出',
#   '而布成',
#   '完颜康'],
#  ['王处一',
#   '白驼',
#   '山少主',
#   '灵智上人',
#   '参仙',
#   '瞧个',
#   '绝艺',
#   '苦思',
#   '老怪',
#   '好手',
#   '倒要',
#   '武林',
#   '图谋',
#   '陡然',
#   '已然',
#   '涉足',
#   '脱身',
#   '端的',
#   '之计',
#   '各人'],
#  ['梁子翁',
#   '燕青拳',
#   '筷子',
#   '雪地',
#   '之上',
#   '一路',
#   '侍仆',
#   '脱靴',
#   '回席',
#   '郭靖',
#   '数寸',
#   '侧弯',
#   '参仙',
#   '地站',
#   '左足',
#   '已落',
#   '欧阳克',
#   '二郎担山',
#   '巧打',
#   '跨虎'],
#  ['盆里',
#   '金盆',
#   '水气',
#   '洗手',
#   '各人',
#   '冒上',
#   '双手',
#   '王处一',
#   '众仆',
#   '中盛',
#   '灵智上人',
#   '显过',
#   '仍浸',
#   '愈盛',
#   '微声',
#   '酒筵',
#   '盆底',
#   '现下',
#   '一缕缕',
#   '斜眼'],
#  ['脉门',
#   '王处一',
#   '灵智上人',
#   '微侧',
#   '隔座',
#   '完颜康',
#   '穴道',
#   '沙通天',
#   '好生了得',
#   '金盆',
#   '内功',
#   '先下手为强',
#   '我非',
#   '稍纵即逝',
#   '集注',
#   '腕上',
#   '先发制人',
#   '提过',
#   '事不宜迟',
#   '出其不意'],
#  ['酒箭',
#   '酒壶',
#   '落入',
#   '酒杯',
#   '各人',
#   '各位',
#   '右手',
#   '提起',
#   '小王爷',
#   '杯内',
#   '一道',
#   '王处一',
#   '那人距',
#   '已空',
#   '斟来',
#   '空而降',
#   '齐杯',
#   '借花献佛',
#   '激射',
#   '酒水'],
#  ['斟酒',
#   '灵智上人',
#   '完颜康',
#   '一运劲',
#   '震碎',
#   '我众',
#   '敌寡',
#   '深湛',
#   '内功',
#   '投鼠忌器',
#   '心肺',
#   '眼睁睁',
#   '眼见',
#   '内脏',
#   '明明',
#   '左手',
#   '背上',
#   '右手',
#   '动手',
#   '立即'],
#  ['各位',
#   '贫道',
#   '小王爷',
#   '王处一',
#   '少年',
#   '郭靖',
#   '非亲非故',
#   '饮干',
#   '朗然',
#   '想求',
#   '若肯',
#   '小哥',
#   '薄面',
#   '无冤无仇',
#   '寻常百姓',
#   '金枝玉叶',
#   '侠义',
#   '骨气',
#   '默不作声',
#   '斟满'],
#  ['梁子翁', '王道', '爽快', '这笔', '生意', '这样'],
#  ['王处一',
#   '食言而肥',
#   '郭靖',
#   '罔顾',
#   '完颜康',
#   '登得',
#   '邪毒',
#   '点首',
#   '武林中',
#   '狠辣',
#   '后会有期',
#   '私底下',
#   '毫不迟疑',
#   '信义',
#   '威名',
#   '决计',
#   '成名',
#   '松开',
#   '旁人',
#   '干事'],
#  ['暗呼', '脸上无光', '滑脱', '竟自', '一尾', '鱼儿', '眼见', '无不', '可惜', '众人'],
#  ['叙叙',
#   '王处一',
#   '有暇',
#   '完颜康',
#   '教益',
#   '恭送',
#   '后辈',
#   '道长',
#   '定神',
#   '再见',
#   '含笑',
#   '了结',
#   '随时',
#   '起身',
#   '日子',
#   '出去',
#   '过来',
#   '咱们',
#   '说道',
#   '一声'],
#  ['王处一',
#   '灵智上人',
#   '手腕',
#   '佩服',
#   '精奥',
#   '右掌',
#   '变招',
#   '两人',
#   '忽道',
#   '双掌',
#   '双掌相',
#   '勾腕',
#   '强对',
#   '微变',
#   '后跃',
#   '满江湖',
#   '怒道',
#   '这姓',
#   '掌力',
#   '所震'],
#  ['郭靖', '王处一', '急步', '停留', '走出', '不敢'],
#  ['沙通天',
#   '彭连虎',
#   '有话',
#   '灵智上人',
#   '大亏',
#   '心下',
#   '失威',
#   '言而无信',
#   '再则',
#   '凛然',
#   '受挫',
#   '阻拦',
#   '以免',
#   '一则',
#   '上前',
#   '不肯',
#   '不再'],
#  ['王处一',
#   '有气没力',
#   '郭靖听',
#   '十余丈',
#   '病容',
#   '情状',
#   '道长',
#   '神采飞扬',
#   '脸色苍白',
#   '客店',
#   '踉跄',
#   '大不相同',
#   '适才',
#   '满面',
#   '快步',
#   '站立',
#   '王府',
#   '大惊',
#   '微弱',
#   '低声'],
#  ['郭靖',
#   '王处一',
#   '郭靖忙',
#   '身来',
#   '急奔',
#   '生恐',
#   '束手待毙',
#   '身受',
#   '低微',
#   '份儿',
#   '入内',
#   '客店',
#   '僻静',
#   '小店',
#   '对头',
#   '蹲下',
#   '寻到',
#   '会意',
#   '快步',
#   '重伤'],
#  ['王处一',
#   '满清水',
#   '尽往',
#   '屋陋',
#   '店房',
#   '郭靖道',
#   '渐弱',
#   '店堂',
#   '大缸',
#   '盛满',
#   '客店',
#   '闯进',
#   '人少',
#   '偏僻',
#   '好容易',
#   '不识',
#   '挥手',
#   '当即',
#   '背上',
#   '呼吸'],
#  ['店小二',
#   '放在',
#   '清水',
#   '银子',
#   '郭靖',
#   '王处一',
#   '郭靖忙',
#   '出房',
#   '店伴',
#   '几钱',
#   '分提',
#   '郭靖回',
#   '抱入',
#   '再命',
#   '浸到',
#   '缸内',
#   '大缸',
#   '一锭',
#   '柜上',
#   '头颈'],
#  ['王处一',
#   '清水',
#   '一缸',
#   '没事',
#   '功夫',
#   '见过',
#   '毒质',
#   '和尚',
#   '黑色',
#   '三缸',
#   '好毒',
#   '急呼',
#   '缓吸',
#   '略复',
#   '郭靖依',
#   '言换',
#   '化在',
#   '连换',
#   '郭靖放',
#   '喜慰'],
#  ['王处一',
#   '未净',
#   '清毒',
#   '抓药',
#   '柜上',
#   '笔砚',
#   '天色已晚',
#   '无碍',
#   '药铺',
#   '残废',
#   '受累',
#   '毒气',
#   '药方',
#   '已然',
#   '关门',
#   '明儿',
#   '内脏',
#   '终身',
#   '一早',
#   '不免'],
#  ['方子',
#   '药铺',
#   '郭靖',
#   '药方',
#   '四味',
#   '血竭',
#   '郭靖拿',
#   '有家',
#   '递到',
#   '店伴',
#   '刚巧',
#   '没货',
#   '搜买',
#   '七八家',
#   '几味',
#   '田七',
#   '没药',
#   '第二句',
#   '金字招牌',
#   '熊胆'],
#  ['王处一',
#   '郭靖',
#   '后要',
#   '竟差',
#   '抄得',
#   '郭靖心',
#   '几味',
#   '药都',
#   '惨然',
#   '歹毒',
#   '药铺',
#   '垂头丧气',
#   '客店',
#   '恍然',
#   '放声大哭',
#   '干干净净',
#   '全城',
#   '用心',
#   '王府',
#   '当真'],
#  ['王处一',
#   '生固',
#   '击着',
#   '知其雄',
#   '知其',
#   '白兮守',
#   '知荣守辱',
#   '损之又损',
#   '郭靖收',
#   '用起',
#   '功来',
#   '未见得',
#   '盘膝',
#   '纵声',
#   '无极',
#   '有生',
#   '床沿',
#   '凡人',
#   '欣然',
#   '怔怔'],
#  ['市镇',
#   '郭靖',
#   '买光',
#   '黄蓉',
#   '忽想',
#   '甚喜',
#   '郭大爷',
#   '郭靖心',
#   '见纸',
#   '亲启',
#   '叫化',
#   '谁给我',
#   '神似',
#   '药都',
#   '一张白纸',
#   '附近',
#   '封皮',
#   '店小二',
#   '形貌',
#   '撕开'],
#  ['送来', '郭靖心', '这信', '闲汉', '怎知', '街边', '店小二', '问道', '这里', '一个'],
#  ['王处一',
#   '郭靖回',
#   '进店',
#   '地下活动',
#   '买药',
#   '道长',
#   '市镇',
#   '何尝',
#   '手足',
#   '想不到',
#   '一层',
#   '不必',
#   '想到',
#   '附近',
#   '说道',
#   '他们',
#   '我们'],
#  ['商量',
#   '郭靖',
#   '王处一',
#   '聪明伶俐',
#   '死心',
#   '一试',
#   '决意',
#   '贤弟',
#   '弟子',
#   '心想',
#   '见面',
#   '不肯',
#   '朋友',
#   '马上',
#   '说道',
#   '一下'],
#  ['王处一',
#   '黄蓉',
#   '生死之交',
#   '身法',
#   '这人',
#   '不经一事',
#   '不长一智',
#   '郭靖',
#   '夸说',
#   '侯通海',
#   '总透',
#   '郭靖道',
#   '你定',
#   '郭靖心',
#   '少年人',
#   '情状',
#   '孩子',
#   '道长',
#   '半分',
#   '戏弄'],
#  ['雪花',
#   '郭靖',
#   '城来',
#   '人踪',
#   '甚寒',
#   '都融',
#   '雪蕊',
#   '冰花',
#   '飞雪',
#   '扑面',
#   '梅树',
#   '皎洁',
#   '愈大',
#   '白茫茫',
#   '一排排',
#   '放眼',
#   '更显',
#   '出得',
#   '闪动',
#   '点点'],
#  ['郭靖',
#   '贤弟',
#   '忽喇喇',
#   '四望',
#   '水鸟',
#   '先回去',
#   '放声',
#   '湖边',
#   '两声',
#   '应声',
#   '人影',
#   '焦急',
#   '声响',
#   '大叫',
#   '莫非',
#   '不来',
#   '心想',
#   '或许',
#   '两只',
#   '不见'],
#  ['黄蓉',
#   '王处一',
#   '之象',
#   '寒梅',
#   '雪景',
#   '见惯',
#   '大雪纷飞',
#   '平湖',
#   '挂念',
#   '大漠',
#   '稀奇',
#   '放在心上',
#   '塞外',
#   '黄沙',
#   '伤势',
#   '湖边',
#   '无心',
#   '毫不',
#   '欣赏',
#   '从小'],
#  ['西首',
#   '半斤八两',
#   '先逃',
#   '便会输',
#   '一人道',
#   '四鬼',
#   '郭靖手',
#   '软鞭',
#   '张去',
#   '粗声',
#   '师哥',
#   '荡秋千',
#   '摔了一跤',
#   '另一人',
#   '探头',
#   '好奇心',
#   '空荡荡',
#   '半空中',
#   '胆小',
#   '不见得'],
#  ['郭靖',
#   '练轻功',
#   '钱青健',
#   '说道',
#   '空中',
#   '空中飞人',
#   '臭小子',
#   '明刀明',
#   '枪地',
#   '这小',
#   '人吊',
#   '四鬼',
#   '料知',
#   '黄蓉必',
#   '怒道',
#   '不生',
#   '怒极',
#   '飞脚',
#   '马青雄',
#   '叫化'],
#  ['一叶扁舟',
#   '郭靖笑',
#   '郭靖转',
#   '中飘',
#   '树丛',
#   '水声',
#   '响动',
#   '过头',
#   '一笑',
#   '身后',
#   '轻轻',
#   '说道',
#   '有人',
#   '突然',
#   '这里',
#   '出来'],
#  ['荡舟',
#   '女子',
#   '笑面',
#   '灿然',
#   '迎人',
#   '容色',
#   '持桨',
#   '上束',
#   '细带',
#   '郭靖见',
#   '那船',
#   '荡近',
#   '方当韶龄',
#   '胜雪',
#   '绝丽',
#   '娇美',
#   '生光',
#   '十五六岁',
#   '披肩',
#   '船尾'],
#  ['郭靖', '只觉', '生花', '转开', '耀眼', '几步', '缓缓', '不敢'],
#  ['船摇到', '上船', '岸边', '少女', '哥哥'],
#  ['郭靖',
#   '郭靖猛',
#   '头来',
#   '生春',
#   '如痴似',
#   '笑靥',
#   '飘动',
#   '风中',
#   '衣襟',
#   '少女',
#   '转过',
#   '一惊',
#   '轻轻',
#   '双手',
#   '只见',
#   '眼睛'],
#  ['一百两',
#   '黄蓉',
#   '郭靖听',
#   '四鬼',
#   '帮个',
#   '八百两',
#   '叫化',
#   '褴褛',
#   '四百两',
#   '叫嚷',
#   '割断',
#   '依稀',
#   '仙女',
#   '怎么',
#   '肮脏',
#   '绳索',
#   '小姑娘',
#   '少女',
#   '一共',
#   '每人'],
#  ['贤弟',
#   '郭靖',
#   '黄蓉',
#   '看时',
#   '果见',
#   '口鼻确',
#   '黄蓉嫣然',
#   '我本',
#   '双足点',
#   '船去',
#   '四鬼',
#   '赏格',
#   '不睬',
#   '说道',
#   '跃上',
#   '定神',
#   '眉目',
#   '理睬',
#   '上船',
#   '兀自'],
#  ['点心',
#   '黄蓉',
#   '细点',
#   '郭靖',
#   '王处一',
#   '荡到',
#   '赏雪',
#   '四鬼',
#   '郭靖心',
#   '神渐',
#   '黄蓉笑',
#   '作蓉儿',
#   '郭靖忽',
#   '完颜康',
#   '求药',
#   '抛入',
#   '黄蓉伸',
#   '已远',
#   '水化',
#   '吃不得'],
#  ['郭靖',
#   '泪水',
#   '点心',
#   '慢慢',
#   '黄蓉',
#   '郭靖见',
#   '渐红',
#   '黄蓉道',
#   '我生',
#   '压烂',
#   '回眸一笑',
#   '放在',
#   '一块',
#   '下来',
#   '哪知',
#   '擦拭',
#   '几颗',
#   '记着',
#   '眼圈',
#   '手帕'],
#  ['郭靖', '只觉', '特异', '情怀', '贤弟', '举动', '丝毫', '要紧', '女儿', '这种', '这个', '什么'],
#  ['黄蓉笑', '我要', '是蓉儿', '贤弟', '不是', '要紧', '什么'],
#  ['仙女',
#   '郭靖道',
#   '好看',
#   '雪山',
#   '郭靖',
#   '黄蓉侧',
#   '郭靖叹',
#   '黄蓉笑',
#   '命活',
#   '黄蓉奇',
#   '叫化',
#   '发痴',
#   '扮成',
#   '冻死',
#   '真像',
#   '微微一笑',
#   '干吗',
#   '顶上',
#   '整天',
#   '老人家'],
#  ['郭靖',
#   '丑八怪',
#   '黄蓉',
#   '黄蓉笑',
#   '急道',
#   '正正经经',
#   '叫化',
#   '发痴',
#   '那有',
#   '一红',
#   '那才',
#   '稀罕',
#   '讨好',
#   '地道',
#   '真心',
#   '还是',
#   '好看',
#   '点点头',
#   '片刻',
#   '衣服'],
#  ['王处一',
#   '我唱个',
#   '郭靖道',
#   '伤药',
#   '买药',
#   '曲儿',
#   '王道',
#   '简略',
#   '买不到',
#   '极好',
#   '明儿',
#   '好不好',
#   '王府',
#   '受伤',
#   '心情',
#   '情形',
#   '咱们',
#   '这时'],
#  ['买药',
#   '郭靖',
#   '小红马',
#   '黄蓉',
#   '黄蓉道',
#   '我本',
#   '进奔出',
#   '一家家',
#   '药铺',
#   '满头大汗',
#   '住所',
#   '贤弟',
#   '知道',
#   '干什么',
#   '身后',
#   '奇怪',
#   '否则',
#   '想起',
#   '说道',
#   '原来'],
#  ['小红马',
#   '王处一',
#   '黄蓉正',
#   '色道',
#   '郭靖听',
#   '惶急',
#   '不谋而合',
#   '所料',
#   '真会',
#   '市镇',
#   '贤弟',
#   '试试',
#   '未必',
#   '难道',
#   '第三',
#   '第二',
#   '第一',
#   '附近',
#   '只是',
#   '不是'],
#  ['黄蓉微', '现下', '唱曲'],
#  ['侧过', '舟边', '清声', '自舌底', '斜倚', '一缕', '吐出', '微微'],
#  ['霜寒',
#   '玉肌',
#   '万花',
#   '难学',
#   '正护',
#   '云轻',
#   '冰犹薄',
#   '溪奁',
#   '含香',
#   '龙绡',
#   '笑嫣然',
#   '转盼',
#   '羞落',
#   '瘦弱',
#   '重重',
#   '东风'],
#  ['粉蝶儿',
#   '未觉',
#   '只解',
#   '寻花觅柳',
#   '南枝',
#   '开遍',
#   '画角',
#   '数声',
#   '雪后',
#   '旧约',
#   '瑶池',
#   '楼阁',
#   '水边',
#   '冷淡',
#   '何在',
#   '园林',
#   '寂寞',
#   '黄昏',
#   '伤心'],
#  ['郭靖',
#   '王处一',
#   '全然不解',
#   '意酣魂',
#   '神驰',
#   '娇柔',
#   '低回',
#   '不自禁',
#   '清音',
#   '地心',
#   '词义',
#   '温存',
#   '缠绵',
#   '婉转',
#   '伤势',
#   '出世',
#   '歌声',
#   '光景',
#   '从未',
#   '一番'],
#  ['辛大人',
#   '黄蓉',
#   '既终',
#   '瑞鹤仙',
#   '郭靖道',
#   '黄蓉道',
#   '岳爷爷',
#   '现下',
#   '雪后',
#   '歌儿',
#   '辛弃疾',
#   '爱民',
#   '做得好',
#   '爹爹',
#   '奸臣',
#   '沦陷',
#   '一曲',
#   '好听',
#   '失地',
#   '金人'],
#  ['残废',
#   '郭靖',
#   '黄蓉道',
#   '常听',
#   '家国',
#   '之痛',
#   '儿救',
#   '郭靖道',
#   '清毒',
#   '大害',
#   '已现',
#   '虐杀',
#   '怒色',
#   '咱们',
#   '慢慢说',
#   '王道',
#   '自小',
#   '残暴',
#   '尽早',
#   '深切'],
#  ['都远胜',
#   '黄蓉',
#   '黄蓉微',
#   '我包',
#   '郭靖听',
#   '无别法',
#   '四鬼',
#   '侯通海',
#   '怎样',
#   '十拿九稳',
#   '言下之意',
#   '计谋',
#   '戏弄',
#   '胸怀',
#   '再者',
#   '武功',
#   '暂且',
#   '放宽',
#   '树上',
#   '大笑'],
#  ['郭靖道',
#   '真是',
#   '暮色四合',
#   '郭靖',
#   '黄蓉',
#   '黄蓉道',
#   '朦朦胧胧',
#   '爹爹',
#   '化成',
#   '伸出手',
#   '手掌',
#   '握住',
#   '眼见',
#   '梅花',
#   '白雪',
#   '现今',
#   '欢喜',
#   '湖水',
#   '低声',
#   '不怕'],
#  ['围住',
#   '郭靖',
#   '黄蓉轻',
#   '轻靠',
#   '只觉',
#   '黄蓉身',
#   '两人握',
#   '甜香',
#   '清香',
#   '梅花',
#   '胸前',
#   '湖水',
#   '天地',
#   '着手',
#   '一股',
#   '发出',
#   '身体',
#   '不再',
#   '说话',
#   '整个'],
#  ['黄蓉道',
#   '郭靖道',
#   '王府',
#   '咱们',
#   '良久良久',
#   '黄蓉叹',
#   '郭靖喜',
#   '搜去',
#   '郭靖吓',
#   '那去',
#   '几味',
#   '哪里',
#   '拿药',
#   '送命',
#   '药铺',
#   '份儿',
#   '王道',
#   '可惜',
#   '口气',
#   '不错'],
#  ['黄蓉道',
#   '郭靖',
#   '郭靖道',
#   '送命',
#   '王道',
#   '总而言之',
#   '残废',
#   '忍心',
#   '热血',
#   '上冲',
#   '伤势',
#   '不过',
#   '厉害',
#   '说不定',
#   '不出',
#   '却说',
#   '道理',
#   '难道',
#   '还要',
#   '为什么'],
#  ['黄蓉',
#   '体惜',
#   '郭靖心',
#   '中一震',
#   '沙通天',
#   '彭连虎',
#   '人殊',
#   '自怜',
#   '拿药',
#   '独个儿',
#   '诸般',
#   '昂然',
#   '狂喜',
#   '顿觉',
#   '难事',
#   '爱惜',
#   '危难',
#   '百倍',
#   '可要',
#   '咱俩'],
#  ['四鬼',
#   '黄河',
#   '四个',
#   '郭靖忽',
#   '然记',
#   '黄蓉格',
#   '格一笑',
#   '冻不坏',
#   '饿不死',
#   '刚烈',
#   '梅林',
#   '雄健',
#   '小舟',
#   '停步',
#   '高雅',
#   '回城',
#   '半路',
#   '兀自',
#   '上岸',
#   '岸边'],
#  ['破犁', '第九回', '铁枪'],
#  ['而进',
#   '黄蓉柔',
#   '郭靖伏',
#   '只觉',
#   '越墙',
#   '黄二人',
#   '轻身',
#   '墙脚',
#   '声道',
#   '院内',
#   '后院',
#   '察看',
#   '开心',
#   '王府',
#   '称赞',
#   '功夫',
#   '说不出',
#   '动静',
#   '来到'],
#  ['小王爷',
#   '先一人',
#   '王妃',
#   '另一人',
#   '姑娘',
#   '这么',
#   '小心',
#   '气袋',
#   '臭美',
#   '一人道',
#   '虽美',
#   '一避',
#   '色迷迷',
#   '转口',
#   '娘胎',
#   '吃了亏',
#   '住口',
#   '谈笑',
#   '砍掉',
#   '风尘'],
#  ['穆姑娘',
#   '人家',
#   '不该',
#   '不肯',
#   '郭靖寻',
#   '完颜康',
#   '比武招亲',
#   '花鞋',
#   '意中人',
#   '强逼',
#   '美貌',
#   '难怪',
#   '难道',
#   '为什么',
#   '原来',
#   '如此',
#   '因此',
#   '起来',
#   '已经'],
#  ['食盒',
#   '两人',
#   '风灯',
#   '那提',
#   '要关',
#   '送菜',
#   '人家',
#   '芳心',
#   '饿坏',
#   '小帽',
#   '美人儿',
#   '仆役',
#   '谈笑',
#   '这么晚',
#   '巴巴',
#   '走远',
#   '青衣',
#   '体贴',
#   '风流',
#   '一个'],
#  ['美人',
#   '女人',
#   '非去',
#   '郭靖',
#   '黄蓉',
#   '郭靖道',
#   '盗药',
#   '黄蓉道',
#   '郭靖心',
#   '比一比',
#   '孩子气',
#   '举步',
#   '先看',
#   '仆役',
#   '美貌',
#   '好奇心',
#   '亲眼',
#   '偏要',
#   '看一看',
#   '古怪'],
#  ['亲兵',
#   '黄蓉',
#   '郭靖闪',
#   '两仆',
#   '屋前',
#   '大屋',
#   '兵刃',
#   '曲曲折折',
#   '打开门',
#   '仆役',
#   '好大',
#   '把守',
#   '手执',
#   '地走了',
#   '看守',
#   '园林',
#   '王府',
#   '望见',
#   '几句话',
#   '一会'],
#  ['两仆',
#   '石子',
#   '郭靖',
#   '黄蓉',
#   '风灯',
#   '打灭',
#   '门去',
#   '只道',
#   '火绒',
#   '跌下',
#   '火石',
#   '挤进',
#   '小门',
#   '点亮',
#   '咒骂',
#   '捡起',
#   '一扇',
#   '纵身',
#   '天井',
#   '知觉'],
#  ['栅栏',
#   '郭靖',
#   '黄蓉',
#   '铁条',
#   '铁笼',
#   '可辨',
#   '一男一女',
#   '猛兽',
#   '依稀',
#   '一条条',
#   '监禁',
#   '编成',
#   '悄悄',
#   '跟随',
#   '后面',
#   '两人',
#   '只见',
#   '里面',
#   '一般'],
#  ['郭靖',
#   '完颜康',
#   '满腹疑团',
#   '大奇',
#   '妙龄少女',
#   '苍然',
#   '进栅',
#   '穆易',
#   '穆念慈',
#   '垂首',
#   '怒容',
#   '大惑不解',
#   '须发',
#   '烛光',
#   '照耀',
#   '不爱',
#   '蜡烛',
#   '身旁',
#   '点燃',
#   '仆人'],
#  ['一盆',
#   '点心',
#   '盆送',
#   '进栅去',
#   '穆易',
#   '我落',
#   '假惺惺',
#   '食盒',
#   '酒菜',
#   '你们',
#   '圈套',
#   '讨好',
#   '仆人',
#   '两名',
#   '取出',
#   '出来'],
#  ['小王爷', '骂声', '您好', '齐声', '亲兵', '外面', '说道'],
#  ['完颜康',
#   '郭靖',
#   '黄蓉',
#   '互望',
#   '穆老',
#   '两仆',
#   '狗腿子',
#   '惹怒',
#   '一腿',
#   '滚出去',
#   '伸舌头',
#   '俯首',
#   '鬼脸',
#   '入内',
#   '呵斥',
#   '门边',
#   '快步',
#   '做个',
#   '仆人',
#   '打断'],
#  ['完颜康',
#   '穆易',
#   '穆易怒',
#   '两位',
#   '吃人不吐骨头',
#   '般关',
#   '做府',
#   '穆念慈',
#   '实在',
#   '下情',
#   '和颜悦色',
#   '怒骂',
#   '相告',
#   '涵养',
#   '过意不去',
#   '对不住',
#   '父女',
#   '见得',
#   '三岁',
#   '这里'],
#  ['完颜康',
#   '穆易',
#   '令爱',
#   '父王',
#   '闲言闲语',
#   '不生',
#   '穆念慈',
#   '俯得',
#   '养好',
#   '完姻',
#   '品貌',
#   '严旨切',
#   '一冷',
#   '迎亲',
#   '两全其美',
#   '家教',
#   '舍下',
#   '或者',
#   '王爵',
#   '草莽'],
#  ['完颜康',
#   '将来',
#   '以务恳',
#   '穆易怒',
#   '邀出',
#   '令爱',
#   '风风光光',
#   '做媒',
#   '正大光明',
#   '老前辈',
#   '闯祸',
#   '朝里',
#   '父王',
#   '偷偷摸摸',
#   '严守',
#   '顽皮',
#   '圣上',
#   '女孩儿',
#   '婚事',
#   '决不能'],
#  ['穆易',
#   '母亲',
#   '忽变',
#   '说个',
#   '完颜康',
#   '从铁栅',
#   '花言巧语',
#   '酒壶',
#   '斩钉截铁',
#   '理睬',
#   '微微一笑',
#   '抓起',
#   '地道',
#   '怎能',
#   '当面',
#   '决不',
#   '见面',
#   '脸色',
#   '清楚',
#   '咱们'],
#  ['穆念慈',
#   '完颜康',
#   '正自',
#   '芳心',
#   '窃喜',
#   '比武',
#   '动怒',
#   '合情合理',
#   '无故',
#   '倾注',
#   '忽见',
#   '伤心',
#   '惊讶',
#   '一颗',
#   '不禁',
#   '早已',
#   '父亲',
#   '身上',
#   '突然',
#   '之后'],
#  ['完颜康', '袍袖', '卷住', '酒壶', '翻过', '而出', '伸手', '桌上', '转身'],
#  ['黄蓉',
#   '郭靖听',
#   '完颜康',
#   '哪料',
#   '穆易',
#   '长身',
#   '从门里',
#   '扯扯',
#   '翻脸',
#   '劝劝',
#   '苦衷',
#   '衣袖',
#   '周到',
#   '法子',
#   '正想',
#   '确有',
#   '心想',
#   '所说',
#   '出去',
#   '忽然'],
#  ['完颜康',
#   '兔子',
#   '仆人',
#   '举起手来',
#   '后腿',
#   '折断',
#   '两声',
#   '快步',
#   '怀中',
#   '拿来',
#   '两条',
#   '接过',
#   '手里',
#   '放在',
#   '一只',
#   '一个'],
#  ['郭靖', '黄蓉甚', '花样', '奇怪', '远远', '跟着', '随后', '不知', '什么'],
#  ['小屋',
#   '乌瓦白',
#   '郭靖',
#   '黄蓉',
#   '居屋',
#   '甚觉',
#   '完颜康',
#   '板门',
#   '豪奢',
#   '竹篱',
#   '寻常百姓',
#   '富丽',
#   '不意',
#   '三间',
#   '绕过',
#   '乡下',
#   '诧异',
#   '王府',
#   '没见',
#   '推开'],
#  ['两人悄步',
#   '俯眼',
#   '完颜康',
#   '地应',
#   '窗缝',
#   '向里',
#   '哪知',
#   '诡秘',
#   '屋后',
#   '特异',
#   '张望',
#   '必有',
#   '心想',
#   '所在',
#   '行动',
#   '里面',
#   '女人',
#   '来到',
#   '声音',
#   '一声'],
#  ['郭靖',
#   '黄蓉',
#   '女子',
#   '姿容秀美',
#   '完颜康',
#   '支颐',
#   '不施',
#   '粗衣',
#   '黄蓉心',
#   '穆姑娘',
#   '不以为奇',
#   '跟蓉儿',
#   '穿些',
#   '闹着玩儿',
#   '冷宫',
#   '赵王',
#   '破破烂烂',
#   '粗布',
#   '内室',
#   '布衫'],
#  ['完颜康',
#   '女子',
#   '好好',
#   '脚趾头',
#   '手道',
#   '没少',
#   '全在',
#   '口气道',
#   '撒娇',
#   '胡闹',
#   '不得了',
#   '拉住',
#   '风声',
#   '身旁',
#   '不是',
#   '舒服',
#   '神情',
#   '鼻子',
#   '师父',
#   '没什么'],
#  ['完颜康',
#   '道长',
#   '师父',
#   '我师叔',
#   '偏不认',
#   '我见',
#   '起人来',
#   '打岔',
#   '真叫人',
#   '没法子',
#   '他杀',
#   '师弟',
#   '发怒',
#   '眼珠',
#   '样儿',
#   '笑了起来',
#   '该是',
#   '道士',
#   '向着',
#   '说来'],
#  ['杀人',
#   '完颜康',
#   '奇道',
#   '忘啦',
#   '神驰',
#   '很久很久',
#   '烛光',
#   '地道',
#   '干吗',
#   '缓缓',
#   '远处',
#   '师父',
#   '抬头',
#   '差不多',
#   '女子',
#   '哪里',
#   '以前',
#   '似乎',
#   '怎么'],
#  ['王道士',
#   '完颜康',
#   '比武招亲',
#   '那姓',
#   '他肯',
#   '铁牢里',
#   '答允',
#   '哪里找',
#   '得意洋洋',
#   '上门来',
#   '父女',
#   '爹爹',
#   '应承',
#   '问过',
#   '地道',
#   '了结',
#   '差人',
#   '追问',
#   '老实',
#   '怎么办'],
#  ['郭靖',
#   '心想',
#   '别见怪',
#   '完颜康',
#   '穆老',
#   '不上',
#   '愠道',
#   '那成',
#   '奸恶',
#   '人家',
#   '赔罪',
#   '送些',
#   '说得过去',
#   '戏弄',
#   '好意',
#   '不以为然',
#   '闺女',
#   '幸亏',
#   '竟是',
#   '暗暗'],
#  ['完颜康',
#   '他们',
#   '骗回',
#   '怎不传进',
#   '耳里',
#   '急道',
#   '要关',
#   '死心塌地',
#   '没完没了',
#   '稀罕',
#   '好话',
#   '宣扬',
#   '说些',
#   '哈哈大笑',
#   '江湖',
#   '二十年',
#   '家乡',
#   '一世',
#   '在外',
#   '在家'],
#  ['窗格子',
#   '郭靖怒',
#   '伸掌',
#   '突觉',
#   '轻声道',
#   '怒喝',
#   '滑腻',
#   '捏住',
#   '发脾气',
#   '张口',
#   '按住',
#   '手腕',
#   '手掌',
#   '柔软',
#   '耳边',
#   '右手',
#   '嘴唇',
#   '随即',
#   '一只',
#   '声音'],
#  ['郭靖',
#   '黄蓉微微',
#   '完颜康',
#   '那姓',
#   '得紧',
#   '再关',
#   '奸猾',
#   '不听话',
#   '上钩',
#   '老儿',
#   '醒悟',
#   '转头',
#   '张望',
#   '登时',
#   '一笑',
#   '不肯',
#   '几天',
#   '一时'],
#  ['完颜康',
#   '女子',
#   '我见',
#   '爹常',
#   '我择',
#   '我准',
#   '品貌',
#   '穷人家',
#   '低三下四',
#   '完颜',
#   '家世',
#   '显贵',
#   '瞧不起',
#   '亲事',
#   '怎么',
#   '驸马',
#   '宗室',
#   '当真',
#   '江湖',
#   '公主'],
#  ['完颜康',
#   '缺德事',
#   '那姓',
#   '三句',
#   '露出马脚',
#   '骗人',
#   '撒谎',
#   '一桩',
#   '笑嘻嘻',
#   '圈子',
#   '当面',
#   '笑话',
#   '就算',
#   '女子',
#   '不让',
#   '不了',
#   '相信',
#   '说明',
#   '几个',
#   '不会'],
#  ['之物',
#   '郭靖',
#   '黄蓉',
#   '桌凳',
#   '粗木',
#   '所制',
#   '生了锈',
#   '铁枪',
#   '床帐',
#   '犁头',
#   '贵为',
#   '无一不是',
#   '称奇',
#   '纺车',
#   '王妃',
#   '摆设',
#   '农家',
#   '用具',
#   '纺纱',
#   '简陋'],
#  ['兔子',
#   '完颜康',
#   '那兔儿',
#   '女子',
#   '衣内',
#   '治治',
#   '刀圭',
#   '伤药',
#   '治伤',
#   '小白兔',
#   '险些儿',
#   '受了伤',
#   '吱吱',
#   '好孩子',
#   '后腿',
#   '两声',
#   '两下',
#   '胸前',
#   '行走',
#   '怀里'],
#  ['心慈',
#   '郭靖怒',
#   '母亲',
#   '怎可',
#   '腿骨',
#   '权谋',
#   '火上',
#   '玩弄',
#   '亲生',
#   '折断',
#   '医治',
#   '兔子',
#   '坏事',
#   '无心',
#   '理会',
#   '自己',
#   '心想',
#   '好好',
#   '一只',
#   '如此'],
#  ['蹑足',
#   '黄蓉靠',
#   '郭靖身',
#   '忽觉',
#   '完颜康',
#   '找药',
#   '郭靖道',
#   '黄蓉摇',
#   '头道',
#   '惊觉',
#   '走远',
#   '可知',
#   '不理',
#   '颤抖',
#   '发作',
#   '全身',
#   '哪里',
#   '咱们',
#   '说道',
#   '出来'],
#  ['郭靖心',
#   '沙通天',
#   '缓地',
#   '一阵',
#   '开言',
#   '亲亲',
#   '哪里找',
#   '大祸临头',
#   '小曲',
#   '闪动',
#   '手提',
#   '偌大',
#   '灯笼',
#   '王府',
#   '惊动',
#   '走近',
#   '灯光',
#   '正要',
#   '嘴里',
#   '商量'],
#  ['小王爷',
#   '黄蓉',
#   '简管家',
#   '那人',
#   '干什么',
#   '郭靖待',
#   '树后',
#   '翻处',
#   '黄蓉道',
#   '我要',
#   '闪入',
#   '蛾眉',
#   '魂不附体',
#   '收着',
#   '喉头',
#   '分水',
#   '明晃晃',
#   '一柄',
#   '结结巴巴',
#   '那好'],
#  ['简管家',
#   '黄蓉',
#   '手腕',
#   '咽喉',
#   '帽子',
#   '左手',
#   '窒闷',
#   '奇痛',
#   '惨厉',
#   '扭断',
#   '抓落',
#   '钢刺',
#   '只觉',
#   '黄蓉右',
#   '手扯',
#   '一拉一',
#   '臂骨',
#   '这声',
#   '昏晕',
#   '蛾眉'],
#  ['小王爷',
#   '黄蓉',
#   '简管家',
#   '低声',
#   '郭靖',
#   '装假',
#   '血竭',
#   '扭断',
#   '万料',
#   '胁下',
#   '那人醒',
#   '你求',
#   '摔断了',
#   '田七',
#   '没药',
#   '摔下来',
#   '熊胆',
#   '毒辣',
#   '娇滴滴',
#   '痛得'],
#  ['黄蓉',
#   '王妃',
#   '快去',
#   '小王爷',
#   '那管家',
#   '扭断',
#   '如装',
#   '简管家',
#   '几味',
#   '咬紧牙',
#   '一句',
#   '寒噤',
#   '一抓',
#   '忍痛',
#   '眼珠子',
#   '奔往',
#   '挖出',
#   '指甲',
#   '眼皮',
#   '住处'],
#  ['完颜康',
#   '简管家',
#   '王妃',
#   '小王爷',
#   '一迭连声',
#   '温言',
#   '黄蓉教',
#   '药梁',
#   '赏张',
#   '谢赏',
#   '药好治伤',
#   '荡来荡去',
#   '笔墨纸砚',
#   '东拉西扯',
#   '痛得',
#   '哭丧着脸',
#   '字条',
#   '右臂',
#   '白纸',
#   '皱眉'],
#  ['简管家',
#   '黄蓉',
#   '几步',
#   '冰寒',
#   '郭靖',
#   '已架',
#   '颈头',
#   '黄蓉道',
#   '后领',
#   '断成两截',
#   '直冒',
#   '众仆见',
#   '彻骨',
#   '支持不住',
#   '查问',
#   '利刃',
#   '一扭',
#   '仆役',
#   '一柄',
#   '踉跄'],
#  ['简管家',
#   '香雪厅',
#   '梁子翁',
#   '所住',
#   '馆门',
#   '郭靖见',
#   '他胁',
#   '宴客',
#   '反锁',
#   '馆舍',
#   '蹒跚',
#   '一瞧',
#   '仆役',
#   '并肩',
#   '王爷',
#   '伸手',
#   '脚步',
#   '三人',
#   '来到',
#   '过去'],
#  ['简管家',
#   '卫士',
#   '郭靖',
#   '黄蓉',
#   '字条',
#   '小王爷',
#   '檐头',
#   '离厅',
#   '觉胁',
#   '穴道',
#   '丛后',
#   '香雪厅',
#   '中向里',
#   '数十步',
#   '点中',
#   '黄二人',
#   '窗缝',
#   '宴客',
#   '酸麻',
#   '攀住'],
#  ['郭靖',
#   '桌边',
#   '一张',
#   '诸人',
#   '同席',
#   '白驼',
#   '山少主',
#   '欧阳克',
#   '沙通天',
#   '侯通海',
#   '参仙',
#   '梁子翁',
#   '人屠',
#   '彭连虎',
#   '金国六',
#   '完颜洪烈',
#   '灵智上人',
#   '脸如',
#   '微张',
#   '毡毯'],
#  ['梁子翁',
#   '小王爷',
#   '简管家',
#   '完颜洪烈',
#   '字条',
#   '递给',
#   '梁公',
#   '完颜康',
#   '各拿五钱',
#   '瞧着办',
#   '五味',
#   '亲笔',
#   '所写',
#   '青衣',
#   '童子',
#   '推门',
#   '管家',
#   '药材',
#   '王爷',
#   '送来'],
#  ['郭靖',
#   '暗叫',
#   '简管家',
#   '黄蓉耳',
#   '边道',
#   '得紧',
#   '黄蓉笑',
#   '只觉',
#   '柔发',
#   '踊身',
#   '黄蓉忙',
#   '双足',
#   '放落',
#   '这往',
#   '初涉',
#   '好险',
#   '脸上',
#   '自愧',
#   '钩住',
#   '出毛病'],
#  ['那小童',
#   '郭靖',
#   '黄蓉',
#   '简管家',
#   '使个',
#   '倒卷',
#   '中白衫',
#   '微动',
#   '十余丈',
#   '百合花',
#   '珠帘',
#   '盛开',
#   '正向',
#   '张望',
#   '一朵',
#   '黑夜',
#   '回过头来',
#   '清风',
#   '犹如',
#   '后面'],
#  ['黄蓉',
#   '郭靖',
#   '彭连虎',
#   '侧头',
#   '附耳',
#   '四射',
#   '厅里',
#   '窥探',
#   '身形',
#   '目送',
#   '察看',
#   '倾听',
#   '各人',
#   '发觉',
#   '黑暗',
#   '到处',
#   '回头',
#   '目光',
#   '这才',
#   '并未'],
#  ['人道',
#   '王处一',
#   '黄蓉',
#   '极响',
#   '灵智上人',
#   '这一掌',
#   '落个',
#   '如电',
#   '彭连虎',
#   '横加',
#   '有所为',
#   '身材矮小',
#   '有意无意',
#   '沙哑',
#   '残废',
#   '插手',
#   '不死',
#   '张望',
#   '嗓子',
#   '无意'],
#  ['真七子',
#   '浪得虚名',
#   '灵智上人',
#   '秘刀',
#   '全算折',
#   '欧阳公子',
#   '半斤八两',
#   '欧阳克',
#   '落个',
#   '只须',
#   '粗厚',
#   '清朗',
#   '贴金',
#   '静养',
#   '吃了亏',
#   '上人',
#   '老衲',
#   '五指',
#   '丧命',
#   '该当'],
#  ['完颜洪烈',
#   '大金国',
#   '五位',
#   '哈哈',
#   '各位',
#   '令叔',
#   '帮主',
#   '言下',
#   '邀到',
#   '之福',
#   '黄蓉心',
#   '灵智上人',
#   '欧阳公子',
#   '彭寨主',
#   '狮子搏兔',
#   '拔刀相助',
#   '远道而来',
#   '真传',
#   '赵王',
#   '大驾'],
#  ['完颜洪烈',
#   '效劳',
#   '小王',
#   '王爷',
#   '各位',
#   '独霸一方',
#   '梁子翁',
#   '有负',
#   '彭连虎',
#   '于卑',
#   '相瞒',
#   '荒疏',
#   '重托',
#   '大金',
#   '老脸',
#   '分庭抗礼',
#   '推心置腹',
#   '自大',
#   '信得过',
#   '无光'],
#  ['严守',
#   '半句',
#   '婉转',
#   '泄漏',
#   '会意',
#   '务必',
#   '各人',
#   '王爷',
#   '几句话',
#   '虽说',
#   '所说',
#   '秘密',
#   '放心',
#   '其实',
#   '的话',
#   '这里',
#   '不能',
#   '他们'],
#  ['完颜洪烈',
#   '重聘',
#   '相请',
#   '相询',
#   '头等大事',
#   '金银珠宝',
#   '为了',
#   '若非',
#   '不提',
#   '偌大',
#   '何事',
#   '机密',
#   '各人',
#   '好奇',
#   '个个',
#   '揭开',
#   '力气',
#   '不便',
#   '致使',
#   '决不'],
#  ['完颜洪烈',
#   '赵官儿',
#   '徽宗',
#   '金兵',
#   '皇帝',
#   '宋朝',
#   '兵威',
#   '之盛',
#   '黄蓉心',
#   '欧阳公子',
#   '金国王爷',
#   '大宋',
#   '我大',
#   '精将',
#   '本可',
#   '梁子翁',
#   '示下',
#   '钦宗',
#   '自吹自擂',
#   '统一天下'],
#  ['岳飞',
#   '金元帅',
#   '完颜洪烈',
#   '我大',
#   '善会',
#   '非众位',
#   '大金国',
#   '授命',
#   '不自量力',
#   '吃败仗',
#   '元气大伤',
#   '大金',
#   '讳言',
#   '皆知',
#   '口气道',
#   '雄心勃勃',
#   '小王',
#   '秦桧',
#   '害死',
#   '南征'],
#  ['攻城掠地',
#   '吾辈',
#   '冲锋陷阵',
#   '其意',
#   '面面相觑',
#   '刺杀',
#   '各人',
#   '元帅',
#   '南朝',
#   '不明',
#   '大将',
#   '所长',
#   '难道',
#   '我们'],
#  ['岳飞',
#   '狱中',
#   '这人',
#   '宋江山',
#   '秘要',
#   '精忠报国',
#   '完颜洪烈',
#   '微颤',
#   '旧档',
#   '给关',
#   '之望',
#   '地写',
#   '要知',
#   '造起',
#   '辞句',
#   '勇悍',
#   '朝廷',
#   '详详细细',
#   '善战',
#   '反来'],
#  ['阁外', '黄蓉', '悬身', '聚精会神', '奇异', '个个', '喝酒', '故事', '众人', '一个'],
#  ['四首',
#   '岳飞',
#   '完颜洪烈',
#   '大金',
#   '贺圣朝',
#   '齐天乐',
#   '乱写',
#   '奴儿',
#   '不叶',
#   '才大如海',
#   '词收',
#   '秘档',
#   '竟藏',
#   '解明',
#   '词须',
#   '地串',
#   '词中',
#   '习他',
#   '虽苦',
#   '先倒'],
#  ['完颜洪烈',
#   '用兵如神',
#   '大金国',
#   '易如反掌',
#   '一统天下',
#   '学得',
#   '岳飞',
#   '兵法',
#   '这部',
#   '打仗',
#   '厉害',
#   '确实',
#   '咱们',
#   '只要',
#   '不是'],
#  ['赵王', '盗墓贼', '恍然大悟', '我们', '众人', '原来'],
#  ['岳飞',
#   '遗书',
#   '坟墓',
#   '各位',
#   '这部',
#   '大豪杰',
#   '王本来',
#   '完颜洪烈',
#   '续道',
#   '大金仇寇',
#   '人相钦',
#   '众安',
#   '翻检',
#   '精忠',
#   '祠庙',
#   '密探',
#   '神武',
#   '另外',
#   '桥边',
#   '宋孝宗'],
#  ['众人', '藏书', '逐一', '望去', '急于', '眼光', '地点', '说出', '这里'],
#  ['小王',
#   '宋人',
#   '遗物',
#   '敬若神明',
#   '手到拿来',
#   '书取',
#   '奇材',
#   '武林中',
#   '能之士',
#   '一等一',
#   '弄巧成拙',
#   '气运',
#   '咱们',
#   '搬动',
#   '加意',
#   '不敢',
#   '哪知',
#   '先得',
#   '郑重其事',
#   '轻举妄动'],
#  ['遗物',
#   '完颜洪烈',
#   '事说',
#   '难到',
#   '极处',
#   '之极',
#   '非同小可',
#   '本领',
#   '固然',
#   '所在',
#   '这件',
#   '看来',
#   '容易',
#   '然而',
#   '原来',
#   '不过',
#   '因此'],
#  ['梁子翁',
#   '青肿',
#   '厅门',
#   '一人冲',
#   '奔到',
#   '看时',
#   '青衣',
#   '童子',
#   '去取',
#   '面目',
#   '正说',
#   '推开',
#   '师父',
#   '众人',
#   '却是',
#   '进来',
#   '面前',
#   '突然',
#   '那个',
#   '这里'],
#  ['童子',
#   '简管家',
#   '青衣',
#   '郭靖',
#   '仍托',
#   '胁下',
#   '既防',
#   '过舍',
#   '梁子翁',
#   '所住',
#   '支持不住',
#   '馆舍',
#   '点亮',
#   '跌倒',
#   '去取',
#   '通风',
#   '蜡烛',
#   '示意',
#   '左手',
#   '开门'],
#  ['那小童',
#   '郭靖',
#   '冲鼻',
#   '便觉',
#   '药气',
#   '瓶儿',
#   '钵儿',
#   '梁子翁',
#   '客中',
#   '简管家',
#   '调弄',
#   '放满',
#   '罐儿',
#   '熟习',
#   '丹药',
#   '五味',
#   '诸般',
#   '药性',
#   '包了',
#   '踏进'],
#  ['简管家',
#   '郭靖',
#   '出房',
#   '门闩',
#   '转身',
#   '那小童',
#   '五包',
#   '那门',
#   '推之不开',
#   '抛入',
#   '房旁',
#   '双掌',
#   '立断',
#   '梁子翁',
#   '性喜',
#   '颚骨',
#   '居处',
#   '下颚',
#   '内力',
#   '扬手'],
#  ['童子',
#   '昏晕',
#   '黄蓉',
#   '郭靖回',
#   '提气',
#   '后领',
#   '抓落',
#   '风响',
#   '一挫',
#   '郭靖心',
#   '招招',
#   '分筋',
#   '错骨手',
#   '连中',
#   '郭靖乘',
#   '势直',
#   '上击',
#   '郭靖提',
#   '拨入',
#   '回进'],
#  ['瓶罐',
#   '每样',
#   '那童儿',
#   '郭靖',
#   '我且',
#   '罐药',
#   '取过',
#   '简管家',
#   '一急',
#   '包得',
#   '刚才',
#   '取药',
#   '拿些',
#   '怎知',
#   '暗骂',
#   '五味',
#   '弯弯曲曲',
#   '王道',
#   '一叠',
#   '白纸'],
#  ['竹篓',
#   '心下',
#   '身来',
#   '一撞',
#   '横跌',
#   '猛向',
#   '大蛇',
#   '如血',
#   '药包',
#   '药瓶',
#   '手肘',
#   '翻倒',
#   '呼噜',
#   '大功告成',
#   '蹿出',
#   '殷红',
#   '好容易',
#   '盖子',
#   '蓦地',
#   '提防'],
#  ['后跃开',
#   '郭靖大',
#   '那蛇',
#   '有小碗',
#   '其长',
#   '最怪',
#   '忽伸',
#   '忽缩',
#   '蛇口',
#   '蛇头',
#   '半身',
#   '朱红',
#   '分叉',
#   '通体',
#   '摇动',
#   '粗细',
#   '舌头',
#   '几何',
#   '伸出',
#   '不住'],
#  ['蛇虫',
#   '本少',
#   '奇蛇',
#   '受震',
#   '突觉',
#   '伸臂',
#   '急跃想',
#   '夺门而出',
#   '苦寒',
#   '漆黑一团',
#   '急步',
#   '缚住',
#   '烛台',
#   '动弹不得',
#   '右臂',
#   '朱红',
#   '一紧',
#   '桌边',
#   '不脱',
#   '背心'],
#  ['左手',
#   '知已',
#   '叉住',
#   '郭靖',
#   '金刀',
#   '郭靖心',
#   '所赐',
#   '药气',
#   '那蛇',
#   '伸舌来',
#   '杀蛇',
#   '那蛇力',
#   '抽刀',
#   '余暇',
#   '脸上',
#   '大蛇',
#   '蛇头',
#   '腥味',
#   '伸过来',
#   '猛力'],
#  ['胸口',
#   '郭靖挺',
#   '运内',
#   '蛇身',
#   '缠得',
#   '郭靖左',
#   '手渐',
#   '发恶',
#   '一松',
#   '蛇口',
#   '大蛇',
#   '酸麻',
#   '喷出来',
#   '撑持',
#   '神智',
#   '难闻',
#   '之极',
#   '腿脚',
#   '外力',
#   '张口'],
#  ['童子',
#   '黄蓉',
#   '防敌',
#   '郭靖击',
#   '郭靖相',
#   '身来',
#   '香雪厅',
#   '地向',
#   '梁子翁',
#   '心下',
#   '雁落',
#   '平沙',
#   '但厅',
#   '完颜洪烈',
#   '黄蓉落',
#   '虽轻',
#   '彭连虎',
#   '窗缝',
#   '回头见',
#   '漆黑一团'],
#  ['黄蓉', '梁子翁', '喝问', '身形', '去路', '晃动', '挡住', '首先', '什么'],
#  ['黄蓉见',
#   '于己',
#   '远胜',
#   '厅里',
#   '老儿',
#   '便知',
#   '开得',
#   '武功',
#   '一跃',
#   '一枝',
#   '微微一笑',
#   '好不好',
#   '高手',
#   '梅花',
#   '别说',
#   '对付',
#   '一人',
#   '不了',
#   '说道',
#   '这里'],
#  ['黄蓉',
#   '梁子翁',
#   '厅外',
#   '如珠',
#   '千金小姐',
#   '谢谢您',
#   '郡主',
#   '绝伦',
#   '衣饰',
#   '笑语',
#   '秀美',
#   '华贵',
#   '老爷子',
#   '料想',
#   '跃起',
#   '纵身',
#   '一枝',
#   '含笑',
#   '梅花',
#   '王府'],
#  ['彭连虎',
#   '完颜洪烈',
#   '姑娘',
#   '一招',
#   '王爷',
#   '机警过人',
#   '黄蓉转',
#   '身要',
#   '黄蓉面',
#   '巧扣',
#   '便来',
#   '伸近',
#   '黄蓉身',
#   '抓向',
#   '黄蓉本',
#   '以谋',
#   '这位',
#   '慢走',
#   '拦在',
#   '五指'],
#  ['扣起',
#   '黄蓉微微',
#   '已自',
#   '挥出',
#   '三指略',
#   '退避',
#   '已极',
#   '拇指',
#   '食指',
#   '美妙',
#   '一枝',
#   '兰花',
#   '余下',
#   '姿势',
#   '右手',
#   '伸出',
#   '不及',
#   '手指',
#   '一惊'],
#  ['出招',
#   '兰花',
#   '曲池',
#   '行若无事',
#   '变招',
#   '大奇',
#   '黄蓉',
#   '小臂',
#   '闲逸',
#   '彭连虎',
#   '只感',
#   '一麻',
#   '疾缩',
#   '穴道',
#   '认穴',
#   '极准',
#   '拂穴',
#   '拂穴手',
#   '字诀',
#   '狠辣'],
#  ['彭连虎',
#   '黄蓉',
#   '诸人',
#   '黄蓉笑',
#   '竟不答',
#   '这枝',
#   '尊师',
#   '贵姓',
#   '哪一位',
#   '旁观',
#   '来头',
#   '狐疑',
#   '问话',
#   '梅花',
#   '无不',
#   '惊讶',
#   '出手',
#   '姑娘',
#   '众人',
#   '不知'],
#  ['侯通海', '彭大哥', '黄蓉笑', '厉声', '听见', '什么'],
#  ['黄蓉',
#   '彭连虎',
#   '曾见',
#   '侯通海',
#   '这小嘴',
#   '微扁',
#   '那脏',
#   '戏弄',
#   '老侯',
#   '鄙夷',
#   '笑嘻嘻',
#   '神态',
#   '小子',
#   '认得',
#   '想起',
#   '姑娘',
#   '这位',
#   '原来',
#   '昨日',
#   '突然'],
#  ['侯通海',
#   '黄蓉',
#   '臭小子',
#   '迷藏',
#   '彭连虎',
#   '日里',
#   '黄蓉望',
#   '黄蓉时',
#   '虽改',
#   '前张',
#   '一扑',
#   '冲口而出',
#   '现下',
#   '闪避',
#   '女装',
#   '呆呆',
#   '猛扑',
#   '咒骂',
#   '愕然',
#   '双臂'],
#  ['沙通天',
#   '左手',
#   '黄蓉',
#   '抢前',
#   '黄蓉右',
#   '疾起',
#   '身形',
#   '龙王',
#   '晃动',
#   '指点',
#   '两眼',
#   '喝道',
#   '右手',
#   '伸出',
#   '抓住',
#   '哪里'],
#  ['沙通天',
#   '不要脸',
#   '欺侮',
#   '黄蓉',
#   '黄蓉道',
#   '一愕',
#   '以大压',
#   '进厅',
#   '黄蓉知',
#   '门去',
#   '踏进',
#   '成名',
#   '前辈',
#   '挣脱',
#   '放开',
#   '没能',
#   '喝道',
#   '双手',
#   '只得',
#   '不行'],
#  ['须得先',
#   '黄蓉',
#   '臭小子',
#   '侯通海',
#   '怒道',
#   '彭连虎',
#   '先问',
#   '料知',
#   '再作',
#   '衣饰',
#   '问明',
#   '来头',
#   '定夺',
#   '人品',
#   '武功',
#   '必是',
#   '大有',
#   '动手',
#   '上前',
#   '师父'],
#  ['黄蓉',
#   '侯通海',
#   '举拳',
#   '一逃',
#   '最怕',
#   '当头',
#   '闪过',
#   '真要',
#   '打下',
#   '逃跑',
#   '理会',
#   '动手',
#   '不许',
#   '难道',
#   '问道',
#   '还有'],
#  ['黄蓉道',
#   '侯通海',
#   '怒道',
#   '一只',
#   '比武',
#   '敢不敢',
#   '装满',
#   '桌上',
#   '双手',
#   '头上',
#   '说道',
#   '这样',
#   '什么'],
#  ['额头',
#   '生角',
#   '黄蓉',
#   '臭小子',
#   '侯通海',
#   '怒道',
#   '上生',
#   '瘤子',
#   '冤仇',
#   '失手',
#   '对得起',
#   '胡说八道',
#   '环顾',
#   '打伤',
#   '踏上',
#   '瞧瞧',
#   '一步',
#   '这位',
#   '众人',
#   '要是'],
#  ['功夫',
#   '泼出来',
#   '黄蓉',
#   '去理',
#   '仍脸',
#   '梁子翁',
#   '折花',
#   '彭连虎',
#   '发招',
#   '沙通天',
#   '侯通海',
#   '迭加',
#   '唯今',
#   '以小卖',
#   '轻身',
#   '比比',
#   '擒拿',
#   '三碗',
#   '三头',
#   '占上风'],
#  ['侯通海', '怒道', '沉猛', '力道', '劈面', '如风', '闹着玩', '来势', '一拳'],
#  ['比划', '黄蓉', '避过', '三碗', '空手', '闪身', '咱们', '身上'],
#  ['一碗',
#   '黄蓉',
#   '侯通海',
#   '沙通天',
#   '连激',
#   '酒往',
#   '微曲',
#   '猛往',
#   '不加思索',
#   '左腿',
#   '威名',
#   '右腿',
#   '气恼',
#   '远不如',
#   '成名',
#   '一放',
#   '师兄',
#   '两倍',
#   '有余',
#   '江湖'],
#  ['黄蓉',
#   '侯通海',
#   '连踢',
#   '黄蓉笑',
#   '满厅',
#   '数腿',
#   '稳然',
#   '垂地',
#   '前趋',
#   '扎得',
#   '连施',
#   '巧招',
#   '想以',
#   '避过',
#   '轻功',
#   '碰翻',
#   '以退为进',
#   '足底',
#   '手肘',
#   '相斗'],
#  ['五味',
#   '不关我事',
#   '血竭',
#   '王处一',
#   '梁子翁',
#   '珍药',
#   '奇宝',
#   '盗药',
#   '派人来',
#   '田七',
#   '没药',
#   '记挂',
#   '顺手牵羊',
#   '心道',
#   '熊胆',
#   '取去',
#   '老侯',
#   '理他',
#   '一长',
#   '奸细'],
#  ['郭靖',
#   '那蛇',
#   '大蛇',
#   '张口',
#   '大口',
#   '再也',
#   '渐渐',
#   '地下',
#   '眼眉',
#   '忽觉',
#   '料知',
#   '伸近',
#   '脸边',
#   '蛇身',
#   '运劲',
#   '往蛇',
#   '受痛',
#   '缠得',
#   '郭靖连',
#   '蓦觉'],
#  ['父女',
#   '监禁',
#   '药材',
#   '各包',
#   '郭靖',
#   '只觉',
#   '按上',
#   '穆易',
#   '完颜康',
#   '出得门',
#   '径往',
#   '穆氏',
#   '铁牢',
#   '火烫',
#   '酸麻',
#   '筋疲力尽',
#   '烘烤',
#   '有救',
#   '热烘烘',
#   '辨明'],
#  ['亲兵',
#   '郭靖',
#   '牢外',
#   '甚严',
#   '奔到',
#   '铁牢',
#   '牢旁',
#   '我来',
#   '老前辈',
#   '跃上',
#   '巡查',
#   '混入',
#   '侧耳',
#   '摸到',
#   '看管',
#   '把守',
#   '兵丁',
#   '倾听',
#   '巡逻',
#   '屋顶'],
#  ['郭靖', '穆易', '郭靖道', '尊驾', '晚辈', '诧异', '大为', '问道'],
#  ['郭靖',
#   '名字',
#   '穆易',
#   '郭靖道',
#   '父亲',
#   '小王爷',
#   '各事',
#   '人静',
#   '两字',
#   '啸天',
#   '朱聪教',
#   '耳鼓',
#   '人声嘈杂',
#   '先父',
#   '纷至沓来',
#   '昨日',
#   '晚辈',
#   '幼时',
#   '声道',
#   '依稀'],
#  ['郭靖',
#   '穆易',
#   '从铁栅',
#   '只觉',
#   '只手',
#   '那小王爷',
#   '轻声道',
#   '几滴',
#   '利刃',
#   '斩断',
#   '热泪盈眶',
#   '紧紧抓住',
#   '存心',
#   '相救',
#   '前辈',
#   '手腕',
#   '伸出手',
#   '不得了',
#   '欺骗',
#   '手臂'],
#  ['姓李', '我妈', '穆易', '你娘', '郭靖大', '故世', '活着', '蒙古', '是不是', '怎么', '还是', '知道'],
#  ['穆易',
#   '郭靖',
#   '义兄',
#   '哽住',
#   '郭靖道',
#   '我手',
#   '斩锁',
#   '他手',
#   '郭靖奇',
#   '八拜之交',
#   '比武招亲',
#   '郭靖听',
#   '出此下策',
#   '故世',
#   '奇珍异宝',
#   '先父',
#   '抛头露面',
#   '似乎',
#   '情义',
#   '喉头'],
#  ['牛家村',
#   '一杆',
#   '妻子',
#   '官兵',
#   '十五六里',
#   '宛似',
#   '义兄',
#   '包氏',
#   '穆易',
#   '杨铁心',
#   '极重',
#   '次晨醒',
#   '反扣',
#   '心下',
#   '自凉',
#   '当夕',
#   '倚壁',
#   '失了',
#   '旧侣',
#   '满积'],
#  ['曲三',
#   '岳家',
#   '曲三是',
#   '牛家村',
#   '郭杨',
#   '后受',
#   '绝艺',
#   '身负',
#   '异人',
#   '反锁',
#   '援手',
#   '探问',
#   '一无',
#   '或能',
#   '音讯',
#   '十多天',
#   '村人',
#   '噩耗',
#   '相熟',
#   '小女儿'],
#  ['杨铁心',
#   '女婴',
#   '找寻',
#   '农家',
#   '远投',
#   '染疫',
#   '郭啸天',
#   '之妻',
#   '荷塘',
#   '祸不单行',
#   '欲哭无泪',
#   '未久',
#   '责无旁贷',
#   '义女',
#   '数天',
#   '四口',
#   '那家',
#   '出世',
#   '四下',
#   '瘟疫'],
#  ['义女',
#   '郭靖',
#   '杨铁心',
#   '郭啸天',
#   '比武招亲',
#   '人海茫茫',
#   '义兄',
#   '变名',
#   '穆易',
#   '穆念慈',
#   '已死',
#   '有后',
#   '短戟',
#   '实盼',
#   '郭靖相',
#   '自照',
#   '怎遇',
#   '东奔西走',
#   '浪迹江湖',
#   '镔铁'],
#  ['心淡',
#   '笃实',
#   '义兄',
#   '尴尬事',
#   '杨铁心',
#   '为婿',
#   '完颜康',
#   '如沸',
#   '五内',
#   '郭家',
#   '过得去',
#   '义女',
#   '年青',
#   '不知',
#   '仗义',
#   '大半年',
#   '心满意足',
#   '人品',
#   '激荡',
#   '心怀'],
#  ['穆念慈',
#   '郭靖先',
#   '出去',
#   '叙旧',
#   '口边',
#   '出言',
#   '旁听',
#   '转念',
#   '刚到',
#   '谈论',
#   '只怕',
#   '提醒',
#   '慢慢',
#   '永远',
#   '两人',
#   '回去',
#   '忽然',
#   '一句',
#   '不到',
#   '这一'],
#  ['王妃',
#   '队长',
#   '小王爷',
#   '郭靖',
#   '开锁',
#   '门缝',
#   '亲兵',
#   '金刀',
#   '温言',
#   '出栅',
#   '完颜康',
#   '应道',
#   '杨铁心',
#   '两锭',
#   '出去',
#   '透进',
#   '纱灯',
#   '牢门',
#   '后藏',
#   '赵王'],
#  ['杨铁心', '不接', '凝视', '目不转睛', '双目', '银子'],
#  ['别见怪',
#   '轻声道',
#   '歉疚',
#   '料想',
#   '王妃',
#   '气恼',
#   '实是',
#   '古怪',
#   '得罪',
#   '对不起',
#   '神色',
#   '两位',
#   '不好',
#   '儿子',
#   '心中',
#   '今日'],
#  ['杨铁心',
#   '揣入',
#   '如不闻',
#   '瞪目',
#   '王妃',
#   '大踏步',
#   '野人',
#   '拜谢',
#   '不语',
#   '队长',
#   '半晌',
#   '规矩',
#   '怀里',
#   '伸手',
#   '接过',
#   '银子',
#   '女儿',
#   '走出'],
#  ['小王爷',
#   '郭靖',
#   '王处一',
#   '弯角',
#   '杨铁心',
#   '出府',
#   '香雪厅',
#   '寻黄蓉',
#   '郭靖忙',
#   '郭靖伸',
#   '臂格开',
#   '完颜康',
#   '送药',
#   '偷听',
#   '跃出',
#   '两盏',
#   '掩映',
#   '王妃',
#   '一程',
#   '父女'],
#  ['放走',
#   '父女',
#   '小王爷',
#   '不顾大局',
#   '郭靖',
#   '两人',
#   '之命',
#   '杨铁心',
#   '完颜康',
#   '对质',
#   '抵赖',
#   '心软',
#   '王妃',
#   '岂知',
#   '飞报',
#   '撞见',
#   '截住',
#   '一味',
#   '队长',
#   '查看'],
#  ['郭靖',
#   '急欲',
#   '出府',
#   '亟盼',
#   '总让',
#   '完颜康',
#   '狠辣',
#   '送药',
#   '杀人灭口',
#   '腰刀',
#   '叫苦',
#   '夺路',
#   '不意',
#   '白日',
#   '截住',
#   '相助',
#   '拔出',
#   '相遇',
#   '黑夜',
#   '了结'],
#  ['侯通海',
#   '只得',
#   '黄蓉',
#   '梁子翁',
#   '要败',
#   '倏变',
#   '黄蓉双',
#   '手齐振',
#   '挺昂',
#   '赶蟾',
#   '双掌',
#   '有碗',
#   '发招',
#   '黄蓉右',
#   '举臂',
#   '挡格',
#   '双腕',
#   '泼得',
#   '八步',
#   '掠去'],
#  ['欧阳克',
#   '疾退',
#   '黄蓉拔',
#   '地落',
#   '之顶',
#   '以巧',
#   '沙通天',
#   '暗叫一声',
#   '溅出',
#   '云鬓',
#   '端端正正',
#   '三碗',
#   '怒目',
#   '喝彩',
#   '两碗',
#   '在意',
#   '取胜',
#   '落下',
#   '一碗',
#   '一点儿'],
#  ['黄蓉', '侯通海', '一刮', '比过', '害臊', '通红', '满脸', '手指', '脸上'],
#  ['沙通天',
#   '黄蓉笑',
#   '已移',
#   '诡计多端',
#   '当路',
#   '跨步',
#   '现下',
#   '师弟',
#   '小丫头',
#   '可要',
#   '明儿',
#   '失利',
#   '弯曲',
#   '拦住',
#   '师父',
#   '身子',
#   '门口',
#   '怎样',
#   '到底',
#   '一声'],
#  ['沙通天',
#   '黄蓉刚',
#   '移形',
#   '暗惊',
#   '微皱',
#   '黄蓉秀',
#   '眉微扬',
#   '换位',
#   '动弹不得',
#   '闯进',
#   '龙王',
#   '这一下',
#   '手腕',
#   '问话',
#   '立时',
#   '干吗',
#   '眉头',
#   '王府',
#   '门下',
#   '功夫'],
#  ['老伯伯',
#   '黄蓉眼',
#   '见厅',
#   '梁子翁',
#   '当路',
#   '数尺',
#   '闯关',
#   '万难',
#   '相距',
#   '拦住',
#   '正要',
#   '身后',
#   '不让',
#   '回家',
#   '走出',
#   '不过',
#   '就是'],
#  ['王问',
#   '梁子翁',
#   '柔声',
#   '黄蓉格',
#   '不爱答',
#   '沙通天',
#   '诉苦',
#   '沙龙',
#   '可要',
#   '这般',
#   '一笑',
#   '不让',
#   '好好',
#   '回答',
#   '说道'],
#  ['沙通天',
#   '沙龙',
#   '黄蓉笑',
#   '黄蓉道',
#   '黄蓉乘',
#   '带风',
#   '肩旁',
#   '冷冷道',
#   '迅捷',
#   '一言为定',
#   '身法',
#   '分心',
#   '纵身',
#   '钻出',
#   '大丈夫',
#   '衣襟',
#   '小丫头',
#   '一指',
#   '本事',
#   '拦住'],
#  ['沙通天',
#   '秃头',
#   '对准',
#   '后退',
#   '收脚',
#   '忽左忽右',
#   '黄蓉',
#   '黄蓉刚',
#   '发能',
#   '虽急',
#   '前趋',
#   '连闯',
#   '油光晶亮',
#   '尺许',
#   '去势',
#   '鼻血',
#   '自己',
#   '身法',
#   '俯下',
#   '鼻尖'],
#  ['梁子翁',
#   '身子',
#   '王是',
#   '疾往',
#   '晃亮',
#   '蛇血',
#   '吸空',
#   '废于',
#   '血腥气',
#   '再试',
#   '药罐',
#   '大蛇',
#   '药瓶',
#   '乱成一团',
#   '一夕',
#   '凉了半截',
#   '干瘪',
#   '满屋子',
#   '加快脚步',
#   '认输'],
#  ['药方',
#   '十余张',
#   '修练',
#   '参茸',
#   '化净',
#   '药物',
#   '衣囊',
#   '益寿',
#   '功德圆满',
#   '吸去',
#   '参仙',
#   '参客',
#   '中得',
#   '武学秘',
#   '照法',
#   '药养',
#   '易筋',
#   '壮体',
#   '照方',
#   '又费'],
#  ['郭靖',
#   '疾奔',
#   '他定',
#   '未凝',
#   '出房',
#   '如焚',
#   '完颜康',
#   '衣上',
#   '高树',
#   '未久',
#   '恶斗',
#   '近身',
#   '腥气',
#   '跃上',
#   '翻翻',
#   '定神',
#   '眺望',
#   '仇人',
#   '怒火',
#   '四下'],
#  ['完颜康',
#   '这番',
#   '难受',
#   '无比',
#   '体内',
#   '郭靖',
#   '异常',
#   '十余招',
#   '只觉',
#   '中拳',
#   '两拳',
#   '滚水',
#   '欲裂',
#   '奇痒',
#   '蛇毒',
#   '相形之下',
#   '热得',
#   '交手',
#   '惊惧',
#   '火球'],
#  ['郭靖',
#   '梁子翁',
#   '王处一',
#   '小贼',
#   '宝蛇',
#   '这宝',
#   '举拳',
#   '古方',
#   '毛头小子',
#   '坏东西',
#   '飞步',
#   '蛇毒',
#   '怒喝',
#   '十之八九',
#   '高人',
#   '害人',
#   '指使',
#   '隐秘',
#   '毒蛇',
#   '决不能'],
#  ['郭靖',
#   '梁子翁',
#   '宝血',
#   '脉门',
#   '吸回',
#   '药气',
#   '陡生',
#   '双掌',
#   '数招',
#   '一勾',
#   '恶念',
#   '药力',
#   '按倒',
#   '更佳',
#   '蟒蛇',
#   '喝干',
#   '翻飞',
#   '未可知',
#   '张口',
#   '闻到'],
#  ['沙通天',
#   '手到拿来',
#   '黄蓉连',
#   '总让',
#   '然见',
#   '完颜洪烈',
#   '不论如何',
#   '轻功',
#   '易地',
#   '露一手',
#   '赵王',
#   '上乘',
#   '旁观',
#   '如要',
#   '快捷',
#   '数次',
#   '挡住',
#   '乘机',
#   '轻轻'],
#  ['沙通天',
#   '爹爹',
#   '黄蓉道',
#   '外入',
#   '功夫',
#   '进门',
#   '本事',
#   '出门',
#   '外面',
#   '黄蓉',
#   '黄蓉叹',
#   '只教',
#   '没教',
#   '奇道',
#   '这路',
#   '移形',
#   '怒道',
#   '他教',
#   '闯门',
#   '他守'],
#  ['门外',
#   '黄蓉',
#   '王是',
#   '当世高人',
#   '言出',
#   '现下',
#   '认输',
#   '如山',
#   '闪身',
#   '中计',
#   '沙龙',
#   '再见',
#   '哈哈大笑',
#   '可不是',
#   '一到',
#   '出门',
#   '咱们'],
#  ['沙通天',
#   '有言在先',
#   '涨红了脸',
#   '后辈',
#   '无计可施',
#   '小丫头',
#   '确是',
#   '门上',
#   '左手',
#   '头顶',
#   '心想',
#   '不算',
#   '一时',
#   '这一',
#   '如何',
#   '虽然',
#   '自己'],
#  ['黄蓉',
#   '彭连虎',
#   '准头',
#   '后脑',
#   '两枚',
#   '脱身',
#   '头顶',
#   '向前',
#   '只得',
#   '赵王爷',
#   '连扬',
#   '黄蓉见',
#   '正自',
#   '钱镖分',
#   '直击',
#   '镖算准',
#   '一撞',
#   '挡架',
#   '急跃',
#   '身刚'],
#  ['彭连虎',
#   '欺侮',
#   '功夫',
#   '逼回',
#   '黄蓉',
#   '没伤',
#   '黄蓉道',
#   '黄蓉笑',
#   '喝彩声',
#   '暗器',
#   '先得',
#   '稀奇',
#   '女孩儿',
#   '伤人',
#   '挡住',
#   '使劲',
#   '肚子',
#   '发射',
#   '用来',
#   '门口'],
#  ['撒赖',
#   '彭连虎',
#   '挥去',
#   '黄蓉竟',
#   '闪不避',
#   '不招',
#   '不架',
#   '斗不过',
#   '反手',
#   '明知',
#   '肩头',
#   '索性',
#   '不出',
#   '不肯',
#   '难道'],
#  ['十招',
#   '动上',
#   '彭连虎',
#   '击到',
#   '撤掌',
#   '回臂',
#   '黄蓉身',
#   '自料',
#   '揭出',
#   '见得多了',
#   '招架',
#   '辨明',
#   '必能',
#   '手背',
#   '宗派',
#   '武功',
#   '各派',
#   '刚要',
#   '诡异',
#   '小丫头'],
#  ['一招',
#   '十招',
#   '三记',
#   '左掌',
#   '黄蓉道',
#   '彭连虎',
#   '看招',
#   '冲打',
#   '踹出去',
#   '三彻',
#   '三指',
#   '叉法',
#   '探海',
#   '右拳',
#   '小指',
#   '夜叉',
#   '无名指',
#   '认不出',
#   '右腿',
#   '三股'],
#  ['黄蓉',
#   '臭小子',
#   '几招',
#   '侯通海',
#   '探海',
#   '本门',
#   '沙通天',
#   '斥道',
#   '师哥',
#   '心知',
#   '夜叉',
#   '戏弄',
#   '师弟',
#   '武功',
#   '多时',
#   '胡说',
#   '宝贝',
#   '大叫',
#   '学会',
#   '早已'],
#  ['彭连虎',
#   '移形',
#   '换位',
#   '少说几句',
#   '黄蓉',
#   '斜身',
#   '不曲',
#   '侯通海',
#   '沙通天',
#   '斥道',
#   '单看',
#   '避得开',
#   '师哥',
#   '劲力',
#   '成不成',
#   '出丑',
#   '如风',
#   '迈步',
#   '之极',
#   '直冲'],
#  ['夺魄',
#   '断魂',
#   '两招',
#   '臭小子',
#   '黄蓉右',
#   '掌横',
#   '沈青刚',
#   '直击',
#   '马青雄',
#   '鞭法',
#   '侯通海',
#   '探海',
#   '本门',
#   '师哥',
#   '这招',
#   '刀法',
#   '接下去',
#   '双臂',
#   '呼叫',
#   '连声'],
#  ['功夫',
#   '彭连虎',
#   '用本门',
#   '学武',
#   '修习本',
#   '尽有',
#   '旁采',
#   '学练别',
#   '拳技',
#   '本门',
#   '渐生',
#   '手下留情',
#   '拳法',
#   '心道',
#   '招架',
#   '精熟',
#   '博取',
#   '自然而然',
#   '杀手',
#   '狡猾'],
#  ['彭连虎',
#   '杀手',
#   '四招',
#   '第五招',
#   '黄蓉',
#   '臭小子',
#   '试招',
#   '双掌',
#   '带风',
#   '诸人见',
#   '侯通海',
#   '无冤无仇',
#   '娇美',
#   '命丧',
#   '容情',
#   '不自禁',
#   '俏皮',
#   '旁观',
#   '越快越好',
#   '可喜'],
#  ['掌法',
#   '彭连虎',
#   '一招',
#   '七招',
#   '左支右绌',
#   '郭靖',
#   '黄蓉',
#   '完颜康',
#   '时学来',
#   '第七招',
#   '三彻',
#   '现学现卖',
#   '所使',
#   '第一招',
#   '黄蓉出',
#   '这才容',
#   '险象环生',
#   '全真',
#   '内力',
#   '尽全力'],
#  ['不成', '白驼', '山少主', '欧阳克笑', '得紧', '彭寨主', '拳法', '啊哟', '小丫头', '聪明', '可用'],
#  ['右拳',
#   '左手',
#   '虚晃',
#   '彭连虎',
#   '第八招',
#   '抢出',
#   '黄蓉料',
#   '似虚乃实',
#   '欧阳克',
#   '斜身',
#   '互用',
#   '拳法',
#   '闪避',
#   '心念',
#   '轻飘飘',
#   '跃出',
#   '认不出来',
#   '灵动',
#   '美妙',
#   '如实'],
#  ['右掌',
#   '黄蓉',
#   '左掌',
#   '彭连虎',
#   '欧阳克',
#   '心下',
#   '人屠',
#   '八招',
#   '不怒',
#   '第九招',
#   '推窗',
#   '并施',
#   '千手',
#   '十成',
#   '望月',
#   '刚柔',
#   '竟自',
#   '分毫',
#   '初时',
#   '端倪'],
#  ['暗叫',
#   '黄蓉',
#   '其势',
#   '拳锋',
#   '掌力',
#   '迫到',
#   '面门',
#   '内弯',
#   '似箭般',
#   '闪躲',
#   '手肘',
#   '急退',
#   '双臂',
#   '不妙',
#   '眼见',
#   '胸口',
#   '低头',
#   '急忙',
#   '不及',
#   '向前'],
#  ['第十招',
#   '黄蓉',
#   '七八步',
#   '彭连虎',
#   '虽猛',
#   '星落',
#   '半式',
#   '扣招',
#   '黑风双',
#   '振处',
#   '直跌出',
#   '料得',
#   '去势',
#   '以攻为守',
#   '凝住',
#   '悬崖勒马',
#   '内力',
#   '长空',
#   '万难',
#   '倏然'],
#  ['彭连虎',
#   '黑风双',
#   '耸然',
#   '完颜洪烈',
#   '第十招',
#   '本要',
#   '痛下',
#   '第九招',
#   '连杀',
#   '手跃开',
#   '呕血',
#   '赵王',
#   '动容',
#   '忌惮',
#   '百人',
#   '魔头',
#   '动心',
#   '杀手',
#   '武功',
#   '小丫头'],
#  ['郭靖',
#   '黄蓉',
#   '推振',
#   '震得',
#   '似失',
#   '待要',
#   '中带',
#   '黄蓉情',
#   '勉力',
#   '静夜',
#   '隐隐作痛',
#   '失色',
#   '摔倒',
#   '双臂',
#   '答话',
#   '险些',
#   '知觉',
#   '惊慌',
#   '叫声',
#   '愤怒'],
#  ['梁子翁',
#   '郭靖',
#   '背心',
#   '脉门',
#   '心胆俱寒',
#   '掌法',
#   '奇痛',
#   '咬啮',
#   '倏觉',
#   '依样葫芦',
#   '稍松',
#   '急使',
#   '身来',
#   '急跃',
#   '这一掌',
#   '避得开',
#   '早着',
#   '完颜康',
#   '本好',
#   '料知'],
#  ['王妃',
#   '梁子翁',
#   '尚明',
#   '心慈',
#   '郭靖大',
#   '所居',
#   '脱难',
#   '他伏',
#   '稍动',
#   '完颜康',
#   '粗声暴气',
#   '显是',
#   '郭靖心',
#   '另室',
#   '一问一答',
#   '烛火',
#   '终究会',
#   '跃入',
#   '农舍',
#   '不暇'],
#  ['橱门',
#   '郭靖',
#   '金刀',
#   '有个',
#   '缩身入',
#   '刚松',
#   '房来',
#   '望出去',
#   '烛火',
#   '呆呆',
#   '王妃',
#   '桌边',
#   '缓步',
#   '出神',
#   '四下',
#   '张望',
#   '关上',
#   '东边',
#   '声响',
#   '当即'],
#  ['完颜康', '梁子翁', '进来', '王妃', '搜查', '另行', '坏人', '摇摇头', '不久', '问道', '出去'],
#  ['咽喉',
#   '小王爷',
#   '便欲安寝',
#   '郭靖心',
#   '窗里',
#   '多待',
#   '没教过',
#   '正招',
#   '我得',
#   '刚才',
#   '大蛇',
#   '记挂',
#   '拆解',
#   '吹灭',
#   '逃出去',
#   '定会',
#   '王妃',
#   '这么久',
#   '快些',
#   '一招'],
#  ['郭靖',
#   '王妃',
#   '推窗',
#   '而呼',
#   '这人时',
#   '穆易',
#   '杨铁心',
#   '只道',
#   '窗格',
#   '大出',
#   '岂知',
#   '意料之外',
#   '失声',
#   '跳进',
#   '响动',
#   '大吃一惊',
#   '逃出',
#   '王府',
#   '此处',
#   '自称'],
#  ['王妃',
#   '穆易',
#   '杨铁心',
#   '亲来',
#   '但语',
#   '酸苦',
#   '死不瞑目',
#   '道谢',
#   '父女',
#   '讥讽',
#   '辛辣',
#   '好心',
#   '多谢',
#   '这本',
#   '看清楚',
#   '孩儿',
#   '也罢',
#   '委屈',
#   '之意',
#   '两位'],
#  ['杨铁心',
#   '这枪',
#   '铁枪',
#   '王妃',
#   '温言',
#   '桌凳',
#   '橱床',
#   '眼上',
#   '生满',
#   '拿近',
#   '看时',
#   '抚挲',
#   '旧识',
#   '无一物',
#   '六寸',
#   '枪杆',
#   '好久没',
#   '枪尖',
#   '铁心',
#   '生锈'],
#  ['杨铁心',
#   '铁枪',
#   '挂回',
#   '涩然',
#   '本有',
#   '不答',
#   '张破犁',
#   '损啦',
#   '张木儿',
#   '半铁',
#   '犁头',
#   '东村',
#   '现下',
#   '一打',
#   '墙头',
#   '王妃',
#   '一斤',
#   '明儿',
#   '注视',
#   '一顿'],
#  ['杨铁心',
#   '凝目',
#   '损啦',
#   '张木儿',
#   '半铁',
#   '犁头',
#   '东村',
#   '一打',
#   '王妃',
#   '颤动',
#   '一斤',
#   '明儿',
#   '地道',
#   '说不出',
#   '半晌',
#   '缓缓',
#   '全身',
#   '这话',
#   '什么'],
#  ['一夜',
#   '酸软',
#   '椅上',
#   '王妃',
#   '声道',
#   '怎么',
#   '双脚',
#   '无力',
#   '去世',
#   '所说',
#   '丈夫',
#   '的话',
#   '知道'],
#  ['包惜弱',
#   '完颜洪烈',
#   '牛家村',
#   '相救',
#   '雄豪',
#   '水磨功夫',
#   '杨铁心',
#   '金国六',
#   '去心',
#   '段天德',
#   '只道',
#   '已死',
#   '出尽',
#   '相嫁',
#   '委身',
#   '娇柔',
#   '丘处机',
#   '举目无亲',
#   '低声下气',
#   '侠义'],
#  ['包惜弱',
#   '言一动',
#   '魂牵梦萦',
#   '无多大',
#   '杨铁心',
#   '侵磨',
#   '非复',
#   '重会',
#   '两人别',
#   '之夕',
#   '遭难',
#   '昔时',
#   '风霜',
#   '前夫',
#   '容颜',
#   '加倍',
#   '思念',
#   '认出',
#   '十八年',
#   '奔走'],
#  ['杨铁心',
#   '不答',
#   '板桌',
#   '抽屜',
#   '见放',
#   '青布衫',
#   '包惜弱',
#   '孕给',
#   '新衫',
#   '几套',
#   '那晚',
#   '布衫',
#   '歇歇',
#   '好好儿',
#   '衣衫',
#   '一模一样',
#   '十八年',
#   '衣裳',
#   '几句话',
#   '怀着'],
#  ['惊喜交集',
#   '杨铁心',
#   '果见',
#   '哭道',
#   '捋起',
#   '做鬼',
#   '显灵',
#   '带我去',
#   '阴间',
#   '伤疤',
#   '左臂',
#   '鬼魂',
#   '衣袖',
#   '十八年',
#   '身旁',
#   '一块儿',
#   '当即',
#   '抱住',
#   '认定',
#   '不由得'],
#  ['难道',
#   '杨铁心',
#   '包惜弱',
#   '铁哥',
#   '两行',
#   '热泪',
#   '放开',
#   '一顿',
#   '活着',
#   '妻子',
#   '不管',
#   '总是',
#   '一阵',
#   '下来',
#   '没有'],
#  ['杨铁心', '完颜康', '答言', '窗外', '伤心', '正要', '说话', '怎么'],
#  ['包惜弱',
#   '完颜康',
#   '疑心',
#   '郭靖',
#   '我倦',
#   '只道',
#   '庇护',
#   '明明',
#   '没事',
#   '几句话',
#   '之声',
#   '室内',
#   '开门',
#   '听得',
#   '一惊',
#   '这时候',
#   '轻轻',
#   '明天',
#   '门口',
#   '再说'],
#  ['杨铁心',
#   '可藏',
#   '他定',
#   '窗边',
#   '窗而出',
#   '那窗',
#   '包惜弱',
#   '无地',
#   '指板',
#   '橱门',
#   '劫后',
#   '爱妻',
#   '惶急',
#   '扣住',
#   '瞒过',
#   '重逢',
#   '狭隘',
#   '一推',
#   '窗子',
#   '暂且'],
#  ['郭靖', '橱门', '包惜弱', '乍见', '房内', '一开', '出声', '禁不住', '大惊', '三人', '同时'],
#  ['完颜康',
#   '郭靖',
#   '杨铁心',
#   '进板',
#   '橱门',
#   '便断',
#   '包惜弱',
#   '母亲',
#   '猛撞',
#   '闯进来',
#   '门闩',
#   '脸色苍白',
#   '定神',
#   '泪痕',
#   '门板',
#   '惊呼',
#   '要害',
#   '甚为',
#   '肩头',
#   '关上'],
#  ['完颜康',
#   '包惜弱',
#   '你别',
#   '混进来',
#   '我要',
#   '只觉',
#   '惊道',
#   '大起',
#   '橱里',
#   '母亲',
#   '儿子',
#   '衣角',
#   '疑云',
#   '脓包',
#   '卫兵',
#   '知不知道',
#   '奸细',
#   '真够',
#   '缓步',
#   '门缝'],
#  ['包惜弱',
#   '郭靖',
#   '完颜康',
#   '一扑',
#   '凤腾蛟',
#   '猛向板',
#   '刺去',
#   '杨铁心',
#   '地送',
#   '大急',
#   '仗势欺人',
#   '铁枪',
#   '一收',
#   '真本事',
#   '比武',
#   '红缨',
#   '不明不白',
#   '失声',
#   '一招',
#   '一抖'],
#  ['收转',
#   '完颜康',
#   '橱门',
#   '已自',
#   '橱里',
#   '枪尖',
#   '未到',
#   '身旁',
#   '注视',
#   '动静',
#   '心想',
#   '母亲',
#   '原来',
#   '有人',
#   '知道'],
#  ['包惜弱',
#   '橱门',
#   '喜慰',
#   '忽惊',
#   '忽喜',
#   '刺破',
#   '支持不住',
#   '半分',
#   '酸软',
#   '好端端',
#   '悠悠',
#   '力气',
#   '这般',
#   '大为',
#   '全身',
#   '并未'],
#  ['完颜康', '包惜弱', '亲儿子', '甚是', '干吗', '为什么', '当然', '很多', '这个'],
#  ['言念',
#   '思潮起伏',
#   '重圆',
#   '包惜弱',
#   '既失',
#   '铁哥',
#   '及此',
#   '泪落',
#   '完颜康',
#   '自求',
#   '大异',
#   '铸成大错',
#   '贞节',
#   '今生今世',
#   '明言',
#   '今日',
#   '如雨',
#   '必得',
#   '惊疑',
#   '相会'],
#  ['包惜弱',
#   '完颜康',
#   '橱门',
#   '枪上',
#   '杨铁心',
#   '我要',
#   '铁枪',
#   '仔细听',
#   '依言',
#   '目不转睛',
#   '问过',
#   '小时候',
#   '好生',
#   '瞧瞧',
#   '此刻',
#   '四个',
#   '不肯',
#   '手中',
#   '什么'],
#  ['杨铁心',
#   '之尊',
#   '行藏',
#   '怦然',
#   '草莽',
#   '匹夫',
#   '王妃',
#   '泄漏',
#   '暗道',
#   '岂能',
#   '母子',
#   '清清楚楚',
#   '现今',
#   '对话',
#   '莫非',
#   '听得',
#   '两人',
#   '儿子',
#   '心中'],
#  ['包惜弱',
#   '牛家村',
#   '破烂',
#   '地方',
#   '大宋',
#   '木床',
#   '运来',
#   '完颜康',
#   '画栋雕梁',
#   '这枝',
#   '铁枪',
#   '犁头',
#   '拿些',
#   '破破烂烂',
#   '千里迢迢',
#   '爹爹',
#   '福气',
#   '好得多',
#   '楼阁',
#   '定要'],
#  ['杨铁心', '扑簌簌', '落下', '心头', '眼泪', '听到', '这里'],
#  ['完颜康',
#   '爹爹',
#   '包惜弱',
#   '更奇',
#   '金国赵',
#   '东奔西走',
#   '流落江湖',
#   '安安稳稳',
#   '声道',
#   '亲生',
#   '干吗',
#   '十八年',
#   '半日',
#   '怎能',
#   '厉声',
#   '可知',
#   '屋子里',
#   '可怜',
#   '奇怪',
#   '便是'],
#  ['铁枪',
#   '爹爹',
#   '亲生',
#   '名字',
#   '包惜弱',
#   '哭道',
#   '枪上',
#   '泪如雨下',
#   '抱住',
#   '所用',
#   '指着',
#   '这才',
#   '便是',
#   '起身',
#   '当年',
#   '不得',
#   '孩子',
#   '知道'],
#  ['完颜康',
#   '糊涂',
#   '包惜弱',
#   '杨康',
#   '大金国',
#   '神智',
#   '女真人',
#   '太医',
#   '叫作',
#   '颤抖',
#   '汉人',
#   '身子',
#   '本来',
#   '什么'],
#  ['完颜康', '爹爹', '惊疑', '万分', '说不出', '愤怒', '转身'],
#  ['包惜弱', '橱门', '杨铁心', '爹爹', '大踏步', '牵着', '拉开', '走到', '这里', '出来'],
#  ['往事如烟', '第十回'],
#  ['杨铁心',
#   '完颜康',
#   '行步',
#   '铁枪',
#   '直刺',
#   '一炷香',
#   '枪尖',
#   '闪闪',
#   '朝天',
#   '惊诧',
#   '陡然',
#   '咽喉',
#   '认出',
#   '大叫',
#   '提起',
#   '之下',
#   '见到'],
#  ['包惜弱', '猛往', '举头', '爹爹', '亲生', '不信', '墙上', '地下', '一声'],
#  ['完颜康',
#   '撤步',
#   '收枪',
#   '存亡未卜',
#   '遭大变',
#   '杨铁心',
#   '满额',
#   '手足无措',
#   '细微',
#   '俯身',
#   '回身',
#   '大惊',
#   '往外',
#   '鲜血',
#   '呼吸',
#   '妻子',
#   '一时',
#   '母亲',
#   '只见'],
#  ['上步', '完颜康', '孤雁出', '枪势', '刺去', '如风', '背心', '放下'],
#  ['杨铁心',
#   '回马枪',
#   '左手',
#   '右手',
#   '杨家传',
#   '杨家枪',
#   '反圈',
#   '半招',
#   '回夺',
#   '挺枪',
#   '包惜弱',
#   '传女',
#   '没教过',
#   '枪杆',
#   '这招',
#   '枪头',
#   '五寸',
#   '世代相传',
#   '绝技',
#   '战阵'],
#  ['杨家枪',
#   '枪法',
#   '正宗',
#   '朽坏',
#   '大宋',
#   '牛家村',
#   '杨铁心',
#   '试枪',
#   '完颜康',
#   '力齐',
#   '那铁枪',
#   '迸断',
#   '嫡传',
#   '秘传',
#   '丘处机',
#   '精研',
#   '齐腰',
#   '这招',
#   '杨家',
#   '绝招'],
#  ['郭靖',
#   '完颜康',
#   '难决',
#   '杨铁心',
#   '早抱',
#   '穆念慈',
#   '两人会',
#   '齐后',
#   '逃远',
#   '屋去',
#   '父女',
#   '爹爹',
#   '守候',
#   '亲生',
#   '纵身',
#   '围墙',
#   '踌躇',
#   '冲出',
#   '王府',
#   '磕头'],
#  ['掌风',
#   '老子',
#   '郭靖',
#   '擦过去',
#   '无知觉',
#   '奔到',
#   '随出',
#   '猛觉',
#   '上直',
#   '悄没声',
#   '地袭',
#   '候得',
#   '参仙',
#   '梁子翁',
#   '缩头',
#   '劲风',
#   '翻墙',
#   '伸过来',
#   '顶门',
#   '骇然'],
#  ['黄蓉听', '彭连虎', '黑风双', '厅门', '门下', '转身', '走向'],
#  ['黑风双',
#   '彭连虎',
#   '黄蓉笑',
#   '十招',
#   '师父',
#   '晃身',
#   '怒道',
#   '灵鳌步',
#   '煞所传',
#   '怎配',
#   '混赖',
#   '黄蓉道',
#   '欺师',
#   '灭祖',
#   '彭寨主',
#   '武林中',
#   '微末',
#   '良善',
#   '无恶不作',
#   '这招'],
#  ['吐实',
#   '黑风双',
#   '无稽',
#   '诋毁',
#   '谎话',
#   '肆意',
#   '辱骂',
#   '决计',
#   '面面相觑',
#   '当众',
#   '起先',
#   '天大',
#   '敢于',
#   '一派',
#   '师长',
#   '决不',
#   '无人',
#   '不禁',
#   '不肯',
#   '众人'],
#  ['彭连虎',
#   '不姓',
#   '黄蓉嫣然',
#   '叫蓉儿',
#   '黄蓉道',
#   '芳名',
#   '贵姓',
#   '不敢当',
#   '说不得',
#   '请教',
#   '小姑娘',
#   '佩服',
#   '一笑',
#   '说道'],
#  ['灵智',
#   '欧阳克',
#   '诸人除',
#   '已输',
#   '身受',
#   '截留',
#   '动弹不得',
#   '注目',
#   '重伤',
#   '各人',
#   '出手',
#   '手里',
#   '之外',
#   '才能',
#   '这时'],
#  ['美貌',
#   '黄蓉',
#   '几招',
#   '欧阳克',
#   '黄蓉见',
#   '骑骆驼',
#   '欧阳克笑',
#   '通统',
#   '姑娘',
#   '蛮不讲理',
#   '加在一起',
#   '一红',
#   '缓步',
#   '白衣',
#   '容貌',
#   '微微一笑',
#   '请教',
#   '老头儿',
#   '而出',
#   '欢喜'],
#  ['武功',
#   '欧阳克',
#   '姬妾',
#   '宝马',
#   '女弟子',
#   '二十四名',
#   '郭靖',
#   '汗血',
#   '收为',
#   '汉女',
#   '学些',
#   '之聘',
#   '姬人',
#   '因姬',
#   '数众',
#   '兼之均',
#   '八人',
#   '六怪',
#   '朱聪',
#   '起心'],
#  ['温颜',
#   '神魂飘荡',
#   '黄蓉',
#   '欧阳克',
#   '陈姬',
#   '大宋',
#   '娇腮欲晕',
#   '虽年',
#   '尚稚',
#   '众姬',
#   '直如',
#   '诸人',
#   '骨软',
#   '心痒',
#   '绝色',
#   '软语',
#   '佳丽',
#   '粪土',
#   '秋波',
#   '比武'],
#  ['黄蓉道',
#   '永远',
#   '拜我为师',
#   '我要',
#   '欧阳克笑',
#   '欧阳克',
#   '只消',
#   '黄蓉侧',
#   '跟着',
#   '成不成',
#   '呼叫',
#   '弟子',
#   '不信',
#   '师父',
#   '全都',
#   '就算',
#   '她们',
#   '不用',
#   '身边',
#   '要是'],
#  ['欧阳克',
#   '个个',
#   '冶艳',
#   '门中',
#   '或肥',
#   '全无二致',
#   '众姬',
#   '彭连虎',
#   '看得眼',
#   '白影',
#   '呼哨',
#   '婀娜',
#   '享福',
#   '二十几个',
#   '真会',
#   '白衣',
#   '体态',
#   '晃动',
#   '侍候',
#   '羡慕'],
#  ['黄蓉',
#   '二十二名',
#   '姬人',
#   '身后',
#   '女弟子',
#   '相激',
#   '众姬',
#   '原想',
#   '乘阁',
#   '欧阳克',
#   '待众',
#   '进厅',
#   '轻摇',
#   '生妒',
#   '料知',
#   '既入',
#   '之眼',
#   '自惭形秽',
#   '看破',
#   '斜睨'],
#  ['还手',
#   '欧阳克',
#   '黄蓉道',
#   '再好没有',
#   '胜得',
#   '拜你为师',
#   '不用',
#   '黄蓉见',
#   '计不售',
#   '欧阳克笑',
#   '欺侮',
#   '舍得',
#   '试试',
#   '本领',
#   '免得',
#   '莫非',
#   '来不及',
#   '不错',
#   '喜欢',
#   '人家'],
#  ['妖法',
#   '轻薄',
#   '武功',
#   '十倍',
#   '小姑娘',
#   '怎能',
#   '打败',
#   '颇为',
#   '动手',
#   '就算',
#   '奇怪',
#   '难道',
#   '众人',
#   '心中'],
#  ['腰带',
#   '双手',
#   '一步',
#   '黄蓉道',
#   '我要',
#   '欧阳克解',
#   '黄蓉见',
#   '全不把',
#   '仍露',
#   '使力',
#   '一崩',
#   '虽使',
#   '竟崩',
#   '算输',
#   '缚住',
#   '内力',
#   '当一回事',
#   '还手',
#   '似是',
#   '有恃无恐'],
#  ['圆圈',
#   '欧阳克',
#   '右足',
#   '左足',
#   '双足',
#   '足尖',
#   '圆边',
#   '深约',
#   '已自',
#   '内劲',
#   '沙通天',
#   '彭连虎',
#   '半寸',
#   '印痕',
#   '六尺',
#   '浅浅的',
#   '相离',
#   '整整齐齐',
#   '三尺',
#   '粗细'],
#  ['欧阳克',
#   '圈子',
#   '黄蓉道',
#   '输好',
#   '推出',
#   '跟我走',
#   '前辈',
#   '乖乖',
#   '见证',
#   '倘若',
#   '走进',
#   '两人',
#   '要是',
#   '说道',
#   '自然',
#   '这里',
#   '不能',
#   '这个'],
#  ['圈子',
#   '欧阳克',
#   '还手',
#   '右掌',
#   '身子',
#   '第二招',
#   '左掌',
#   '黄蓉道',
#   '星河',
#   '左轻',
#   '右重',
#   '劲含',
#   '微侧',
#   '两掌',
#   '黄蓉掌',
#   '力方',
#   '立知',
#   '打力',
#   '掌力',
#   '黄蓉竟'],
#  ['黄蓉',
#   '白衫',
#   '欧阳克',
#   '金环',
#   '夜长梦多',
#   '发上',
#   '加快脚步',
#   '飘动',
#   '变卦',
#   '闪闪',
#   '缓步',
#   '门边',
#   '圈子',
#   '再生',
#   '只见',
#   '身上'],
#  ['欧阳克',
#   '黄蓉',
#   '暗呼',
#   '沙通天',
#   '彭连虎',
#   '捧腹大笑',
#   '有言在先',
#   '碍于',
#   '僵住',
#   '诡计',
#   '上当',
#   '追赶',
#   '不便',
#   '忍不住'],
#  ['黄蓉正',
#   '风响',
#   '身前',
#   '从空',
#   '带椅',
#   '纵跃',
#   '巨物',
#   '坐在',
#   '红袍',
#   '闪避',
#   '椅上',
#   '太师椅',
#   '连人',
#   '落下来',
#   '侧身',
#   '压住',
#   '身穿',
#   '竟是',
#   '高大',
#   '头顶'],
#  ['铜钹',
#   '双钹',
#   '僧袍',
#   '灵智',
#   '右掌',
#   '三截',
#   '异常',
#   '黄蓉正',
#   '合处',
#   '铜声',
#   '当系外',
#   '钢钹',
#   '一花',
#   '已近',
#   '一托',
#   '左足',
#   '两钹',
#   '已跃近',
#   '生光',
#   '飞过来'],
#  ['灵智',
#   '黄蓉',
#   '巨掌',
#   '一掌',
#   '手掌',
#   '收转',
#   '起处',
#   '秘刀',
#   '收足',
#   '掌震得',
#   '筋折',
#   '骨断',
#   '欧阳克',
#   '时力道',
#   '必巨',
#   '回缩',
#   '竟似',
#   '掌力来',
#   '众人',
#   '立即'],
#  ['软猬',
#   '灵智',
#   '掌来',
#   '右手掌',
#   '掌中',
#   '鲜血淋漓',
#   '刺破',
#   '怒吼',
#   '十多个',
#   '痛楚',
#   '凝神',
#   '蓦地',
#   '小孔',
#   '叫声',
#   '举起',
#   '连连',
#   '想起',
#   '众人',
#   '只见'],
#  ['软猬',
#   '桃花岛',
#   '彭连虎',
#   '惊道',
#   '镇岛',
#   '沙通天',
#   '奇道',
#   '小小年纪',
#   '之宝',
#   '怎能',
#   '东海',
#   '丫头',
#   '身上'],
#  ['黄蓉',
#   '欧阳克',
#   '长声',
#   '领了',
#   '众姬',
#   '感喜慰',
#   '我要',
#   '呼哨',
#   '跃出',
#   '挂念',
#   '追寻',
#   '人影',
#   '好歹',
#   '想来',
#   '逃走',
#   '何处',
#   '受伤',
#   '黑暗',
#   '门外',
#   '并未'],
#  ['侯通海',
#   '彭连虎',
#   '师哥',
#   '沙通天',
#   '刺猬',
#   '臭小子',
#   '软猬',
#   '软甲',
#   '这软甲',
#   '生满',
#   '就够',
#   '师兄弟',
#   '刀枪不入',
#   '伸舌头',
#   '倒刺',
#   '回来',
#   '打中',
#   '亏得',
#   '一拳',
#   '外衣'],
#  ['卫队长',
#   '奋勇当先',
#   '完颜洪烈',
#   '急报',
#   '惊怒',
#   '两人点',
#   '出府',
#   '汤祖德',
#   '得悉',
#   '赵王',
#   '交集',
#   '大呼小叫',
#   '天翻地覆',
#   '刺客',
#   '搜捕',
#   '里里外外',
#   '王妃',
#   '部属',
#   '王府',
#   '追赶'],
#  ['荆棘',
#   '郭靖',
#   '梁子翁',
#   '乱石',
#   '刀山剑林',
#   '四五丈',
#   '大骇',
#   '不辨',
#   '尽往',
#   '钻去',
#   '郭靖轻',
#   '忽觉',
#   '石剑',
#   '只觉',
#   '刺得',
#   '下堕',
#   '倒插',
#   '余暇',
#   '嶙峋',
#   '啊哟'],
#  ['圆球',
#   '他身',
#   '运劲',
#   '地时',
#   '双足',
#   '所触',
#   '手触',
#   '深洞',
#   '跌伤',
#   '辨出',
#   '骷髅头',
#   '杀了人',
#   '撑持',
#   '一跤',
#   '仰天',
#   '只待',
#   '站定',
#   '跌倒',
#   '已然',
#   '滚动'],
#  ['梁子翁',
#   '空洞无物',
#   '郭靖心',
#   '跃下',
#   '快上来',
#   '送死',
#   '追杀',
#   '四下',
#   '摸索',
#   '以防',
#   '洞口',
#   '后退',
#   '小子',
#   '几步',
#   '伸手',
#   '身后',
#   '上来',
#   '上面',
#   '于是',
#   '那么'],
#  ['郭靖',
#   '阎王殿',
#   '梁子翁',
#   '踊身',
#   '叫骂',
#   '料想',
#   '决计',
#   '追到',
#   '逃到',
#   '几声',
#   '喝道',
#   '老子',
#   '上来',
#   '不会'],
#  ['容身之处', '郭靖大', '探路', '一步步', '地道', '前行', '转过身', '几步', '伸出', '居然', '双手', '原来'],
#  ['郭靖',
#   '地道',
#   '梁子翁',
#   '逃不了',
#   '瓮中捉鳖',
#   '左右两壁',
#   '发足',
#   '艺高人胆大',
#   '漆黑一团',
#   '追去',
#   '伸手不见五指',
#   '暗算',
#   '叫苦',
#   '性急',
#   '这一下',
#   '一步步',
#   '紧迫',
#   '张开',
#   '总有',
#   '发觉'],
#  ['郭靖',
#   '臭小子',
#   '陡觉',
#   '土室',
#   '梁子翁',
#   '数丈',
#   '空旷',
#   '转眼',
#   '地道',
#   '逃到',
#   '前面',
#   '哪里',
#   '来到',
#   '一个'],
#  ['撒野', '冷冷的', '角落里', '左边', '忽然', '声音', '说道', '这里', '一个'],
#  ['万料',
#   '虽轻',
#   '两人耳中',
#   '直如',
#   '焦雷',
#   '郭靖固',
#   '梁子翁',
#   '轰轰',
#   '语声',
#   '突突',
#   '毛骨悚然',
#   '黑洞',
#   '地底',
#   '竟会',
#   '蓦地',
#   '一颗',
#   '不禁',
#   '两人',
#   '听到',
#   '之中'],
#  ['洞来',
#   '无生',
#   '声似',
#   '急喘',
#   '身患',
#   '阴森森',
#   '重病',
#   '地道',
#   '不耐烦',
#   '不住',
#   '女子',
#   '声音',
#   '说话',
#   '似乎',
#   '你们'],
#  ['梁子翁',
#   '郭靖听',
#   '掉进来',
#   '郭靖',
#   '扯裂',
#   '怪责',
#   '一言未',
#   '抢上',
#   '一拿不中',
#   '连施',
#   '郭靖左',
#   '左躲右闪',
#   '一团漆黑',
#   '稍减',
#   '疾忙',
#   '数步',
#   '擒拿',
#   '鬼怪',
#   '出言',
#   '惊惧'],
#  ['扮鬼',
#   '气喘喘',
#   '怒道',
#   '捉人',
#   '梁子翁',
#   '装神',
#   '躲到',
#   '郭靖身',
#   '突觉',
#   '一拉之下',
#   '少年人',
#   '万状',
#   '五根',
#   '劲力',
#   '伸过来',
#   '撞入',
#   '不假思索',
#   '异乎寻常',
#   '绝境',
#   '干草'],
#  ['梁子翁', '擒拿', '关外', '几下', '不小', '女人'],
#  ['梁子翁',
#   '得紧',
#   '参客',
#   '姓梁',
#   '要物',
#   '勿加',
#   '中视',
#   '轻忽',
#   '半根',
#   '寒毛',
#   '尊驾',
#   '声道',
#   '关东',
#   '武功',
#   '阻拦',
#   '家数',
#   '大吃一惊',
#   '怎地',
#   '古怪',
#   '小子'],
#  ['梁子翁',
#   '万儿',
#   '枉顾',
#   '参仙',
#   '我洞',
#   '已罪',
#   '梁老怪',
#   '愈觉',
#   '郭靖突',
#   '觉拿住',
#   '只手',
#   '强抑',
#   '武林中',
#   '问道',
#   '尊驾',
#   '宗师',
#   '懂吗',
#   '闯进',
#   '松开',
#   '手腕'],
#  ['梁子翁',
#   '郭靖',
#   '病即',
#   '运劲于',
#   '疾向',
#   '反拿敌臂',
#   '震得',
#   '幸他',
#   '内功',
#   '身负',
#   '绝技',
#   '三步',
#   '一掌',
#   '自负',
#   '武功',
#   '回转',
#   '倒退',
#   '手腕',
#   '呻吟',
#   '抓紧'],
#  ['梁子翁',
#   '女子',
#   '好贼婆',
#   '物卷',
#   '软鞭',
#   '鞭来',
#   '奇速',
#   '身随',
#   '土壁',
#   '脚踝',
#   '如风',
#   '右腿',
#   '惊惧',
#   '无声无息',
#   '七分',
#   '下身',
#   '喘气',
#   '纵身',
#   '这一下',
#   '应变'],
#  ['冲阳',
#   '头顶',
#   '这一腿',
#   '当者',
#   '立毙',
#   '撞壁',
#   '忽觉',
#   '一麻',
#   '穴道',
# ...
#   '狠毒',
#   '王道',
#   '叫苦',
#   '作响',
#   '客栈'],
#  ['梅超风', '多谢', '不答', '郭靖道', '转头', '好事', '从来', '答应', '什么'],
#  ['记不起',
#   '师哥',
#   '真经',
#   '抄本',
#   '看不见',
#   '照顾',
#   '小心',
#   '我要',
#   '江南七怪',
#   '内劲',
#   '痛到',
#   '雨下',
#   '手里',
#   '漆黑一团',
#   '多少',
#   '师妹',
#   '猛力',
#   '下卷',
#   '一掌',
#   '追来'],
#  ['杨康',
#   '短剑',
#   '哥哥',
#   '一分',
#   '抵到',
#   '雨里',
#   '地冷',
#   '有血',
#   '两字',
#   '此仇',
#   '跟着',
#   '师哥',
#   '杀了人',
#   '喷出来',
#   '不先',
#   '尖头',
#   '肚脐',
#   '杀过',
#   '算啦',
#   '细细地'],
#  ['阴世',
#   '女鬼',
#   '没完',
#   '长长地',
#   '这般',
#   '老婆',
#   '口气',
#   '哥哥',
#   '永远',
#   '要是',
#   '想到',
#   '咱们',
#   '这里',
#   '什么'],
#  ['大金国',
#   '王爷',
#   '可怜',
#   '练功夫',
#   '几年',
#   '心好',
#   '倒肯',
#   '中苦',
#   '赵王爷',
#   '师哥',
#   '瞎了眼睛',
#   '乞食',
#   '废置',
#   '牛羊肉',
#   '瞎眼',
#   '面饼',
#   '牛乳',
#   '练功',
#   '后花园',
#   '带队'],
#  ['小王爷',
#   '师父',
#   '功夫',
#   '武功',
#   '不许',
#   '跟我学',
#   '连王爷',
#   '高兴',
#   '我练',
#   '银鞭',
#   '非教',
#   '我教',
#   '一学',
#   '九阴',
#   '推心',
#   '重誓',
#   '无能之辈',
#   '喜欢',
#   '教得',
#   '三招'],
#  ['王爷',
#   '小王爷',
#   '子马钰',
#   '蒙古',
#   '真七子',
#   '我求',
#   '江南七怪',
#   '使力',
#   '答允',
#   '内功',
#   '依从',
#   '当然',
#   '七人',
#   '同去',
#   '丹阳',
#   '宠爱',
#   '运气',
#   '了不起',
#   '报仇',
#   '怎能'],
#  ['哈哈',
#   '内功',
#   '小王爷',
#   '急冲',
#   '长强',
#   '一股',
#   '哥哥',
#   '没白',
#   '地传',
#   '真诀',
#   '再练',
#   '强修',
#   '猛练',
#   '这姓',
#   '我准',
#   '苦功',
#   '真气',
#   '下半身',
#   '刚劲',
#   '怎知'],
#  ['郭靖',
#   '梅超风',
#   '右手',
#   '马钰',
#   '郭靖头',
#   '猛扼不入',
#   '反让',
#   '掌力化',
#   '举掌',
#   '摧心',
#   '得开',
#   '挡格',
#   '玄门',
#   '长啸',
#   '真传',
#   '不弱',
#   '修习',
#   '既得',
#   '内力',
#   '撑持'],
#  ['内功',
#   '手指',
#   '叉住',
#   '一根',
#   '郭靖',
#   '梅超风',
#   '感臂',
#   '剧震',
#   '动处',
#   '收势',
#   '马钰学',
#   '郭靖头',
#   '我要',
#   '根嚼来',
#   '行功',
#   '走火入魔',
#   '空言',
#   '走火',
#   '倒也不是',
#   '修习'],
#  ['郭靖', '白森森', '寒战', '张口', '打个', '牙齿', '言语', '露出', '不敢'],
#  ['梅超风',
#   '内功',
#   '花聚顶',
#   '师父',
#   '恶妇',
#   '郭靖',
#   '全真教',
#   '奇痛',
#   '五气',
#   '朝元',
#   '郭靖心',
#   '再增',
#   '不答',
#   '乘早',
#   '条心',
#   '死就死',
#   '必去',
#   '真传',
#   '彻骨',
#   '六位'],
#  ['王处一',
#   '梅超风',
#   '郭靖心',
#   '中一凛',
#   '你立',
#   '重誓',
#   '马道长',
#   '柔声道',
#   '拿药',
#   '下半身',
#   '六位',
#   '法门',
#   '不屈',
#   '倔强',
#   '不会',
#   '动弹',
#   '放松',
#   '性命',
#   '师父',
#   '交给'],
#  ['梅超风',
#   '全真教',
#   '王处一',
#   '臭小子',
#   '内功',
#   '法门',
#   '送交',
#   '动弹不得',
#   '受苦',
#   '大喜',
#   '全身',
#   '药物',
#   '永远',
#   '说道'],
#  ['臭小子',
#   '受死',
#   '郭靖听',
#   '侯通海',
#   '一面',
#   '十余丈',
#   '左前方',
#   '逃不了',
#   '另一人',
#   '左近',
#   '三头',
#   '走远',
#   '两句话',
#   '钻出来',
#   '小丫头',
#   '必定',
#   '说完',
#   '放心',
#   '两人',
#   '忽然'],
#  ['梅超风',
#   '郭靖大',
#   '须答允',
#   '怒道',
#   '郭靖道',
#   '答允',
#   '心念',
#   '脱险',
#   '秘诀',
#   '踪迹',
#   '小姑娘',
#   '高手',
#   '王府',
#   '离去',
#   '一动',
#   '折磨',
#   '一批',
#   '否则',
#   '尚未',
#   '怎样'],
#  ['梅超风',
#   '情人',
#   '多情多义',
#   '郭靖',
#   '臭小子',
#   '救不救',
#   '没答',
#   '允饶',
#   '加劲',
#   '啰唆',
#   '答允',
#   '内功',
#   '气闷',
#   '说道',
#   '怎知',
#   '脱险',
#   '喉头',
#   '不屈',
#   '秘诀',
#   '任性'],
#  ['黄蓉',
#   '郭靖听',
#   '一喜',
#   '郭靖大',
#   '喜道',
#   '答允',
#   '难为',
#   '丛中',
#   '两声',
#   '玫瑰',
#   '决不能',
#   '身旁',
#   '心头',
#   '答应',
#   '早就',
#   '这儿',
#   '别人',
#   '声音',
#   '说道',
#   '一声'],
#  ['梅超风',
#   '郭靖',
#   '黄蓉',
#   '梅若华',
#   '甜甜的',
#   '两滴',
#   '心中',
#   '花丛',
#   '对答',
#   '念念不忘',
#   '温馨',
#   '安危',
#   '放手',
#   '情人',
#   '脸颊',
#   '热泪',
#   '一阵子',
#   '喝道',
#   '感激',
#   '不顾'],
#  ['投师',
#   '梅若华',
#   '梅超风',
#   '这三字',
#   '人呼',
#   '一惊直',
#   '无人知晓',
#   '陡然间',
#   '颤声',
#   '很久没',
#   '听人',
#   '非同小可',
#   '本名',
#   '江湖',
#   '已有',
#   '问道',
#   '之前',
#   '出来'],
#  ['黄蓉朗', '影落', '按玉箫', '神剑', '姓黄', '声道', '海潮', '桃花'],
#  ['桃花岛',
#   '梅超风',
#   '旧游',
#   '黄蓉叫',
#   '试剑亭',
#   '恍若隔世',
#   '弹指',
#   '清音',
#   '颤声',
#   '学艺',
#   '竹林',
#   '东海',
#   '吃惊',
#   '师父',
#   '之地',
#   '记得',
#   '怎样',
#   '此时',
#   '问道',
#   '更加'],
#  ['忘记', '黄蓉道', '爹爹', '老人家', '亲自'],
#  ['师父',
#   '一听之下',
#   '梅超风',
#   '哪动',
#   '黄蓉叫',
#   '魂飞天外',
#   '喜不自胜',
#   '分毫',
#   '飞奔',
#   '只想',
#   '立时',
#   '放开',
#   '脚下',
#   '转身',
#   '见到',
#   '想到',
#   '可是'],
#  ['桃花岛',
#   '梅超风',
#   '没离',
#   '九阴真经',
#   '出岛',
#   '混骗',
#   '莫让',
#   '这些年来',
#   '怎能',
#   '追赶',
#   '师父',
#   '哥哥',
#   '想起',
#   '忽然',
#   '一直',
#   '这里'],
#  ['梅超风',
#   '一招',
#   '落英',
#   '黄蓉见',
#   '左足',
#   '丈余',
#   '连转',
#   '挥掌',
#   '击到',
#   '桃华',
#   '格开',
#   '黄蓉落',
#   '郭靖拉',
#   '飞花',
#   '江城',
#   '教过',
#   '师妹',
#   '一扯',
#   '跃起',
#   '爹爹'],
#  ['黄药师',
#   '桃花岛',
#   '以致',
#   '东邪',
#   '岛主',
#   '惯得',
#   '黄蓉',
#   '女儿',
#   '于生',
#   '岛去',
#   '之号',
#   '学武',
#   '所精',
#   '算经',
#   '要学',
#   '已臻',
#   '之境',
#   '出神入化',
#   '尚幼',
#   '怪僻'],
#  ['黄蓉',
#   '父亲',
#   '责骂',
#   '那人',
#   '桃花岛',
#   '黄药师',
#   '但觉',
#   '酒太淡',
#   '气苦',
#   '刁蛮',
#   '自怜',
#   '叫化',
#   '斗气',
#   '一老',
#   '心中',
#   '扮成',
#   '浪荡',
#   '赞不绝口',
#   '美酒',
#   '之极'],
#  ['坦诚相待',
#   '郭靖',
#   '两人',
#   '郭靖头',
#   '郭靖竟',
#   '送金',
#   '赠马',
#   '知交',
#   '一见如故',
#   '备至',
#   '雪中送炭',
#   '解衣',
#   '心中',
#   '凄苦',
#   '哪知',
#   '无意间',
#   '言谈',
#   '怨气',
#   '初时',
#   '张家口'],
#  ['梅超风',
#   '桃花岛',
#   '武功',
#   '黄药师',
#   '郭靖',
#   '黄蓉',
#   '陈玄风',
#   '闺名',
#   '影落',
#   '按玉箫',
#   '试剑亭',
#   '一吓',
#   '神剑',
#   '父亲',
#   '无人不知',
#   '谎称',
#   '两门',
#   '敌手',
#   '海潮',
#   '自知'],
#  ['黄药师',
#   '师父',
#   '弟子',
#   '从宽',
#   '处分',
#   '全身',
#   '梅超风',
#   '之酷',
#   '之辣',
#   '脸如',
#   '已站',
#   '身前',
#   '似已',
#   '全失',
#   '已盲',
#   '慕之念',
#   '虽怕',
#   '严越',
#   '土色',
#   '猪狗不如'],
#  ['郭靖',
#   '黄蓉提',
#   '大感',
#   '不以为意',
#   '大敌当前',
#   '凶神恶煞',
#   '爹爹',
#   '重围',
#   '悬崖',
#   '相遇',
#   '落入',
#   '纵然',
#   '犹如',
#   '一听',
#   '每次',
#   '奇怪',
#   '样子',
#   '总是',
#   '然而',
#   '一般'],
#  ['清啸',
#   '郭靖',
#   '黄蓉',
#   '墙外',
#   '跃墙',
#   '一人长',
#   '手摇',
#   '一拉',
#   '折扇',
#   '女孩儿',
#   '好笑',
#   '正想',
#   '逃出',
#   '暗暗',
#   '身后',
#   '两人',
#   '不再',
#   '一声'],
#  ['梅超风',
#   '爹爹',
#   '最肯',
#   '见到',
#   '黄蓉见',
#   '欧阳克',
#   '梅师姊',
#   '先立',
#   '黄蓉道',
#   '待会',
#   '敌不过',
#   '大振',
#   '必能',
#   '欺侮',
#   '求情',
#   '武功',
#   '转头',
#   '假装',
#   '坏人',
#   '几件'],
#  ['欧阳克', '姬妾', '四名', '眼前', '来到', '说话', '之间'],
#  ['动上', '黄蓉拉', '郭靖躲', '梅超风', '欧阳克', '溜走', '只待', '乘机', '身后'],
#  ['地下',
#   '啊啊啊',
#   '径行',
#   '黄蓉',
#   '欧阳克见',
#   '梅超风',
#   '轻挥',
#   '抓劲势',
#   '未遇',
#   '大骇',
#   '伸扇',
#   '击去',
#   '急跃',
#   '连响',
#   '欧阳克',
#   '四女',
#   '指孔',
#   '罕闻',
#   '腕骨',
#   '天灵盖'],
#  ['怯意',
#   '欧阳克惊',
#   '神驼',
#   '发掌',
#   '梅超风',
#   '每一',
#   '欧阳克',
#   '欺近',
#   '身去',
#   '劲风',
#   '减了',
#   '半身不遂',
#   '抓出',
#   '十指',
#   '挟着',
#   '交集',
#   '飘忽',
#   '家传',
#   '尖利',
#   '身形'],
#  ['侯通海',
#   '两响',
#   '怎有',
#   '黄蓉拉',
#   '郭靖正',
#   '黄蓉身',
#   '正自',
#   '软猬',
#   '急缩',
#   '只痛',
#   '哇哇大叫',
#   '余裕',
#   '狂吼',
#   '挥拳',
#   '略偏',
#   '双拳',
#   '肉瘤',
#   '哇哇',
#   '啪啪',
#   '打中'],
#  ['沙通天', '梁子翁', '彭连虎', '诸人', '片刻之间', '赶到', '先后'],
#  ['婆娘',
#   '扮鬼',
#   '梁子翁',
#   '欧阳克连',
#   '沙通天',
#   '梅超风',
#   '而动',
#   '彭连虎',
#   '数招',
#   '黑风双',
#   '俟机',
#   '狠辣',
#   '遇险',
#   '近旁',
#   '撕得',
#   '骇然',
#   '高强',
#   '稀烂',
#   '哇哇',
#   '地洞'],
#  ['侯通海',
#   '钢刺',
#   '蛾眉',
#   '啊哟',
#   '头上',
#   '头顶',
#   '不来',
#   '生刺',
#   '黄蓉',
#   '臭小子',
#   '东躲西',
#   '黄蓉见',
#   '抓向',
#   '矮身',
#   '丛后',
#   '只痛',
#   '黄蓉笑',
#   '沙通天',
#   '斥道',
#   '师哥'],
#  ['梅超风',
#   '郭靖',
#   '肩头',
#   '攻来',
#   '那姓梁',
#   '渐感',
#   '回臂',
#   '郭靖背',
#   '共抗',
#   '欧阳克',
#   '右爪',
#   '梁子翁',
#   '郭靖道',
#   '依着',
#   '趋后',
#   '趋退',
#   '闪跃',
#   '下击',
#   '放在',
#   '挡开'],
#  ['梅超风',
#   '五心',
#   '郭靖道',
#   '内功',
#   '掌心',
#   '修练',
#   '时姿式',
#   '双足',
#   '梁子翁',
#   '迸现',
#   '跃开',
#   '盘膝而坐',
#   '一面',
#   '念念不忘',
#   '大振',
#   '秘诀',
#   '迎敌',
#   '登时',
#   '肩头',
#   '鲜血'],
#  ['上前',
#   '郭靖',
#   '黄蓉',
#   '沙通天',
#   '梅超风',
#   '飞步',
#   '踏步',
#   '擒拿',
#   '见鬼',
#   '师弟',
#   '龙王',
#   '打发',
#   '追赶',
#   '一惊',
#   '心里',
#   '过去',
#   '两个'],
#  ['侯通海',
#   '梅超风',
#   '救命',
#   '急缩',
#   '前伸',
#   '疾往',
#   '麻软',
#   '天灵盖',
#   '后心',
#   '动弹不得',
#   '岂知',
#   '左臂',
#   '手臂',
#   '大叫',
#   '右手',
#   '伸出',
#   '手指',
#   '提起',
#   '身后',
#   '抓住'],
#  [],
#  ['威士忌',
#   '白饭',
#   '而是',
#   '亦非',
#   '并非',
#   '诸葛亮',
#   '当真',
#   '谈论',
#   '舌头',
#   '不是',
#   '甜饼',
#   '三文治',
#   '虾饺',
#   '舌战群儒',
#   '烧卖',
#   '日月星',
#   '论剑',
#   '纳采',
#   '汤包',
#   '打擂台'],
#  ['朝元',
#   '五气',
#   '花聚顶',
#   '还丹',
#   '钟离',
#   '玉液',
#   '内功',
#   '吕洞宾',
#   '求仙',
#   '梅超风',
#   '聚顶',
#   '炼形',
#   '易语',
#   '炼气',
#   '修习',
#   '用于',
#   '轻言',
#   '长生不老',
#   '各为',
#   '入门'],
#  ['第十一回', '服输', '长春'],
#  ['侯通海',
#   '沙通天',
#   '梅超风',
#   '势道',
#   '师弟',
#   '这般',
#   '纸鹞',
#   '恭喜发财',
#   '急格',
#   '感臂',
#   '彭连虎',
#   '往钱',
#   '声中',
#   '中镖',
#   '黄蓉百',
#   '多钱',
#   '必受',
#   '伸掌',
#   '力托',
#   '般飞'],
#  ['梅超风',
#   '沙通天',
#   '侯通海',
#   '中拳',
#   '彭连虎',
#   '欧阳克',
#   '梁子翁',
#   '肉瘤',
#   '师弟',
#   '眨眼',
#   '三路',
#   '从前',
#   '之事',
#   '陆续',
#   '同时'],
#  ['梅超风',
#   '郭靖道',
#   '五气',
#   '朝元',
#   '铮铮',
#   '马钰',
#   '数十枚',
#   '辨形',
#   '连弹',
#   '一阵响',
#   '钱镖分',
#   '彭四人射',
#   '东魂',
#   '之木',
#   '西魄',
#   '之金',
#   '南神',
#   '北精之水',
#   '之土',
#   '凝耳韵'],
#  ['郭靖',
#   '内功',
#   '师父',
#   '道家',
#   '偷心',
#   '马钰',
#   '教他',
#   '运息',
#   '功诀',
#   '黑虎',
#   '如何',
#   '耗子',
#   '一招',
#   '武功',
#   '伯伯',
#   '道士',
#   '忠厚老实',
#   '通任督',
#   '桃花岛',
#   '外功'],
#  ['道家',
#   '花聚顶',
#   '修练',
#   '郭靖',
#   '五气',
#   '朝元',
#   '行功',
#   '九阴真经',
#   '梅超风',
#   '秘奥',
#   '不喜',
#   '郭靖道',
#   '为神',
#   '走火',
#   '内功',
#   '修习',
#   '四象',
#   '苦思',
#   '求仙',
#   '练功'],
#  ['梅超风',
#   '二用',
#   '练功夫',
#   '郭靖',
#   '全神',
#   '稍长',
#   '左肩',
#   '右胁',
#   '欧阳克',
#   '沙通天',
#   '落败',
#   '稍缓',
#   '口诀',
#   '难当',
#   '心有',
#   '剧痛',
#   '一掌',
#   '留神',
#   '应战',
#   '名家'],
#  ['郭靖',
#   '梅超风',
#   '师父',
#   '对头',
#   '厉害',
#   '黄蓉本',
#   '数招',
#   '为人处事',
#   '下风',
#   '哪知',
#   '师妹',
#   '溜走',
#   '情急',
#   '左右为难',
#   '上阵',
#   '毛骨悚然',
#   '缠住',
#   '全然',
#   '救护',
#   '亲眼'],
#  ['郭靖',
#   '梅超风',
#   '强好胜',
#   '怎是',
#   '左支右绌',
#   '黄蓉道',
#   '也动',
#   '每一',
#   '有苦难言',
#   '自傲',
#   '命丧',
#   '寒毛',
#   '托大',
#   '内功',
#   '疑难',
#   '敌手',
#   '奉承',
#   '果真',
#   '刹那间',
#   '放开'],
#  ['梁子翁',
#   '梅超风',
#   '长发',
#   '再斗',
#   '长声',
#   '跃向',
#   '觉到',
#   '袭到',
#   '横挥',
#   '猛觉',
#   '黄蓉眼',
#   '见势',
#   '发掌',
#   '仍拉住',
#   '挥掌',
#   '只觉',
#   '劲风',
#   '击出',
#   '扑面',
#   '松手'],
#  ['梅超风',
#   '彭连虎',
#   '黑风双',
#   '瞒天大谎',
#   '师父',
#   '黄蓉',
#   '拆招',
#   '煞中',
#   '黄蓉笑',
#   '大感',
#   '再学',
#   '不认',
#   '早知',
#   '一百年',
#   '敬意',
#   '非但',
#   '武功',
#   '家数',
#   '小丫头',
#   '良久'],
#  ['沙通天',
#   '梅超风',
#   '彭连虎',
#   '心想',
#   '射人先射马',
#   '右掌',
#   '郭靖',
#   '长鞭',
#   '猛往',
#   '吐声',
#   '低啸',
#   '俯低',
#   '欧阳克',
#   '逼开',
#   '不先毙',
#   '铜尸',
#   '陈玄风',
#   '六怪',
#   '黑风双',
#   '远震'],
#  ['梅超风',
#   '彭连虎',
#   '顾不到',
#   '郭靖',
#   '地下',
#   '难挡',
#   '难避',
#   '沙通天',
#   '梁子翁',
#   '欧阳克',
#   '非易',
#   '跃开',
#   '鞭法',
#   '舞鞭',
#   '疾伸',
#   '四丈',
#   '滚进',
#   '罢手',
#   '唿哨',
#   '拍击'],
#  ['彭连虎',
#   '郭靖',
#   '长鞭',
#   '黄蓉见',
#   '梅超风',
#   '舞成',
#   '银圈',
#   '怎进',
#   '鞭圈',
#   '实已',
#   '郭靖叫',
#   '黄蓉叫',
#   '形势危急',
#   '遇险',
#   '招架不住',
#   '单手',
#   '住手',
#   '大家',
#   '插手',
#   '理睬'],
#  ['围墙',
#   '黄蓉',
#   '看时',
#   '彭连虎',
#   '方酣',
#   '恶斗',
#   '住手',
#   '六人',
#   '看不清楚',
#   '一排',
#   '面目',
#   '顶上',
#   '黑暗',
#   '回头',
#   '不了',
#   '只见',
#   '有人',
#   '不知',
#   '大家'],
#  ['一人',
#   '两人跃下',
#   '地来',
#   '软鞭',
#   '齐向',
#   '欧阳克打',
#   '那使',
#   '采花贼',
#   '墙头',
#   '扁担',
#   '挥动',
#   '举起',
#   '哪里',
#   '胖子'],
#  ['郭靖听', '快救', '语声', '弟子', '大喜', '师父', '心中'],
#  ['六怪',
#   '欧阳克',
#   '少女',
#   '功夫',
#   '女子',
#   '江南',
#   '郭靖',
#   '良家女子',
#   '扭断',
#   '这六人',
#   '白驼',
#   '手来',
#   '虽高',
#   '但六怪',
#   '大非',
#   '昔比',
#   '以六攻',
#   '柯镇恶',
#   '一杖',
#   '朱聪以'],
#  ['郭靖',
#   '上前',
#   '之下',
#   '长鞭',
#   '欧阳克',
#   '韩宝驹',
#   '郭靖叫',
#   '朱聪',
#   '铁尸',
#   '梅超风',
#   '韩小莹',
#   '挺剑',
#   '全金发',
#   '鞭圈',
#   '来救',
#   '滚进',
#   '舞动',
#   '又惊又喜',
#   '六人',
#   '凝神'],
#  ['彭连虎',
#   '住手',
#   '若洪钟',
#   '已感',
#   '这六人',
#   '攻铁尸',
#   '是友',
#   '不斗',
#   '地堂',
#   '鞭圈',
#   '震得',
#   '梁子翁',
#   '沙通天',
#   '嗡嗡作响',
#   '拳法',
#   '吆喝声',
#   '耳中',
#   '滚出',
#   '六人',
#   '更难'],
#  ['柯镇恶',
#   '喝声',
#   '三弟',
#   '七妹',
#   '韩宝驹',
#   '别忙',
#   '退后',
#   '叫唤',
#   '此人',
#   '动手',
#   '大哥',
#   '当下',
#   '知道'],
#  ['梅超风',
#   '黄蓉',
#   '银鞭',
#   '郭靖大',
#   '打手势',
#   '爹爹',
#   '喘气',
#   '呼呼',
#   '功劳',
#   '欢喜',
#   '必定',
#   '不小',
#   '走上',
#   '前去',
#   '双手',
#   '身子',
#   '这次',
#   '说道'],
#  ['软鞭',
#   '花聚顶',
#   '拔身',
#   '后跃开',
#   '郭靖',
#   '黄蓉',
#   '为神',
#   '梅超风',
#   '化法',
#   '忽觉',
#   '郭靖乘',
#   '使力',
#   '提气',
#   '他身',
#   '生满',
#   '韩宝驹',
#   '双鞭',
#   '只觉',
#   '剧震',
#   '强夺'],
#  ['七怪',
#   '今日',
#   '梅超风',
#   '撑落',
#   '柯镇恶',
#   '那声',
#   '韩小莹',
#   '知是',
#   '江南七怪',
#   '换作',
#   '那正',
#   '环攻',
#   '无生',
#   '梁老怪',
#   '拚得',
#   '白蟒',
#   '六怪',
#   '手底',
#   '呼喝',
#   '弥陀'],
#  ['四五丈',
#   '六怪',
#   '沙通天',
#   '银鞭',
#   '寂静无声',
#   '忌惮',
#   '个个',
#   '厉害',
#   '之内',
#   '远远',
#   '江南',
#   '身子',
#   '一时',
#   '不敢'],
#  ['朱聪',
#   '妖妇',
#   '郭靖',
#   '帮起',
#   '郭靖道',
#   '人要',
#   '梅超风',
#   '大惑不解',
#   '干吗',
#   '低声',
#   '动手',
#   '那些',
#   '怎么',
#   '他们'],
#  ['彭连虎',
#   '久仰',
#   '万儿',
#   '柯镇恶',
#   '江南七怪',
#   '七侠',
#   '有何贵干',
#   '七人',
#   '来者',
#   '冷冷地',
#   '人称',
#   '江湖',
#   '江南',
#   '留下',
#   '兄弟',
#   '闯王',
#   '我们'],
#  ['七怪',
#   '南希仁',
#   '沙通天',
#   '老沙',
#   '江南七怪',
#   '触起',
#   '四徒',
#   '之恨',
#   '抢上',
#   '劈下',
#   '只交',
#   '数招',
#   '韩小莹',
#   '全金发',
#   '秤杆',
#   '怪声',
#   '长剑',
#   '径向',
#   '找上门来',
#   '受辱'],
#  ['全金发',
#   '彭连虎',
#   '秤杆',
#   '兵刃',
#   '调调儿',
#   '险招',
#   '六弟',
#   '大喝',
#   '来夺',
#   '后缩',
#   '使招',
#   '身直',
#   '双掌',
#   '风响',
#   '韩宝驹',
#   '势危',
#   '虽失',
#   '横拳',
#   '飞足',
#   '双战'],
#  ['落下风',
#   '魔杖',
#   '朱二人',
#   '柯镇恶',
#   '动伏',
#   '南希仁',
#   '朱聪挥',
#   '起白',
#   '彭连虎',
#   '六怪',
#   '超余人',
#   '沙彭',
#   '以一敌',
#   '中远',
#   '折扇',
#   '武功',
#   '相助',
#   '二人',
#   '分别'],
#  ['侯通海',
#   '黄蓉道',
#   '怒道',
#   '公道',
#   '瘤儿',
#   '不割',
#   '占便宜',
#   '黄蓉',
#   '臭小子',
#   '已斗得',
#   '软猬',
#   '拳掌',
#   '碰向',
#   '我见',
#   '瘤子',
#   '我脱',
#   '软甲',
#   '尖刺',
#   '三个',
#   '欺人'],
#  ['柯镇恶',
#   '欧阳克',
#   '妖妇',
#   '抖起',
#   '先杀',
#   '欺到',
#   '旁风响',
#   '避过',
#   '钢杖',
#   '南希仁',
#   '他东',
#   '西跃',
#   '竟向',
#   '轻功',
#   '右脑',
#   '公子爷',
#   '瞬息',
#   '多管闲事',
#   '进身',
#   '出掌'],
#  ['郭靖',
#   '梁子翁',
#   '十几包',
#   '几招',
#   '欧阳克',
#   '后六怪',
#   '要败',
#   '拆得',
#   '郭靖情',
#   '急中',
#   '疾向',
#   '药气',
#   '招架',
#   '撕破',
#   '小腹',
#   '自始至终',
#   '转眼',
#   '不离',
#   '闻到',
#   '胸口'],
#  ['郭靖',
#   '梅超风',
#   '长鞭',
#   '抱住',
#   '快救',
#   '只绕',
#   '梁子翁',
#   '虽见',
#   '听明',
#   '银鞭',
#   '玄门',
#   '紧追不舍',
#   '急奔',
#   '内功',
#   '老怪',
#   '五指',
#   '留神',
#   '再要',
#   '所及',
#   '喘气'],
#  ['黄蓉',
#   '郭靖',
#   '梅超风',
#   '长鞭',
#   '侯通海',
#   '梁子翁',
#   '鞭头',
#   '银鞭',
#   '遇物',
#   '回扯',
#   '梅若华',
#   '过远',
#   '相斗',
#   '闪避',
#   '情急之下',
#   '飞身',
#   '拦腰',
#   '缠住',
#   '相救',
#   '上风'],
#  ['梅超风',
#   '倒钩',
#   '小丫头',
#   '赔还',
#   '师父',
#   '黄蓉',
#   '长鞭',
#   '再作',
#   '黄蓉拉',
#   '鞭上',
#   '上利',
#   '外衫',
#   '黄蓉笑',
#   '我要',
#   '软猬',
#   '小妹子',
#   '扯破',
#   '新衣',
#   '满以为',
#   '拉过来'],
#  ['梅超风',
#   '郭靖',
#   '黄蓉',
#   '郭靖招',
#   '身去',
#   '丈许',
#   '梁子翁',
#   '忌惮',
#   '走近',
#   '逼近',
#   '厉害',
#   '之外',
#   '不敢'],
#  ['六怪',
#   '彭连虎',
#   '圆阵',
#   '韩宝驹',
#   '郭靖',
#   '沙通天',
#   '欧阳克',
#   '侯通海',
#   '半倍',
#   '但沙',
#   '他知',
#   '狠极',
#   '战团',
#   '险象环生',
#   '勉力',
#   '练成',
#   '片刻间',
#   '太强',
#   '下毒手',
#   '咬紧牙关'],
#  ['彭连虎',
#   '爹爹',
#   '情急智生',
#   '匹夫无罪',
#   '怀璧其罪',
#   '郭靖眼',
#   '见势',
#   '双掌',
#   '排云',
#   '推月',
#   '猛往',
#   '心震去',
#   '挥掌',
#   '掠开',
#   '郭靖便',
#   '黄蓉见',
#   '梅超风',
#   '九阴真经',
#   '飞步',
#   '三招'],
#  ['梅超风',
#   '四人',
#   '九阴真经',
#   '顾不到',
#   '一凛',
#   '欧阳克',
#   '沙通天',
#   '彭连虎',
#   '梁子翁',
#   '黑风双',
#   '银鞭',
#   '欺不进',
#   '鞭圈',
#   '武学',
#   '大利',
#   '秘笈',
#   '一时之间',
#   '舞动',
#   '好手',
#   '至高无上'],
#  ['郭靖', '黄蓉见', '支开', '一拉', '强敌', '四名', '低声', '一句', '咱们'],
#  ['各位',
#   '小王爷',
#   '步奔',
#   '完颜康',
#   '惶急',
#   '要事',
#   '金冠',
#   '语声',
#   '爹爹',
#   '花木',
#   '丛中',
#   '相助',
#   '师傅',
#   '头顶',
#   '前去',
#   '一人',
#   '现有',
#   '立即',
#   '此时',
#   '一边'],
#  ['彭连虎',
#   '跃开',
#   '九阴真经',
#   '梅超风',
#   '完颜康',
#   '参请',
#   '母亲',
#   '礼聘',
#   '轻声道',
#   '奸人',
#   '集注',
#   '恋恋不舍',
#   '相救',
#   '急事',
#   '快去',
#   '王爷',
#   '各位',
#   '当即',
#   '不去',
#   '既有'],
#  ['完颜洪烈',
#   '彭连虎',
#   '忙命',
#   '回府',
#   '完颜康',
#   '心下',
#   '梅超风',
#   '不见踪影',
#   '王妃',
#   '神通广大',
#   '黑夜',
#   '王府',
#   '焦急',
#   '追赶',
#   '带领',
#   '亲兵',
#   '地下',
#   '见到',
#   '想起',
#   '之中'],
#  ['王妃',
#   '真经',
#   '调虎离山',
#   '彭连虎',
#   '六怪',
#   '将众',
#   '另下',
#   '九阴真经',
#   '决难',
#   '压倒群雄',
#   '既知',
#   '完颜康',
#   '独吞',
#   '绊住',
#   '劫持',
#   '何用',
#   '快步',
#   '高手',
#   '计较',
#   '本事'],
#  ['梁子翁',
#   '郭靖',
#   '救不救',
#   '孤势',
#   '郭靖叫',
#   '药来',
#   '怒极',
#   '一扬',
#   '劲力',
#   '透骨',
#   '回手',
#   '忘情',
#   '倒也不',
#   '王妃',
#   '凌厉',
#   '热血',
#   '脑门',
#   '呼呼',
#   '在意',
#   '一枚'],
#  ['朱聪',
#   '梁子翁',
#   '透骨',
#   '左手',
#   '转身',
#   '左掌',
#   '那钉',
#   '一闻',
#   '见血',
#   '封喉',
#   '他知',
#   '朱聪见',
#   '上满',
#   '怒道',
#   '飞步',
#   '鼻端',
#   '暗算',
#   '子午',
#   '暗器',
#   '折扇'],
#  ['柯镇恶',
#   '郭靖',
#   '伤药',
#   '正自',
#   '五怪',
#   '上墙',
#   '韩小莹',
#   '梅超风',
#   '马道长',
#   '回去',
#   '历险',
#   '跃上',
#   '敌手',
#   '纵身',
#   '围墙',
#   '踌躇',
#   '为难',
#   '好生',
#   '就此',
#   '夺取'],
#  ['桃花岛',
#   '黄蓉笑',
#   '梅超风',
#   '老人家',
#   '师父',
#   '六怪',
#   '黄蓉格',
#   '格笑',
#   '问来',
#   '师妹',
#   '跃上',
#   '气喘',
#   '爹爹',
#   '另一端',
#   '嘻嘻',
#   '围墙',
#   '即刻',
#   '干吗',
#   '请安',
#   '喝道'],
#  ['黄蓉',
#   '长强',
#   '下身',
#   '忽地',
#   '练内功',
#   '梅超风',
#   '怒极',
#   '地向',
#   '真气行',
#   '之末',
#   '当足',
#   '之会',
#   '强运',
#   '急怒',
#   '浑忘',
#   '发足',
#   '疾冲',
#   '之境',
#   '涌至',
#   '真气'],
#  ['黄蓉见', '发足', '跃下', '一溜烟', '追来', '无影无踪', '围墙', '大吃一惊'],
#  ['梅超风', '此念', '忽麻', '跌倒', '双腿', '就此', '想起', '突然', '一起', '过去', '怎么'],
#  ['郭靖',
#   '胜之不武',
#   '略述',
#   '王处一',
#   '六怪',
#   '要伤',
#   '马钰有',
#   '韩小莹',
#   '靖儿',
#   '盗药',
#   '遇梅',
#   '杨铁心',
#   '朱聪道',
#   '长去',
#   '探囊取物',
#   '便携',
#   '跃出',
#   '王道',
#   '失手',
#   '地洞'],
#  ['妻子', '杨铁心', '跃出', '重逢', '团圆', '王府', '说不出'],
#  ['大奇',
#   '穆念慈',
#   '杨铁心',
#   '横抱',
#   '包惜弱',
#   '急奔',
#   '义女',
#   '墙边',
#   '我妈',
#   '双臂',
#   '悄声',
#   '王府',
#   '焦急',
#   '忽见',
#   '等候',
#   '外围',
#   '女子',
#   '回头',
#   '再说',
#   '父亲'],
#  ['包惜弱',
#   '中见',
#   '杨铁心',
#   '喜极',
#   '而涕',
#   '日思夜想',
#   '柔声道',
#   '破晓',
#   '天将',
#   '犹疑',
#   '一程',
#   '微光',
#   '声道',
#   '好端端',
#   '身在',
#   '悠悠',
#   '黎明',
#   '大哥',
#   '伸手',
#   '丈夫'],
#  ['一彪',
#   '莫走',
#   '蹄声',
#   '杂沓',
#   '反贼',
#   '王妃',
#   '劫持',
#   '马军',
#   '一语',
#   '并举',
#   '刀枪',
#   '闪动',
#   '当先',
#   '火把',
#   '大叫',
#   '赶来',
#   '后面',
#   '人马'],
#  ['十八年',
#   '丈夫',
#   '杨铁心',
#   '重会',
#   '包惜弱',
#   '牛家村',
#   '突觉',
#   '惨事',
#   '可怜见',
#   '蓦然',
#   '心满意足',
#   '追兵',
#   '临安',
#   '暗想',
#   '屈辱',
#   '重演',
#   '搂住',
#   '狼狈',
#   '放手',
#   '牢牢'],
#  ['追兵',
#   '杨铁心',
#   '亲兵',
#   '已近',
#   '穆念慈',
#   '威增',
#   '汤祖德',
#   '发喊',
#   '心下',
#   '稍定',
#   '夺到',
#   '挥拳',
#   '中枪',
#   '小兵',
#   '一枝花',
#   '颇感',
#   '力战',
#   '受辱',
#   '落马',
#   '四下'],
#  ['包惜弱',
#   '提不起来',
#   '天已',
#   '惊道',
#   '杨铁心',
#   '忽感',
#   '使力',
#   '完颜康',
#   '指孔',
#   '尘头',
#   '迸裂',
#   '点点滴滴',
#   '创口',
#   '抓出',
#   '这时',
#   '酸软',
#   '大振',
#   '剧痛',
#   '手背',
#   '包扎']]
