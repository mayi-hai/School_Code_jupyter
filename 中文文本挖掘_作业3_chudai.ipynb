# %%
import pandas as pd
raw = pd.read_csv("金庸-射雕英雄传txt精校版.txt",
                  names = ['txt'], sep ='aaa', encoding ="GBK" ,engine='python')
print(len(raw))
raw
# Out:
# 7165
#                                                     txt
# 0     全本全集精校小说尽在：http://www.yimuhe.com/u/anglewing26...
# 1                       更多资源下载：http://qqzone.ctdisk.com
# 2     ※声明：本电子书仅供读者预览,请在下载24小时内删除，不得用作商业用途；如果喜欢请购买正版图书！※
# 3            ------------------------------------------
# 4                                             “金庸作品集”新序
# 5                                     小说是写给人看的。小说的内容是人。
# 6     小说写一个人、几个人、一群人、或成千成万人的性格和感情。他们的性格和感情从横面的环境中反映出...
# 7     西洋传统的小说理论分别从环境、人物、情节三个方面去分析一篇作品。由于小说作者不同的个性与才能...
# 8     基本上，武侠小说与别的小说一样，也是写人，只不过环境是古代的，主要人物是有武功的，情节偏重于...
# 9     小说是艺术的一种，艺术的基本内容是人的感情和生命，主要形式是美，广义的、美学上的美。在小说，...
# 10    读者阅读一部小说，是将小说的内容与自己的心理状态结合起来。同样一部小说，有的人感到强烈的震动...
# 11    武侠小说只是表现人情的一种特定形式。作曲家或演奏家要表现一种情绪，用钢琴、小提琴、交响乐、或...
# 12    好或者不好，在艺术上是属于美的范畴，不属于真或善的范畴。判断美的标准是美，是感情，不是科学上...
# 13    在中世纪的欧洲，基督教的势力及于一切，所以我们到欧美的博物院去参观，见到所有中世纪的绘画都以...
# 14    中国人的文艺观，长期以来是“文以载道”，那和中世纪欧洲黑暗时代的文艺思想是一致的，用“善或不...
# 15    我写武侠小说，只是塑造一些人物，描写他们在特定的武侠环境（中国古代的、没有法治的、以武力来解...
# 16    对于小说，我希望读者们只说喜欢或不喜欢，只说受到感动或觉得厌烦。我最高兴的是读者喜爱或憎恨我...
# 17    武侠小说虽说是通俗作品，以大众化、娱乐性强为重点，但对广大读者终究是会发生影响的。我希望传达...
# 18    武侠小说并不是现实主义的作品。有不少批评家认定，文学上只可肯定现实主义一个流派，除此之外，全...
# 19    撰写这套总数三十六册的《作品集》，是从一九五五年到七二年，前后约十三、四年，包括十二部长篇小...
# 20    翻版本不付版税，还在其次。许多版本粗制滥造，错讹百出。还有人借用“金庸”之名，撰写及出版武侠...
# 21    有些翻版本中，还说我和古龙、倪匡合出了一个上联“冰比冰水冰”徵对，真正是大开玩笑了。汉语的对...
# 22    为了使得读者易于分辨，我把我十四部长、中篇小说书名的第一个字凑成一副对联：“飞雪连天射白鹿，...
# 23    有不少读者来信提出一个同样的问题：“你所写的小说之中，你认为哪一部最好？最喜欢哪一部？”这个...
# 24    这些小说在香港、台湾、中国内地、新加坡曾拍摄为电影和电视连续集，有的还拍了三、四个不同版本，...
# 25    武侠小说继承中国古典小说的长期传统。中国最早的武侠小说，应该是唐人传奇的《虬髯客传》、《红线...
# 26    我初期所写的小说，汉人皇朝的正统观念很强。到了后期，中华民族各族一视同仁的观念成为基调，那是...
# 27    历史上的事件和人物，要放在当时的历史环境中去看。宋辽之际、元明之际、明清之际，汉族和契丹、蒙...
# 28    在刘再复先生与他千金刘剑梅合写的“父女两地书”（共悟人间）中，剑梅小姐提到她曾和李陀先生的一...
# 29    这次第三次修改，改正了许多错字讹字、以及漏失之处，多数由于得到了读者们的指正。有几段较长的补...
# ...                                                 ...
# 7135                                                 黄裳
# 7136  《射雕英雄传》中所说的黄裳真有其人。近人陈国符先生《道藏源流考》中考证宋徽宗访求天下道教遗书...
# 7137  黄裳，字晟仲，人称演山先生，福建延平人，高宗建炎三年卒，年八十七。《演山先生神道碑》中说他：...
# 7138  黄裳刊印道藏的名气很响，后来明教刊印经书，也借用他的名字。陆游《渭南文集卷五·条对状》：“明...
# 7139                    至于黄裳根据道藏而撰《九阴真经》，自是武侠小说家的凭空撰述了。
# 7140                                                 后记
# 7141  《射雕英雄传》作于一九五七年到一九五九年，在《香港商报》连载。回想十多年前《香港商报》副刊编...
# 7142  《射雕》中的人物个性单纯，郭靖诚朴厚重、黄蓉机智灵巧，读者容易印象深刻。这是中国传统小说和戏...
# 7143  写《射雕》时，我正在长城电影公司做编剧和导演，这段时期中所读的书主要是西洋的戏剧和戏剧理论，...
# 7144  修订时曾作了不少改动。删去了初版中一些与故事或人物并无必要联系的情节，如小红鸟、蛙蛤大战、铁...
# 7145  成吉思汗的事迹，主要取材于一部非常奇怪的书。这部书本来面目的怪异，远胜《九阴真经》，书名《忙...
# 7146  原来此书是以汉字写蒙古话，写成于一二四○年七月。“忙豁仑”就是“蒙古”，“纽察”在蒙古话中是...
# 7147  《元朝秘史》的第一行，仍写着原书书名的怪文“忙豁仑纽察脱必赤颜”。起初治元史的学者如李文田等...
# 7148  后来叶德辉所刊印的“怪文本”流传到了外国，各国汉学家热心研究，其中以法国人伯希和、德国人海涅...
# 7149  我所参考的《蒙古秘史》，是外蒙古学者策·达木丁苏隆先将汉字怪文本还原为蒙古古语（原书是十三世...
# 7150  《秘史》是原始材料，有若干修正本流传到西方，再由此而发展成许多著作，其中最重要的是波斯人拉施...
# 7151                  《九阴真经》中那段怪文的设想从什么地方得到启发，读者们自然知道了。
# 7152  蒙古人统治全中国八十九年，统治中国北部则超过一百年，但因文化低落，对中国人的生活没有遗留重大...
# 7153  本书的插图（大陆版未收——编注）有一幅是大理国画师张胜温所绘的佛像，此图有明朝翰林学士宋濂的...
# 7154  其中所考证的年代弄错了。宋濂认为画中的“庚子”是宋理宗嘉熙四年（一二四○年），其实他算迟了六...
# 7155  此图现藏台北故宫博物馆，该馆出版物中的说明根据宋濂的考证而写，将来似可改正。宋濂是明初有大名...
# 7156                                           一九七五年十二月
# 7157  本书第三版于2001年至2002年再作修订，改正了不少年代的错误，黄药师和诸弟子的关系也重写...
# 7158  第三版修订本中，将吕文焕守襄阳一节，改为李全、杨妙真夫妇领“忠义军”守青州，以顺合历史及地理...
# 7159  本书台湾出版者台北远流出版公司负责人王荣文先生、编辑李佳颖小姐、郑祥琳小姐、赵贞仪小姐，对书...
# 7160                                            二〇〇二年六月
# 7161         ------------------------------------------
# 7162  全本全集精校小说尽在：http://www.yimuhe.com/u/anglewing26...
# 7163                    更多资源下载：http://qqzone.ctdisk.com
# 7164  ※声明：本电子书仅供读者预览,请在下载24小时内删除，不得用作商业用途；如果喜欢请购买正版图书！※
#
# [7165 rows x 1 columns]

# %%
# 章节判断用变量预处理
def m_head(tmpstr):
    return tmpstr[:1]

def m_mid(tmpstr):
    return tmpstr.find("回 ")

raw['head'] = raw.txt.apply(m_head)
raw['mid'] = raw.txt.apply(m_mid)
raw['len'] = raw.txt.apply(len)
# raw['chap'] = 0
raw.head(50)
# Out:
#                                                   txt head  mid  len
# 0   全本全集精校小说尽在：http://www.yimuhe.com/u/anglewing26...    全   -1   55
# 1                     更多资源下载：http://qqzone.ctdisk.com    更   -1   31
# 2   ※声明：本电子书仅供读者预览,请在下载24小时内删除，不得用作商业用途；如果喜欢请购买正版图书！※    ※   -1   49
# 3          ------------------------------------------    -   -1   42
# 4                                           “金庸作品集”新序    “   -1    9
# 5                                   小说是写给人看的。小说的内容是人。    小   -1   17
# 6   小说写一个人、几个人、一群人、或成千成万人的性格和感情。他们的性格和感情从横面的环境中反映出...    小   -1  225
# 7   西洋传统的小说理论分别从环境、人物、情节三个方面去分析一篇作品。由于小说作者不同的个性与才能...    西   -1   56
# 8   基本上，武侠小说与别的小说一样，也是写人，只不过环境是古代的，主要人物是有武功的，情节偏重于...    基   -1  151
# 9   小说是艺术的一种，艺术的基本内容是人的感情和生命，主要形式是美，广义的、美学上的美。在小说，...    小   -1  133
# 10  读者阅读一部小说，是将小说的内容与自己的心理状态结合起来。同样一部小说，有的人感到强烈的震动...    读   -1   94
# 11  武侠小说只是表现人情的一种特定形式。作曲家或演奏家要表现一种情绪，用钢琴、小提琴、交响乐、或...    武   -1  155
# 12  好或者不好，在艺术上是属于美的范畴，不属于真或善的范畴。判断美的标准是美，是感情，不是科学上...    好   -1  148
# 13  在中世纪的欧洲，基督教的势力及于一切，所以我们到欧美的博物院去参观，见到所有中世纪的绘画都以...    在   -1  140
# 14  中国人的文艺观，长期以来是“文以载道”，那和中世纪欧洲黑暗时代的文艺思想是一致的，用“善或不...    中   -1  176
# 15  我写武侠小说，只是塑造一些人物，描写他们在特定的武侠环境（中国古代的、没有法治的、以武力来解...    我   -1  287
# 16  对于小说，我希望读者们只说喜欢或不喜欢，只说受到感动或觉得厌烦。我最高兴的是读者喜爱或憎恨我...    对   -1  262
# 17  武侠小说虽说是通俗作品，以大众化、娱乐性强为重点，但对广大读者终究是会发生影响的。我希望传达...    武   -1  266
# 18  武侠小说并不是现实主义的作品。有不少批评家认定，文学上只可肯定现实主义一个流派，除此之外，全...    武   -1  293
# 19  撰写这套总数三十六册的《作品集》，是从一九五五年到七二年，前后约十三、四年，包括十二部长篇小...    撰   -1  336
# 20  翻版本不付版税，还在其次。许多版本粗制滥造，错讹百出。还有人借用“金庸”之名，撰写及出版武侠...    翻   -1  224
# 21  有些翻版本中，还说我和古龙、倪匡合出了一个上联“冰比冰水冰”徵对，真正是大开玩笑了。汉语的对...    有   -1  128
# 22  为了使得读者易于分辨，我把我十四部长、中篇小说书名的第一个字凑成一副对联：“飞雪连天射白鹿，...    为   -1  240
# 23  有不少读者来信提出一个同样的问题：“你所写的小说之中，你认为哪一部最好？最喜欢哪一部？”这个...    有   -1  234
# 24  这些小说在香港、台湾、中国内地、新加坡曾拍摄为电影和电视连续集，有的还拍了三、四个不同版本，...    这   -1  370
# 25  武侠小说继承中国古典小说的长期传统。中国最早的武侠小说，应该是唐人传奇的《虬髯客传》、《红线...    武   -1  239
# 26  我初期所写的小说，汉人皇朝的正统观念很强。到了后期，中华民族各族一视同仁的观念成为基调，那是...    我   -1  306
# 27  历史上的事件和人物，要放在当时的历史环境中去看。宋辽之际、元明之际、明清之际，汉族和契丹、蒙...    历   -1  188
# 28  在刘再复先生与他千金刘剑梅合写的“父女两地书”（共悟人间）中，剑梅小姐提到她曾和李陀先生的一...    在   -1  280
# 29  这次第三次修改，改正了许多错字讹字、以及漏失之处，多数由于得到了读者们的指正。有几段较长的补...    这   -1  159
# 30                                        二○○二年四月 于香港    二   -1   11
# 31                                           第一回 风雪惊变    第    2    8
# 32  钱塘江浩浩江水，日日夜夜无穷无休的从两浙西路临安府牛家村边绕过，东流入海。江畔一排数十株乌柏...    钱   -1  136
# 33  那说话人五十来岁年纪，一件青布长袍早洗得褪成了蓝灰带白。只听他两片梨花木板碰了几下，左手中竹...    那   -1   81
# 34                                  几处败垣围故井，向来一一是人家。”    几   -1   17
# 35  那说话人将木板敲了几下，说道：“这首七言诗，说的是兵火过后，原来的家家户户，都变成了断墙残瓦...    那   -1  342
# 36  “叶老汉和叶妈妈吓得呆了，扑将上去，搂住了儿子的尸体，放声大哭。那长官提起狼牙棒，一棒一个，...    “   -1  245
# 37                        他说一段，唱一段，只听得众村民无不咬牙切齿，愤怒叹息。    他   -1   27
# 38                                  那人又道：“众位听了，常言道得好：    那   -1   17
# 39                                   为人切莫用欺心，举头三尺有神明。    为   -1   16
# 40                                   若还作恶无报应，天下凶徒人吃人。    若   -1   16
# 41  “可是那金兵占了我大宋天下，杀人放火，奸淫掳掠，无恶不作，却又不见他遭到什么报应。只怪我大宋...    “   -1  234
# 42    众村民便有人拿出两文三文，放入木盘，霎时间得了六七十文。张十五谢了，将铜钱放入囊中，便欲起行。    众   -1   47
# 43  村民中走出一个二十来岁的大汉，说道：“张先生，你可是从北方来吗？”说的是北方口音。张十五见他...    村   -1  225
# 44                        郭啸天带着张十五来到村头一家小酒店中，在张饭桌旁坐了。    郭   -1   27
# 45  小酒店的主人是个跛子，撑着两根拐杖，慢慢烫了两壶黄酒，摆出一碟蚕豆、一碟咸花生，一碟豆腐干，...    小   -1   92
# 46  郭啸天斟了酒，劝张十五喝了两杯，说道：“乡下地方，只初二、十六才有肉卖。没了下酒之物，先生莫...    郭   -1  173
# 47  张十五叹道：“江南花花世界，遍地皆是金银，放眼但见美女，金兵又有哪一日不想过来？只是他来与不...    张   -1   69
# 48                         郭啸天和杨铁心齐感诧异，同声问道：“这却是怎生说？”    郭   -1   26
# 49  张十五道：“我中国百姓，比女真人多上一百倍也还不止。只要朝廷肯用忠臣良将，咱们一百个打他一个...    张   -1  187

# %%
# 章节判断
chapnum = 0
for i in range(len(raw)):
    if raw['head'][i] == "第" and raw['mid'][i] > 0 and raw['len'][i] < 30 :
        chapnum += 1
    if chapnum >= 40 and raw['txt'][i] == "附录一：成吉思汗家族" :
        chapnum = 0
    raw.loc[i, 'chap'] = chapnum
    
# 删除临时变量
del raw['head']
del raw['mid']
del raw['len']
raw.head(50)
# Out:
#                                                   txt  chap
# 0   全本全集精校小说尽在：http://www.yimuhe.com/u/anglewing26...   0.0
# 1                     更多资源下载：http://qqzone.ctdisk.com   0.0
# 2   ※声明：本电子书仅供读者预览,请在下载24小时内删除，不得用作商业用途；如果喜欢请购买正版图书！※   0.0
# 3          ------------------------------------------   0.0
# 4                                           “金庸作品集”新序   0.0
# 5                                   小说是写给人看的。小说的内容是人。   0.0
# 6   小说写一个人、几个人、一群人、或成千成万人的性格和感情。他们的性格和感情从横面的环境中反映出...   0.0
# 7   西洋传统的小说理论分别从环境、人物、情节三个方面去分析一篇作品。由于小说作者不同的个性与才能...   0.0
# 8   基本上，武侠小说与别的小说一样，也是写人，只不过环境是古代的，主要人物是有武功的，情节偏重于...   0.0
# 9   小说是艺术的一种，艺术的基本内容是人的感情和生命，主要形式是美，广义的、美学上的美。在小说，...   0.0
# 10  读者阅读一部小说，是将小说的内容与自己的心理状态结合起来。同样一部小说，有的人感到强烈的震动...   0.0
# 11  武侠小说只是表现人情的一种特定形式。作曲家或演奏家要表现一种情绪，用钢琴、小提琴、交响乐、或...   0.0
# 12  好或者不好，在艺术上是属于美的范畴，不属于真或善的范畴。判断美的标准是美，是感情，不是科学上...   0.0
# 13  在中世纪的欧洲，基督教的势力及于一切，所以我们到欧美的博物院去参观，见到所有中世纪的绘画都以...   0.0
# 14  中国人的文艺观，长期以来是“文以载道”，那和中世纪欧洲黑暗时代的文艺思想是一致的，用“善或不...   0.0
# 15  我写武侠小说，只是塑造一些人物，描写他们在特定的武侠环境（中国古代的、没有法治的、以武力来解...   0.0
# 16  对于小说，我希望读者们只说喜欢或不喜欢，只说受到感动或觉得厌烦。我最高兴的是读者喜爱或憎恨我...   0.0
# 17  武侠小说虽说是通俗作品，以大众化、娱乐性强为重点，但对广大读者终究是会发生影响的。我希望传达...   0.0
# 18  武侠小说并不是现实主义的作品。有不少批评家认定，文学上只可肯定现实主义一个流派，除此之外，全...   0.0
# 19  撰写这套总数三十六册的《作品集》，是从一九五五年到七二年，前后约十三、四年，包括十二部长篇小...   0.0
# 20  翻版本不付版税，还在其次。许多版本粗制滥造，错讹百出。还有人借用“金庸”之名，撰写及出版武侠...   0.0
# 21  有些翻版本中，还说我和古龙、倪匡合出了一个上联“冰比冰水冰”徵对，真正是大开玩笑了。汉语的对...   0.0
# 22  为了使得读者易于分辨，我把我十四部长、中篇小说书名的第一个字凑成一副对联：“飞雪连天射白鹿，...   0.0
# 23  有不少读者来信提出一个同样的问题：“你所写的小说之中，你认为哪一部最好？最喜欢哪一部？”这个...   0.0
# 24  这些小说在香港、台湾、中国内地、新加坡曾拍摄为电影和电视连续集，有的还拍了三、四个不同版本，...   0.0
# 25  武侠小说继承中国古典小说的长期传统。中国最早的武侠小说，应该是唐人传奇的《虬髯客传》、《红线...   0.0
# 26  我初期所写的小说，汉人皇朝的正统观念很强。到了后期，中华民族各族一视同仁的观念成为基调，那是...   0.0
# 27  历史上的事件和人物，要放在当时的历史环境中去看。宋辽之际、元明之际、明清之际，汉族和契丹、蒙...   0.0
# 28  在刘再复先生与他千金刘剑梅合写的“父女两地书”（共悟人间）中，剑梅小姐提到她曾和李陀先生的一...   0.0
# 29  这次第三次修改，改正了许多错字讹字、以及漏失之处，多数由于得到了读者们的指正。有几段较长的补...   0.0
# 30                                        二○○二年四月 于香港   0.0
# 31                                           第一回 风雪惊变   1.0
# 32  钱塘江浩浩江水，日日夜夜无穷无休的从两浙西路临安府牛家村边绕过，东流入海。江畔一排数十株乌柏...   1.0
# 33  那说话人五十来岁年纪，一件青布长袍早洗得褪成了蓝灰带白。只听他两片梨花木板碰了几下，左手中竹...   1.0
# 34                                  几处败垣围故井，向来一一是人家。”   1.0
# 35  那说话人将木板敲了几下，说道：“这首七言诗，说的是兵火过后，原来的家家户户，都变成了断墙残瓦...   1.0
# 36  “叶老汉和叶妈妈吓得呆了，扑将上去，搂住了儿子的尸体，放声大哭。那长官提起狼牙棒，一棒一个，...   1.0
# 37                        他说一段，唱一段，只听得众村民无不咬牙切齿，愤怒叹息。   1.0
# 38                                  那人又道：“众位听了，常言道得好：   1.0
# 39                                   为人切莫用欺心，举头三尺有神明。   1.0
# 40                                   若还作恶无报应，天下凶徒人吃人。   1.0
# 41  “可是那金兵占了我大宋天下，杀人放火，奸淫掳掠，无恶不作，却又不见他遭到什么报应。只怪我大宋...   1.0
# 42    众村民便有人拿出两文三文，放入木盘，霎时间得了六七十文。张十五谢了，将铜钱放入囊中，便欲起行。   1.0
# 43  村民中走出一个二十来岁的大汉，说道：“张先生，你可是从北方来吗？”说的是北方口音。张十五见他...   1.0
# 44                        郭啸天带着张十五来到村头一家小酒店中，在张饭桌旁坐了。   1.0
# 45  小酒店的主人是个跛子，撑着两根拐杖，慢慢烫了两壶黄酒，摆出一碟蚕豆、一碟咸花生，一碟豆腐干，...   1.0
# 46  郭啸天斟了酒，劝张十五喝了两杯，说道：“乡下地方，只初二、十六才有肉卖。没了下酒之物，先生莫...   1.0
# 47  张十五叹道：“江南花花世界，遍地皆是金银，放眼但见美女，金兵又有哪一日不想过来？只是他来与不...   1.0
# 48                         郭啸天和杨铁心齐感诧异，同声问道：“这却是怎生说？”   1.0
# 49  张十五道：“我中国百姓，比女真人多上一百倍也还不止。只要朝廷肯用忠臣良将，咱们一百个打他一个...   1.0

# %%
rawgrp = raw.groupby('chap')
chapter = rawgrp.agg(sum) # 只有字符串列的情况下，sum函数自动转为合并字符串
chapter = chapter[chapter.index != 0]
chapter.txt[1]
a=chapter.txt[1]
a
# Out:
# '第一回 风雪惊变钱塘江浩浩江水，日日夜夜无穷无休的从两浙西路临安府牛家村边绕过，东流入海。江畔一排数十株乌柏树，叶子似火烧般红，正是八月天时。村前村后的野草刚起始变黄，一抹斜阳映照之下，更增了几分萧索。两株大松树下围着一堆村民，男男女女和十几个小孩，正自聚精会神的听着一个瘦削的老者说话。那说话人五十来岁年纪，一件青布长袍早洗得褪成了蓝灰带白。只听他两片梨花木板碰了几下，左手中竹棒在一面小羯鼓上敲起得得连声。唱道：“小桃无主自开花，烟草茫茫带晚鸦。几处败垣围故井，向来一一是人家。”那说话人将木板敲了几下，说道：“这首七言诗，说的是兵火过后，原来的家
# %%
##########
##########实验三
psg.lcut(a) # 直接输出为list，成员为pair
# Out:
# [pair('第一回', 'm'),
#  pair(' ', 'x'),
#  pair('风雪', 'n'),
#  pair('惊变', 'v'),
#  pair('钱塘江', 'nr'),
#  pair('浩浩', 'nz'),
#  pair('江水', 'ns'),
#  pair('，', 'x'),
#  pair('日日夜夜', 'i'),
#  pair('无穷', 'd'),
#  pair('无休', 'v'),
#  pair('的', 'uj'),
#  pair('从', 'p'),
#  pair('两', 'm'),
#  pair('浙西', 'ns'),
#  pair('路', 'n'),
#  pair('临安', 'ns'),
#  pair('府', 'nr'),
#  pair('牛家村', 'nr'),
#  pair('边', 'd'),
#  pair('绕过', 'v'),
#  pair('，', 'x'),
#  pair('东', 'ns'),
#  pair('流入', 'v'),
#  pair('海', 'n'),
#  pair('。', 'x'),
#  pair('江畔', 'ns'),
#  pair('一排', 'm'),
#  pair('数十株', 'm'),
#  pair('乌', 'nr'),
#  pair('柏树', 'nr'),
#  pair('，', 'x'),
#  pair('叶子', 'nr'),
#  pair('似', 'd'),
#  pair('火烧', 'n'),
#  pair('般红', 'z'),
#  pair('，', 'x'),
#  pair('正是', 'd'),
#  pair('八月', 't'),
#  pair('天时', 't'),
#  pair('。', 'x'),
#  pair('村前村后', 'l'),
#  pair('的', 'uj'),
#  pair('野草', 'n'),
#  pair('刚', 'd'),
#  pair('起始', 'v'),
#  pair('变', 'v'),
#  pair('黄', 'nr'),
#  pair('，', 'x'),
#  pair('一抹', 'm'),
#  pair('斜阳', 'n'),
#  pair('映照', 'v'),
#  pair('之下', 'f'),
#  pair('，', 'x'),
#  pair('更', 'd'),
#  pair('增', 'v'),
#  pair('了', 'ul'),
#  pair('几分', 'm'),
#  pair('萧索', 'nr'),
#  pair('。', 'x'),
#  pair('两株', 'm'),
#  pair('大', 'a'),
#  pair('松树', 'nr'),
#  pair('下', 'f'),
#  pair('围着', 'v'),
#  pair('一堆', 'm'),
#  pair('村民', 'n'),
#  pair('，', 'x'),
#  pair('男男女女', 'l'),
#  pair('和', 'c'),
#  pair('十几个', 'm'),
#  pair('小孩', 'n'),
#  pair('，', 'x'),
#  pair('正自', 'd'),
#  pair('聚精会神', 'n'),
#  pair('的', 'uj'),
#  pair('听', 'v'),
#  pair('着', 'uz'),
#  pair('一个', 'm'),
#  pair('瘦削', 'a'),
#  pair('的', 'uj'),
#  pair('老者', 'n'),
#  pair('说话', 'v'),
#  pair('。', 'x'),
#  pair('那', 'r'),
#  pair('说话', 'v'),
#  pair('人', 'n'),
#  pair('五十', 'm'),
#  pair('来', 'v'),
#  pair('岁', 'm'),
#  pair('年纪', 't'),
#  pair('，', 'x'),
#  pair('一件', 'm'),
#  pair('青布', 'v'),
#  pair('长袍', 'n'),
#  pair('早', 'a'),
#  pair('洗', 'v'),
#  pair('得', 'ud'),
#  pair('褪成', 'v'),
#  pair('了', 'ul'),
#  pair('蓝灰', 'n'),
#  pair('带白', 'v'),
#  pair('。', 'x'),
#  pair('只', 'd'),
#  pair('听', 'v'),
#  pair('他', 'r'),
#  pair('两片', 'm'),
#  pair('梨花', 'n'),
#  pair('木板', 'n'),
#  pair('碰', 'v'),
#  pair('了', 'ul'),
#  pair('几下', 'm'),
#  pair('，', 'x'),
#  pair('左手', 'm'),
#  pair('中', 'f'),
#  pair('竹棒', 'n'),
#  pair('在', 'p'),
#  pair('一面', 'm'),
#  pair('小', 'a'),
#  pair('羯鼓', 'n'),
#  pair('上', 'f'),
#  pair('敲起', 'v'),
#  pair('得', 'ud'),
#  pair('得', 'ud'),
#  pair('连声', 'd'),
#  pair('。', 'x'),
#  pair('唱道', 'v'),
#  pair('：', 'x'),
#  pair('“', 'x'),
#  pair('小桃', 'n'),
#  pair('无主', 'v'),
#  pair('自', 'r'),
#  pair('开花', 'n'),
#  pair('，', 'x'),
#  pair('烟草', 'n'),
#  pair('茫茫', 'z'),
#  pair('带', 'v'),
#  pair('晚鸦', 'n'),
#  pair('。', 'x'),
#  pair('几处', 'm'),
#  pair('败垣', 'n'),
#  pair('围', 'v'),
#  pair('故井', 'n'),
#  pair('，', 'x'),
#  pair('向来', 'v'),
#  pair('一一', 'm'),
#  pair('是', 'v'),
#  pair('人家', 'n'),
#  pair('。', 'x'),
#  pair('”', 'x'),
#  pair('那', 'r'),
#  pair('说话', 'v'),
#  pair('人', 'n'),
#  pair('将', 'd'),
#  pair('木板', 'n'),
#  pair('敲', 'v'),
#  pair('了', 'ul'),
#  pair('几下', 'm'),
#  pair('，', 'x'),
#  pair('说道', 'v'),
#  pair('：', 'x'),
#  pair('“', 'x'),
#  pair('这', 'r'),
#  pair('首', 'm'),
#  pair('七言诗', 'l'),
#  pair('，', 'x'),
#  pair('说', 'v'),
#  pair('的', 'uj'),
#  pair('是', 'v'),
#  pair('兵火', 'n'),
#  pair('过后', 't'),
#  pair('，', 'x'),
#  pair('原来', 'd'),
#  pair('的', 'uj'),
#  pair('家家户户', 'n'),
#  pair('，', 'x'),
#  pair('都', 'd'),
#  pair('变成', 'v'),
#  pair('了断', 'v'),
#  pair('墙', 'n'),
#  pair('残瓦', 'n'),
#  pair('的', 'uj'),
#  pair('破败', 'v'),
#  pair('之', 'u'),
#  pair('地', 'uv'),
#  pair('。', 'x'),
#  pair('小人', 'n'),
#  pair('刚才', 't'),
#  pair('说', 'v'),
#  pair('到', 'v'),
#  pair('那', 'r'),
#  pair('叶老汉', 'nr'),
#  pair('一家', 'm'),
#  pair('四口', 'm'),
#  pair('，', 'x'),
#  pair('悲欢离合', 'i'),
#  pair('，', 'x'),
#  pair('聚', 'v'),
#  pair('了', 'ul'),
#  pair('又', 'd'),
#  pair('散', 'v'),
#  pair('，', 'x'),
#  pair('散', 'v'),
#  pair('了', 'ul'),
#  pair('又', 'd'),
#  pair('聚', 'v'),
#  pair('。', 'x'),
#  pair('他', 'r'),
#  pair('四', 'm'),
#  pair('人', 'n'),
#  pair('给', 'p'),
#  pair('金兵', 'n'),
#  pair('冲散', 'v'),
#  pair('，', 'x'),
#  pair('好容易', 'l'),
#  pair('又', 'd'),
#  pair('再', 'd'),
#  pair('团聚', 'v'),
#  pair('，', 'x'),
#  pair('欢天喜地', 'i'),
#  pair('地', 'uv'),
#  pair('回到', 'v'),
#  pair('故乡', 'n'),
#  pair('卫州', 'nr'),
#  pair('，', 'x'),
#  pair('却', 'd'),
#  pair('见', 'v'),
#  pair('房屋', 'n'),
#  pair('已', 'd'),
#  pair('给', 'p'),
#  pair('金兵', 'n'),
#  pair('烧', 'v'),
#  pair('得', 'ud'),
#  pair('干干净净', 'z'),
#  pair('，', 'x'),
#  pair('无可奈何', 'i'),
#  pair('，', 'x'),
#  pair('只得', 'v'),
#  pair('去', 'v'),
#  pair('到', 'v'),
#  pair('京城', 'ns'),
#  pair('汴梁', 'ns'),
#  pair('，', 'x'),
#  pair('想', 'v'),
#  pair('觅', 'v'),
#  pair('个', 'q'),
#  pair('生计', 'vn'),
#  pair('。', 'x'),
#  pair('不', 'd'),
#  pair('料想', 'v'),
#  pair('：', 'x'),
#  pair('天有不测风云', 'i'),
#  pair('，', 'x'),
#  pair('人有旦夕祸福', 'i'),
#  pair('。', 'x'),
#  pair('他', 'r'),
#  pair('四', 'm'),
#  pair('人', 'n'),
#  pair('刚', 'd'),
#  pair('进', 'v'),
#  pair('汴梁', 'ns'),
#  pair('城', 'n'),
#  pair('，', 'x'),
#  pair('迎面', 'd'),
#  pair('便', 'd'),
#  pair('过来', 't'),
#  pair('一队', 'm'),
#  pair('金兵', 'n'),
#  pair('。', 'x'),
#  pair('带兵', 'v'),
#  pair('的', 'uj'),
#  pair('头儿', 'n'),
#  pair('一双', 'm'),
#  pair('三角', 'm'),
#  pair('眼', 'n'),
#  pair('觑', 'v'),
#  pair('将', 'd'),
#  pair('过去', 't'),
#  pair('，', 'x'),
#  pair('见', 'v'),
#  pair('那', 'r'),
#  pair('叶三姐', 'nr'),
#  pair('生', 'vn'),
#  pair('得', 'ud'),
#  pair('美貌', 'nz'),
#  pair('，', 'x'),
#  pair('跳', 'v'),
#  pair('下马', 'v'),
#  pair('来', 'v'),
#  pair('，', 'x'),
#  pair('当即', 'd'),
#  pair('一把', 'm'),
#  pair('抱住', 'v'),
#  pair('，', 'x'),
#  pair('哈哈大笑', 'l'),
#  pair('，', 'x'),
#  pair('便', 'd'),
#  pair('将', 'd'),
#  pair('她', 'r'),
#  pair('放上', 'v'),
#  pair('了', 'ul'),
#  pair('马鞍', 'nr'),
#  pair('，', 'x'),
#  pair('说道', 'v'),
#  pair('：', 'x'),
#  pair('‘', 'x'),
#  pair('小姑娘', 'nr'),
#  pair('，', 'x'),
#  pair('跟', 'p'),
#  pair('我', 'r'),
#  pair('回家', 'n'),
#  pair('，', 'x'),
#  pair('服侍', 'v'),
#  pair('老爷', 'n'),
#  pair('。', 'x'),
#  pair('’', 'x'),
#  pair('那', 'r'),
#  pair('叶三姐', 'nr'),
#  pair('如何', 'r'),
#  pair('肯从', 'v'),
#  pair('？', 'x'),
#  pair('拼命', 'v'),
#  pair('挣扎', 'v'),
#  pair('。', 'x'),
#  pair('那金兵', 'nr'),
#  pair('长官', 'n'),
#  pair('喝道', 'v'),
#  pair('：', 'x'),
#  pair('‘', 'x'),
#  pair('你', 'r'),
#  pair('不肯', 'v'),
#  pair('从', 'p'),
#  pair('我', 'r'),
#  pair('，', 'x'),
#  pair('便', 'd'),
#  pair('杀', 'v'),
#  pair('了', 'ul'),
#  pair('你', 'r'),
#  pair('的', 'uj'),
#  pair('父母', 'n'),
#  pair('兄弟', 'n'),
#  pair('！', 'x'),
#  pair('’', 'x'),
#  pair('提起', 'v'),
#  pair('狼牙棒', 'i'),
#  pair('，', 'x'),
#  pair('一', 'm'),
#  pair('棒打', 'n'),
#  pair('在', 'p'),
#  pair('那', 'r'),
#  pair('叶四郎', 'nr'),
#  pair('的', 'uj'),
#  pair('头上', 's'),
#  pair('，', 'x'),
#  pair('登时', 'd'),
#  pair('脑浆', 'n'),
#  pair('迸裂', 'v'),
#  pair('，', 'x'),
#  pair('一命呜呼', 'i'),
#  pair('。', 'x'),
#  pair('正是', 'd'),
#  pair('：', 'x'),
#  pair('阴世', 'nr'),
#  pair('新添', 'v'),
#  pair('枉死鬼', 'i'),
#  pair('，', 'x'),
#  pair('阳间', 'n'),
#  pair('不见', 'v'),
#  pair('少年人', 'n'),
#  pair('！', 'x'),
#  pair('“', 'x'),
#  pair('叶老汉', 'nr'),
#  pair('和', 'c'),
#  pair('叶', 'nr'),
#  pair('妈妈', 'n'),
#  pair('吓', 'v'),
#  pair('得', 'ud'),
#  pair('呆', 'v'),
#  pair('了', 'ul'),
#  pair('，', 'x'),
#  pair('扑', 'v'),
#  pair('将', 'd'),
#  pair('上去', 't'),
#  pair('，', 'x'),
#  pair('搂住', 'v'),
#  pair('了', 'ul'),
#  pair('儿子', 'n'),
#  pair('的', 'uj'),
#  pair('尸体', 'n'),
#  pair('，', 'x'),
#  pair('放声大哭', 'l'),
#  pair('。', 'x'),
#  pair('那', 'r'),
#  pair('长官', 'n'),
#  pair('提起', 'v'),
#  pair('狼牙棒', 'i'),
#  pair('，', 'x'),
#  pair('一', 'm'),
#  pair('棒', 'a'),
#  pair('一个', 'm'),
#  pair('，', 'x'),
#  pair('又', 'd'),
#  pair('都', 'd'),
#  pair('了', 'ul'),
#  pair('帐', 'q'),
#  pair('。', 'x'),
#  pair('那', 'r'),
#  pair('叶三姐', 'nr'),
#  pair('却', 'd'),
#  pair('不', 'd'),
#  pair('啼哭', 'v'),
#  pair('，', 'x'),
#  pair('说道', 'v'),
#  pair('：', 'x'),
#  pair('‘', 'x'),
#  pair('长官', 'n'),
#  pair('休', 'zg'),
#  pair('得', 'ud'),
#  pair('凶恶', 'a'),
#  pair('，', 'x'),
#  pair('我', 'r'),
#  pair('跟', 'p'),
#  pair('你', 'r'),
#  pair('回家', 'n'),
#  pair('便', 'd'),
#  pair('了', 'ul'),
#  pair('！', 'x'),
#  pair('’', 'x'),
#  pair('那', 'r'),
#  pair('长官', 'n'),
#  pair('大喜', 'n'),
#  pair('，', 'x'),
#  pair('将', 'd'),
#  pair('叶三姐', 'nr'),
#  pair('带得', 'v'),
#  pair('回家', 'n'),
#  pair('。', 'x'),
#  pair('不料', 'n'),
#  pair('叶三姐', 'nr'),
#  pair('觑', 'v'),
#  pair('他', 'r'),
#  pair('不', 'd'),
#  pair('防', 'v'),
#  pair('，', 'x'),
#  pair('突然', 'ad'),
#  pair('抢步', 'v'),
#  pair('过去', 't'),
#  pair('，', 'x'),
#  pair('拔出', 'v'),
#  pair('那', 'r'),
#  pair('长官', 'n'),
#  pair('的', 'uj'),
#  pair('腰刀', 'n'),
#  pair('，', 'x'),
#  pair('对准', 'n'),
#  pair('了', 'ul'),
#  pair('他', 'r'),
#  pair('心口', 's'),
#  pair('，', 'x'),
#  pair('挺', 'v'),
#  pair('刀', 'n'),
#  pair('刺', 'v'),
#  pair('将', 'd'),
#  pair('过去', 't'),
#  pair('，', 'x'),
#  pair('说时迟', 'l'),
#  pair('，', 'x'),
#  pair('那时快', 'nr'),
#  pair('，', 'x'),
#  pair('这', 'r'),
#  pair('钢刀', 'n'),
#  pair('刺去', 'v'),
#  pair('，', 'x'),
#  pair('眼见', 'n'),
#  pair('便', 'd'),
#  pair('可', 'v'),
#  pair('报得', 'v'),
#  pair('父母', 'n'),
#  pair('兄弟', 'n'),
#  pair('的', 'uj'),
#  pair('大仇', 'n'),
#  pair('。', 'x'),
#  pair('不料', 'n'),
#  pair('那', 'r'),
#  pair('长官', 'n'),
#  pair('久经', 'd'),
#  pair('战阵', 'n'),
#  pair('，', 'x'),
#  pair('武艺', 'n'),
#  pair('精熟', 'a'),
#  pair('，', 'x'),
#  pair('顺手', 'd'),
#  pair('一', 'm'),
#  pair('推', 'v'),
#  pair('，', 'x'),
#  pair('叶三姐', 'nr'),
#  pair('登时', 'd'),
#  pair('摔', 'v'),
#  pair('了', 'ul'),
#  pair('出去', 'v'),
#  pair('。', 'x'),
#  pair('那', 'r'),
#  pair('长官', 'n'),
#  pair('刚', 'd'),
#  pair('骂', 'v'),
#  pair('得', 'ud'),
#  pair('一声', 'm'),
#  pair('：', 'x'),
#  pair('‘', 'x'),
#  pair('小', 'a'),
#  pair('贱人', 'n'),
#  pair('！', 'x'),
#  pair('’', 'x'),
#  pair('叶三姐', 'nr'),
#  pair('已', 'd'),
#  pair('举起', 'v'),
#  pair('钢刀', 'n'),
#  pair('，', 'x'),
#  pair('在', 'p'),
#  pair('脖子', 'n'),
#  pair('中一勒', 'nz'),
#  pair('。', 'x'),
#  pair('可怜', 'v'),
#  pair('她', 'r'),
#  pair('：', 'x'),
#  pair('花容月貌', 'i'),
#  pair('无双', 'm'),
#  pair('女', 'b'),
#  pair('，', 'x'),
#  pair('惆怅', 'a'),
#  pair('芳魂', 'n'),
#  pair('赴', 'v'),
#  pair('九泉', 'nz'),
#  pair('。', 'x'),
#  pair('”', 'x'),
#  pair('他', 'r'),
#  pair('说', 'v'),
#  pair('一段', 'm'),
#  pair('，', 'x'),
#  pair('唱', 'v'),
#  pair('一段', 'm'),
#  pair('，', 'x'),
#  pair('只', 'd'),
#  pair('听', 'v'),
#  pair('得', 'ud'),
#  pair('众', 'i'),
#  pair('村民', 'n'),
#  pair('无不', 'd'),
#  pair('咬牙切齿', 'i'),
#  pair('，', 'x'),
#  pair('愤怒', 'v'),
#  pair('叹息', 'v'),
#  pair('。', 'x'),
#  pair('那人', 'r'),
#  pair('又', 'd'),
#  pair('道', 'q'),
#  pair('：', 'x'),
#  pair('“', 'x'),
#  pair('众位', 'm'),
#  pair('听', 'v'),
#  pair('了', 'ul'),
#  pair('，', 'x'),
#  pair('常言道', 'l'),
#  pair('得', 'ud'),
#  pair('好', 'a'),
#  pair('：', 'x'),
#  pair('为', 'p'),
#  pair('人', 'n'),
#  pair('切莫', 'nrt'),
#  pair('用', 'p'),
#  pair('欺心', 'v'),
#  pair('，', 'x'),
#  pair('举头', 'v'),
#  pair('三尺', 'm'),
#  pair('有', 'v'),
#  pair('神明', 'n'),
#  pair('。', 'x'),
#  pair('若', 'c'),
#  pair('还', 'd'),
#  pair('作恶', 'v'),
#  pair('无', 'v'),
#  pair('报应', 'v'),
#  pair('，', 'x'),
#  pair('天下', 's'),
#  pair('凶徒', 'n'),
#  pair('人吃人', 'n'),
#  pair('。', 'x'),
#  pair('“', 'x'),
#  pair('可是', 'c'),
#  pair('那金兵', 'nr'),
#  pair('占', 'v'),
#  pair('了', 'ul'),
#  pair('我', 'r'),
#  pair('大', 'a'),
#  pair('宋', 'nr'),
#  pair('天下', 's'),
#  pair('，', 'x'),
#  pair('杀人放火', 'i'),
#  pair('，', 'x'),
#  pair('奸淫掳掠', 'vn'),
#  pair('，', 'x'),
#  pair('无恶不作', 'i'),
#  pair('，', 'x'),
#  pair('却', 'd'),
#  pair('又', 'd'),
#  pair('不见', 'v'),
#  pair('他', 'r'),
#  pair('遭到', 'v'),
#  pair('什么', 'r'),
#  pair('报应', 'v'),
#  pair('。', 'x'),
#  pair('只', 'd'),
#  pair('怪', 'v'),
#  pair('我', 'r'),
#  pair('大', 'a'),
#  pair('宋', 'nr'),
#  pair('官家', 'n'),
#  pair('不争气', 'n'),
#  pair('，', 'x'),
#  pair('我', 'r'),
#  pair('中国', 'ns'),
#  pair('本来', 't'),
#  pair('兵多将广', 'i'),
#  pair('，', 'x'),
#  pair('可是', 'c'),
#  pair('一', 'm'),
#  pair('见到', 'v'),
#  pair('金兵', 'n'),
#  pair('到来', 'd'),
#  pair('，', 'x'),
#  pair('便', 'd'),
#  pair('远远地', 'z'),
#  pair('逃之夭夭', 'i'),
#  pair('，', 'x'),
#  pair('只', 'd'),
#  pair('剩下', 'v'),
#  pair('老百姓', 'n'),
#  pair('遭殃', 'v'),
#  pair('。', 'x'),
#  pair('好似', 'v'),
#  pair('那', 'r'),
#  pair('叶三姐', 'nr'),
#  pair('一家', 'm'),
#  pair('的', 'uj'),
#  pair('惨祸', 'n'),
#  pair('。', 'x'),
#  pair('江北', 'ns'),
#  pair('之', 'u'),
#  pair('地', 'uv'),
#  pair('，', 'x'),
#  pair('实', 'n'),
#  pair('是', 'v'),
#  pair('成千成万', 'i'),
#  pair('，', 'x'),
#  pair('便', 'd'),
#  pair('如', 'v'),
#  pair('家常便饭', 'l'),
#  pair('一般', 'a'),
#  pair('。', 'x'),
#  pair('诸君', 'nr'),
#  pair('住', 'v'),
#  pair('在', 'p'),
#  pair('江南', 'ns'),
#  pair('，', 'x'),
#  pair('当真', 'd'),
#  pair('是', 'v'),
#  pair('在', 'p'),
#  pair('天堂', 'n'),
#  pair('里', 'f'),
#  pair('了', 'ul'),
#  pair('，', 'x'),
#  pair('怕只怕', 'v'),
#  pair('金兵', 'n'),
#  pair('何日', 'r'),
#  pair('到来', 'd'),
#  pair('。', 'x'),
#  pair('正是', 'd'),
#  pair('：', 'x'),
#  pair('宁作', 'nr'),
#  pair('太平', 'ns'),
#  pair('犬', 'ng'),
#  pair('，', 'x'),
#  pair('莫为', 'nr'),
#  pair('乱世', 'v'),
#  pair('人', 'n'),
#  pair('。', 'x'),
#  pair('小人', 'n'),
#  pair('张十五', 'nr'),
#  pair('，', 'x'),
#  pair('今日', 't'),
#  pair('路经', 'n'),
#  pair('贵', 'a'),
#  pair('地', 'uv'),
#  pair('，', 'x'),
#  pair('服侍', 'v'),
#  pair('众位', 'm'),
#  pair('听客', 'v'),
#  pair('这', 'r'),
#  pair('一段', 'm'),
#  pair('说话', 'v'),
#  pair('，', 'x'),
#  pair('叫作', 'v'),
#  pair('《', 'x'),
#  pair('叶三姐', 'nr'),
#  pair('节烈', 'a'),
#  pair('记', 'n'),
#  pair('》', 'x'),
#  pair('。', 'x'),
#  pair('话本', 'n'),
#  pair('说', 'v'),
#  pair('彻', 'ad'),
#  pair('，', 'x'),
#  pair('权', 'n'),
#  pair('作', 'v'),
#  pair('散场', 'n'),
#  pair('。', 'x'),
#  pair('”', 'x'),
#  pair('将', 'd'),
#  pair('两片', 'm'),
#  pair('梨花', 'n'),
#  pair('木板', 'n'),
#  pair('啪啪', 'o'),
#  pair('啪', 'o'),
#  pair('的', 'uj'),
#  pair('乱', 'd'),
#  pair('敲', 'v'),
#  pair('一阵', 'm'),
#  pair('，', 'x'),
#  pair('托出', 'v'),
#  pair('一只', 'm'),
#  pair('盘子', 'n'),
#  pair('。', 'x'),
#  pair('众', 'ng'),
#  pair('村民', 'n'),
#  pair('便', 'd'),
#  pair('有人', 'r'),
#  pair('拿出', 'v'),
#  pair('两文', 'm'),
#  pair('三文', 'nz'),
#  pair('，', 'x'),
#  pair('放入', 'v'),
#  pair('木盘', 'n'),
#  pair('，', 'x'),
#  pair('霎时间', 't'),
#  pair('得', 'ud'),
#  pair('了', 'ul'),
#  pair('六七十', 'm'),
#  pair('文', 'n'),
#  pair('。', 'x'),
#  pair('张十五', 'nr'),
#  pair('谢', 'v'),
#  pair('了', 'ul'),
#  pair('，', 'x'),
#  pair('将', 'd'),
#  pair('铜钱', 'n'),
#  pair('放入', 'v'),
#  pair('囊中', 's'),
#  pair('，', 'x'),
#  pair('便', 'd'),
#  pair('欲', 'd'),
#  pair('起行', 'v'),
#  pair('。', 'x'),
#  pair('村民', 'n'),
#  pair('中', 'f'),
#  pair('走出', 'v'),
#  pair('一个二十', 'm'),
#  pair('来', 'v'),
#  pair('岁', 'm'),
#  pair('的', 'uj'),
#  pair('大汉', 'ns'),
#  pair('，', 'x'),
#  pair('说道', 'v'),
#  pair('：', 'x'),
#  pair('“', 'x'),
#  pair('张', 'q'),
#  pair('先生', 'n'),
#  pair('，', 'x'),
#  pair('你', 'r'),
#  pair('可是', 'c'),
#  pair('从', 'p'),
#  pair('北方', 'f'),
#  pair('来', 'v'),
#  pair('吗', 'y'),
#  pair('？', 'x'),
#  pair('”', 'x'),
#  pair('说', 'v'),
#  pair('的', 'uj'),
#  pair('是', 'v'),
#  pair('北方', 'f'),
#  pair('口音', 'n'),
#  pair('。', 'x'),
#  pair('张十五', 'nr'),
#  pair('见', 'v'),
#  pair('他', 'r'),
#  pair('身材', 'n'),
#  pair('魁梧', 'a'),
#  pair('，', 'x'),
#  pair('浓眉大眼', 'i'),
#  pair('，', 'x'),
#  pair('便', 'd'),
#  pair('道', 'q'),
#  pair('：', 'x'),
#  pair('“', 'x'),
#  pair('正是', 'd'),
#  pair('。', 'x'),
#  pair('”', 'x'),
#  pair('那', 'r'),
#  pair('大汉', 'ns'),
#  pair('道', 'q'),
#  pair('：', 'x'),
#  pair('“', 'x'),
#  pair('小弟', 'n'),
#  pair('做东', 'n'),
#  pair('，', 'x'),
#  pair('请', 'v'),
#  pair('先生', 'n'),
#  pair('去', 'v'),
#  pair('饮', 'v'),
#  pair('上', 'f'),
#  pair('三杯', 'm'),
#  pair('如何', 'r'),
#  pair('？', 'x'),
#  pair('”', 'x'),
#  pair('张', 'q'),
#  pair('十五大', 'j'),
#  pair('喜', 'v'),
#  pair('，', 'x'),
#  pair('说道', 'v'),
#  pair('：', 'x'),
#  pair('“', 'x'),
#  pair('素不相识', 'i'),
#  pair('，', 'x'),
#  pair('怎敢', 'l'),
#  pair('叨扰', 'v'),
#  pair('？', 'x'),
#  pair('”', 'x'),
#  pair('那', 'r'),
#  pair('大汉', 'ns'),
#  pair('笑', 'v'),
#  pair('道', 'q'),
#  pair('：', 'x'),
#  pair('“', 'x'),
#  pair('喝', 'vg'),
#  pair('上', 'f'),
#  pair('三杯', 'm'),
#  pair('，', 'x'),
#  pair('那', 'r'),
#  pair('便', 'd'),
#  pair('相识', 'v'),
#  pair('了', 'ul'),
#  pair('。', 'x'),
#  pair('俺', 'r'),
#  pair('姓', 'v'),
#  pair('郭', 'nr'),
#  pair('，', 'x'),
#  pair('名叫', 'v'),
#  pair('郭啸天', 'nr'),
#  pair('。', 'x'),
#  pair('”', 'x'),
#  pair('指着', 'v'),
#  pair('身旁', 's'),
#  pair('一个', 'm'),
#  pair('白净', 'nr'),
#  pair('面皮', 'n'),
#  pair('的', 'uj'),
#  pair('汉子', 'n'),
#  pair('道', 'q'),
#  pair('：', 'x'),
#  pair('“', 'x'),
#  pair('这位', 'rz'),
#  pair('是', 'v'),
#  pair('杨铁心', 'nr'),
#  pair('杨兄弟', 'nr'),
#  pair('。', 'x'),
#  pair('适才', 'n'),
#  pair('俺', 'r'),
#  pair('二人', 'nrt'),
#  pair('听', 'v'),
#  pair('先生', 'n'),
#  pair('说唱', 'v'),
#  pair('叶三姐', 'nr'),
#  pair('节烈', 'a'),
#  pair('记', 'n'),
#  pair('，', 'x'),
#  pair('果然', 'd'),
#  pair('是', 'v'),
#  pair('说得好', 'l'),
#  pair('，', 'x'),
#  pair('却', 'd'),
#  pair('有', 'v'),
#  pair('几句话', 'l'),
#  pair('想要', 'v'),
#  pair('请问', 'v'),
#  pair('。', 'x'),
#  pair('”', 'x'),
#  pair('张', 'q'),
#  pair('十五道', 'm'),
#  pair('：', 'x'),
#  pair('“', 'x'),
#  pair('好', 'a'),
#  pair('说', 'v'),
#  pair('，', 'x'),
#  pair('好', 'a'),
#  pair('说', 'v'),
#  pair('。', 'x'),
#  pair('今日', 't'),
#  pair('得遇', 'v'),
#  pair('郭杨', 'nr'),
#  pair('二位', 'm'),
#  pair('，', 'x'),
#  pair('也', 'd'),
#  pair('是', 'v'),
#  pair('有缘', 'n'),
#  pair('。', 'x'),
#  pair('”', 'x'),
#  pair('郭啸天', 'nr'),
#  pair('带', 'v'),
#  pair('着', 'uz'),
#  pair('张十五', 'nr'),
#  pair('来到', 'v'),
#  pair('村头', 'n'),
#  pair('一家', 'm'),
#  pair('小', 'a'),
#  pair('酒店', 'n'),
#  pair('中', 'f'),
#  pair('，', 'x'),
#  pair('在', 'p'),
#  pair('张', 'nr'),
#  pair('饭桌', 'n'),
#  pair('旁坐', 'v'),
#  pair('了', 'ul'),
#  pair('。', 'x'),
#  pair('小', 'a'),
#  pair('酒店', 'n'),
#  pair('的', 'uj'),
#  pair('主人', 'n'),
#  pair('是', 'v'),
#  pair('个', 'q'),
#  pair('跛子', 'n'),
#  pair('，', 'x'),
#  pair('撑', 'v'),
#  pair('着', 'uz'),
#  pair('两根', 'm'),
#  pair('拐杖', 'n'),
#  pair('，', 'x'),
#  pair('慢慢', 'd'),
#  pair('烫', 'v'),
#  pair('了', 'ul'),
#  pair('两壶', 'n'),
#  pair('黄酒', 'n'),
#  pair('，', 'x'),
#  pair('摆', 'v'),
#  pair('出', 'v'),
#  pair('一碟', 'n'),
#  pair('蚕豆', 'n'),
#  pair('、', 'x'),
#  pair('一碟', 'n'),
#  pair('咸', 'ns'),
#  pair('花生', 'n'),
#  pair('，', 'x'),
#  pair('一碟', 'n'),
#  pair('豆腐干', 'n'),
#  pair('，', 'x'),
#  pair('另', 'r'),
#  pair('有', 'v'),
#  pair('三个', 'm'),
#  pair('切开', 'ad'),
#  pair('的', 'uj'),
#  pair('咸蛋', 'nr'),
#  pair('，', 'x'),
#  pair('自行', 'r'),
#  pair('在', 'p'),
#  pair('门口', 's'),
#  pair('板凳', 'n'),
#  pair('上', 'f'),
#  pair('坐', 'v'),
#  pair('了', 'ul'),
#  pair('，', 'x'),
#  pair('抬头', 'v'),
#  pair('瞧', 'v'),
#  pair('着', 'uz'),
#  pair('天边', 's'),
#  pair('正要', 'a'),
#  pair('落山', 'ns'),
#  pair('的', 'uj'),
#  pair('太阳', 'ns'),
#  pair('，', 'x'),
#  pair('却', 'd'),
#  pair('不再', 'd'),
#  pair('向', 'p'),
#  pair('三', 'm'),
#  pair('人', 'n'),
#  pair('望', 'v'),
#  pair('上', 'f'),
#  pair('一眼', 'm'),
#  pair('。', 'x'),
#  pair('郭啸天', 'nr'),
#  pair('斟', 'v'),
#  pair('了', 'ul'),
#  pair('酒', 'n'),
#  ...]

# %%
wordlist = []
b=psg.lcut(a)
for t in b:
     if t.flag in ["nr",]:
            wordlist.append(t.word)

# %%
print(wordlist)
# Out:
'杨铁心', '包惜弱', '包惜弱', '包惜弱', '包惜弱', '白雪', '仁慈', '田鸡', '田野', '红梅', '包惜弱', '杨铁心', '杨铁心', '包惜弱', '包惜弱', '包惜弱', '那枝箭', '包惜弱', '包惜弱', '包惜弱', '包惜弱', '高耸', '宛', '包惜弱', '汤全', '包惜弱', '包惜弱', '柴房中', '冷汗', '包惜弱', '向西', '杨铁心', '包惜弱', '杨铁心', '曲三', '小女儿', '包惜弱', '红梅', '杨铁心', '曲三', '包惜弱', '杨氏', '包惜弱', '杨铁心', '包惜弱', '张木儿', '包惜弱', '杨铁心', '包惜弱', '杨铁心', '包惜弱', '包惜弱', '包惜弱', '马来', '杨铁心', '越来越近', '杨铁心', '包惜弱', '杨铁心', '杨铁心', '齐声', '莫让', '杨铁心', '寻思', '曲三', '武功', '郭啸天', '杨铁心', '杨铁心', '包惜弱', '杨铁心',  ...

# %%
wordlist2 = []
b=psg.lcut(a)
for t in b:
     if t.flag in ["ns",]:
            wordlist2.append(t.word)

# %%
print(wordlist2)
# Out:
# ['江水', '浙西', '临安', '东', '江畔', '京城', '汴梁', '汴梁', '中国', '江北', '江南', '太平', '大汉', '大汉', '大汉', '咸', '落山', '太阳', '山东', '江南', '江南', '金国', '临安', '中国', '朝廷', '半壁江山', '江山', '朝廷', '京城', '汴梁', '京城', '中国', '南京', '京城', '汴梁', '中国', '临安', '金国', '中国', '绍兴', '绍兴', '两国', '淮', '藩国', '中国', '淮水', '河山', '泰山', '江山', '临安', '青山', '西湖', '杭州', '汴州', '西湖', '杭州', '汴梁', '旧京', '临安', '之极', '无伦', '临安', '东西', '八拜', '朝廷', '妙绝', '半壁江山', '东西', '巴巴', '大江', '北风', '中', '东西', '之士', '临安', '朝廷', '临安', '竹篱茅舍', '山野', '临安', '扬头', '江湖', '山东', '大汉', '临安', '满口', '山东', '山东', '东西', '江湖', '怒极', '长撒', '中原', '虎口', '长春', '长春', '江南', '长春', '江湖', '临安', '临安', '大金国', '金国', '意兴', '二哥', '东西', '哥哥', '松林', '狼牙', '深渊', '英雄', '东村', '东南西北', '江湖', '东西', '临安', '临安', '临安', '白马', '那马', '上马', '临安', '中都', '那马', '中原', '辽东', '那马', '北', '黑马', '长索', '长索', '黑马', '黑马', '临安', '贵村', '之士', '上马', '北', '那大', '长安', '江南春', '北', '临安', '临安', '临安', '安顿', '朝廷', '英雄', '淮河', '中宿歇', '浙西', '大城', '秀州', '龙兴', '临安', '兴旺']

# %%
allwordslist=wordlist + wordlist2
print(allwordslist)
# Out:
# ['钱塘江', '府', '牛家村', '乌', '柏树', '叶子', '黄', '萧索', '松树', '叶老汉', '卫州', '叶三姐', '马鞍', '小姑娘', '叶三姐', '那金兵', '叶四郎', '阴世', '叶老汉', '叶', '叶三姐', '叶三姐', '叶三姐', '那时快', '叶三姐', '叶三姐', '那金兵', '宋', '宋', '叶三姐', '诸君', '宁作', '莫为', '张十五', '叶三姐', '张十五', '张十五', '郭', '郭啸天', '白净', '杨铁心', '杨兄弟', '叶三姐', '郭杨', '郭啸天', '张十五', '张', '咸蛋', '郭啸天', '张十五', '杨铁心', '金狗', '江', '张十五', '宋朝廷', '郭啸天', '杨铁心', '宋', '高宗', '金', '郭啸天', '宗道君', '蔡京', '朱', '王', '童贯', '梁师成', '李邦彦', '里若',
# %%
df = pd.DataFrame(allwordslist, columns = ['word'])
result = df.groupby(['word']).size()
print(type(result))
freqlist = result.sort_values(ascending=False)
freqlist
# Out:
# <class 'pandas.core.series.Series'>
# word
# 杨铁心     148
# 包惜弱     114
# 郭啸天      67
# 郭        38
# 颜烈       37
# 杨二人      32
# 那道人      24
# 临安       21
# 曲三       19
# 段天德      17
# 杨家枪      13
# 秦桧       12
# 武功       11
# 李萍       11
# 叶三姐      10
# 岳爷爷      10
# 李氏        9
# 张十五       9
# 府         9
# 宋         9
# 牛家村       7
# 老虎        7
# 冷笑        7
# 杨         6
# 相公        6
# 马背        6
# 东西        6
# 杨再兴       6
# 中国        6
# 高宗皇帝      5
#        ...
# 萍         1
# 杨将军       1
# 那枝箭       1
# 杨氏        1
# 梁师成       1
# 赵构        1
# 江水        1
# 越来越近      1
# 江南春       1
# 越礼        1
# 江北        1
# 江         1
# 辽东        1
# 武林        1
# 武勇        1
# 森森        1
# 齐备        1
# 那时快       1
# 栗六        1
# 柴房中       1
# 柏树        1
# 林来        1
# 松树        1
# 松林        1
# 连珠        1
# 杨门        1
# 那大        1
# 杨郭        1
# 杨老令       1
# 龙兴        1
# Length: 319, dtype: int64

# %%
import wordcloud
import matplotlib.pyplot as plt
myfont = 'msyh.ttf'
cloudobj = wordcloud.WordCloud(font_path = myfont, 
    width = 450, height = 250,
    mode = "RGBA", background_color = None).fit_words(freqlist)
plt.imshow(cloudobj)
plt.axis("off")
plt.show()

# %%
# 官网提供的颜色分组类代码，略有修改
from wordcloud import get_single_color_func

class GroupedColorFunc(object):

    def __init__(self, color_to_words, default_color):
        self.color_func_to_words = [
            (get_single_color_func(color), set(words))
            for (color, words) in color_to_words.items()]

        self.default_color_func = get_single_color_func(default_color)

    def get_color_func(self, word):
        """Returns a single_color_func associated with the word"""
        try:
            color_func = next(
                color_func for (color_func, words) in self.color_func_to_words
                if word in words)
        except StopIteration:
            color_func = self.default_color_func

        return color_func

    def __call__(self, word, **kwargs):
        return self.get_color_func(word)(word, **kwargs)

######

# 指定分组色系
color_to_words = {
    'blue': wordlist,
    'red': wordlist2
}

default_color = 'grey' # 指定其他词条的颜色

grouped_color_func = GroupedColorFunc(color_to_words, default_color)

cloudobj.recolor(color_func=grouped_color_func)

plt.imshow(cloudobj)
plt.axis("off")
plt.show()
cloudobj.to_file("词云.png")

# %%
import numpy as np
from scipy.misc import imread

imgobj = imread("蓝.jpg")
image_colors = wordcloud.ImageColorGenerator(np.array(imgobj))
cloudobj.recolor(color_func=image_colors)

plt.imshow(cloudobj)
plt.axis("off")
plt.show()

# %%
imgobj = imread("绿.jpg")
image_colors = wordcloud.ImageColorGenerator(np.array(imgobj))
cloudobj.recolor(color_func=image_colors)

plt.imshow(cloudobj)
plt.axis("off")
plt.show()

# %%
from scipy.misc import imread


cloudobj = wordcloud.WordCloud(font_path = myfont, 
    mask = imread("射雕背景1.png"), 
    mode = "RGBA", background_color = None
    ).fit_words(freqlist)

plt.imshow(cloudobj)
plt.axis("off")
plt.show()

# %%
cloudobj = wordcloud.WordCloud(font_path = myfont, 
    mask = imread("射雕背景2.png"), 
    mode = "RGBA", background_color = None
    ).fit_words(freqlist)

plt.imshow(cloudobj)
plt.axis("off")
plt.show()
